# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
from sklearn.metrics import mean_squared_error
# !pip install scikeras
# import scikeras

# %%
data=pd.read_csv('drive/MyDrive/Colab Notebooks/data.csv',delimiter=',',parse_dates=True,index_col=0)
# y=(data.iloc[:,-2]-data.iloc[:,-1])#.values
y=data.iloc[:,-2:]
X=data.iloc[:,:-2]#.values

# %%
y.std()
# Out:
# sum(physicalFlow)0 inflow     1.815534e+06
# sum(physicalFlow)1 outflow    2.205656e+06
# dtype: float64

# %%
y.mean()
# Out:
# sum(physicalFlow)0 inflow     7.223504e+06
# sum(physicalFlow)1 outflow    7.114683e+06
# dtype: float64

# %%
data
# Out:
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      sum(physicalFlow)0 inflow  sum(physicalFlow)1 outflow
# 2018-08-02 04:00:00                  5332486.0                   4084033.0
# 2018-08-02 05:00:00                  5425152.0                   4611564.0
# 2018-08-02 06:00:00                  5411656.0                   5204580.0
# 2018-08-02 07:00:00                  5792693.0                   5379787.0
# 2018-08-02 08:00:00                  5735920.0                   5706807.0
# ...                                        ...                         ...
# 2022-01-31 19:00:00                  7602602.0                  11077110.0
# 2022-01-31 20:00:00                  7418126.0                  10019737.0
# 2022-01-31 21:00:00                  7407216.0                   9476736.0
# 2022-01-31 22:00:00                  7398530.0                   8326807.0
# 2022-01-31 23:00:00                  7374867.0                   7325447.0
#
# [29001 rows x 5 columns]

# %% [markdown]
# # Feature engineering

# %%
f=lambda x: x.hour
ff=np.vectorize(f)
hour_of_day=ff(X.index.to_pydatetime())
X.loc[:, "hour"]=hour_of_day
X
# Out:
# <ipython-input-7-53c44885d1b3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, "hour"]=hour_of_day
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      hour
# 2018-08-02 04:00:00     4
# 2018-08-02 05:00:00     5
# 2018-08-02 06:00:00     6
# 2018-08-02 07:00:00     7
# 2018-08-02 08:00:00     8
# ...                   ...
# 2022-01-31 19:00:00    19
# 2022-01-31 20:00:00    20
# 2022-01-31 21:00:00    21
# 2022-01-31 22:00:00    22
# 2022-01-31 23:00:00    23
#
# [29001 rows x 4 columns]

# %% [markdown]
# # Split input data in 3 sets (train, validation, testing)

# %%
# https://datascience.stackexchange.com/questions/15135/train-test-validation-set-splitting-in-sklearn
from sklearn.model_selection import train_test_split

train_ratio = 0.75 # training
validation_ratio = 0.15 # hyperparameter tuning
test_ratio = 0.10 # final evaluation

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=test_ratio,shuffle=False, random_state=1234)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_ratio/(1-test_ratio),shuffle=False, random_state=1)

# print('train percent',X_train.index.size/X.index.size)
# print('validation percent',X_val.index.size/X.index.size)
# print('test percent',X_test.index.size/X.index.size)
print('train percent',y_train.index.size/X.index.size, '\ttrain days',y_train.index.size/24 )
print('validation percent',y_val.index.size/X.index.size,'\tvalid days',y_val.index.size/24)
print('test percent',y_test.index.size/X.index.size,'\ttest days',y_test.index.size/24)
# print('train percent',y_train.size/X.size, '\ttrain days',y_train.index.size/24 )
# Out:
# train percent 0.7499741388227992 	train days 906.25
# validation percent 0.14999482776455983 	valid days 181.25
# test percent 0.10003103341264094 	test days 120.875

# %%
train_idx=X_train.index
val_idx=X_val.index
test_idx=X_test.index
test_idx
# Out:
# DatetimeIndex(['2021-10-02 16:00:00', '2021-10-02 17:00:00',
#                '2021-10-02 18:00:00', '2021-10-02 19:00:00',
#                '2021-10-02 20:00:00', '2021-10-02 21:00:00',
#                '2021-10-02 22:00:00', '2021-10-02 23:00:00',
#                '2021-10-03 00:00:00', '2021-10-03 01:00:00',
#                ...
#                '2022-01-31 14:00:00', '2022-01-31 15:00:00',
#                '2022-01-31 16:00:00', '2022-01-31 17:00:00',
#                '2022-01-31 18:00:00', '2022-01-31 19:00:00',
#                '2022-01-31 20:00:00', '2022-01-31 21:00:00',
#                '2022-01-31 22:00:00', '2022-01-31 23:00:00'],
#               dtype='datetime64[ns]', length=2901, freq=None)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()


X_train=sc.fit_transform(X_train)
X_val=sc.transform(X_val)
X_test=sc.transform(X_test)

# %%
# from sklearn.utils import shuffle
# X_train_shuffled, y_train_shuffled = shuffle(X_train, y_train, random_state=42)

# %%
X_train
# Out:
# array([[-0.70473316, -0.44212536, -0.04271406, -1.08333581],
#        [-0.61317217,  0.11094688,  0.58407691, -0.93886447],
#        [-0.55823558,  0.79018873,  1.14383607, -0.79439312],
#        ...,
#        [ 1.11916167,  1.31215066, -0.59028562, -0.64992178],
#        [ 1.18142314,  1.83756929, -0.35001575, -0.50545043],
#        [ 1.18325436,  2.11756211, -0.22726918, -0.36097909]])

# %% [markdown]
# # Training neural networks

# %% [markdown]
# ## hidden layers: 32-32-16

# %% [markdown]
# ### 1 model creation + training process

# %%
# %%time
model_name='32-32-16'
def new_nn():
  ann=tf.keras.models.Sequential()
  ann.add(tf.keras.layers.Dense(units=32,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=32,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=16,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=2,activation='linear'))
  ann.compile(optimizer='adam',loss=tf.keras.losses.MeanSquaredError(),metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
  return ann

earlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',start_from_epoch=5, patience=500,restore_best_weights=True)
modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath='{epoch:02d}-32-32-16-1.keras',save_freq='epoch')

new=new_nn()
history=new.fit(X_train,y_train,epochs=3000,validation_data=(X_val,y_val),callbacks=[earlyStop,modelCheckpoint],verbose=2)
# Out:
# Epoch 1/3000
# 680/680 - 11s - 16ms/step - loss: 51077919539200.0000 - mean_absolute_percentage_error: 99.8119 - val_loss: 65036269649920.0000 - val_mean_absolute_percentage_error: 99.0775
# Epoch 2/3000
# 680/680 - 2s - 2ms/step - loss: 46361001066496.0000 - mean_absolute_percentage_error: 94.4045 - val_loss: 51060500594688.0000 - val_mean_absolute_percentage_error: 87.0673
# Epoch 3/3000
# 680/680 - 3s - 4ms/step - loss: 28489031876608.0000 - mean_absolute_percentage_error: 70.2374 - val_loss: 21732891033600.0000 - val_mean_absolute_percentage_error: 53.2038
# Epoch 4/3000
# 680/680 - 3s - 4ms/step - loss: 9232897277952.0000 - mean_absolute_percentage_error: 33.9536 - val_loss: 7179295260672.0000 - val_mean_absolute_percentage_error: 27.5208
# Epoch 5/3000
# 680/680 - 3s - 4ms/step - loss: 4014823702528.0000 - mean_absolute_percentage_error: 23.8342 - val_loss: 5495327293440.0000 - val_mean_absolute_percentage_error: 24.2941
# Epoch 6/3000
# 680/680 - 3s - 4ms/step - loss: 3528792997888.0000 - mean_absolute_percentage_error: 23.5791 - val_loss: 4910130659328.0000 - val_mean_absolute_percentage_error: 23.1562
# Epoch 7/3000
# 680/680 - 2s - 3ms/step - loss: 3326680236032.0000 - mean_absolute_percentage_error: 23.1120 - val_loss: 4504867569664.0000 - val_mean_absolute_percentage_error: 22.2713
# Epoch 8/3000
# 680/680 - 3s - 4ms/step - loss: 3171115859968.0000 - mean_absolute_percentage_error: 22.6668 - val_loss: 4157652336640.0000 - val_mean_absolute_percentage_error: 21.4654
# Epoch 9/3000
# 680/680 - 3s - 4ms/step - loss: 3046282362880.0000 - mean_absolute_percentage_error: 22.2888 - val_loss: 3886060142592.0000 - val_mean_absolute_percentage_error: 20.7666
# Epoch 10/3000
# 680/680 - 3s - 4ms/step - loss: 2948162650112.0000 - mean_absolute_percentage_error: 21.9459 - val_loss: 3656228274176.0000 - val_mean_absolute_percentage_error: 20.1643
# Epoch 11/3000
# 680/680 - 3s - 5ms/step - loss: 2876490907648.0000 - mean_absolute_percentage_error: 21.7148 - val_loss: 3503533326336.0000 - val_mean_absolute_percentage_error: 19.7036
# Epoch 12/3000
# 680/680 - 2s - 2ms/step - loss: 2824902279168.0000 - mean_absolute_percentage_error: 21.5209 - val_loss: 3397596217344.0000 - val_mean_absolute_percentage_error: 19.3916
# Epoch 13/3000
# 680/680 - 2s - 2ms/step - loss: 2788108795904.0000 - mean_absolute_percentage_error: 21.3836 - val_loss: 3278211383296.0000 - val_mean_absolute_percentage_error: 19.0548
# Epoch 14/3000
# 680/680 - 3s - 4ms/step - loss: 2760792604672.0000 - mean_absolute_percentage_error: 21.3174 - val_loss: 3264032538624.0000 - val_mean_absolute_percentage_error: 18.9649
# Epoch 15/3000
# 680/680 - 3s - 4ms/step - loss: 2740371587072.0000 - mean_absolute_percentage_error: 21.2165 - val_loss: 3212258574336.0000 - val_mean_absolute_percentage_error: 18.8198
# Epoch 16/3000
# 680/680 - 3s - 4ms/step - loss: 2725516935168.0000 - mean_absolute_percentage_error: 21.1589 - val_loss: 3143863894016.0000 - val_mean_absolute_percentage_error: 18.6332
# Epoch 17/3000
# 680/680 - 3s - 4ms/step - loss: 2713639452672.0000 - mean_absolute_percentage_error: 21.1372 - val_loss: 3114837737472.0000 - val_mean_absolute_percentage_error: 18.5365
# Epoch 18/3000
# 680/680 - 2s - 3ms/step - loss: 2704315777024.0000 - mean_absolute_percentage_error: 21.1046 - val_loss: 3166478270464.0000 - val_mean_absolute_percentage_error: 18.6405
# Epoch 19/3000
# 680/680 - 3s - 4ms/step - loss: 2697139847168.0000 - mean_absolute_percentage_error: 21.0594 - val_loss: 3093309161472.0000 - val_mean_absolute_percentage_error: 18.4583
# Epoch 20/3000
# 680/680 - 3s - 4ms/step - loss: 2690741698560.0000 - mean_absolute_percentage_error: 21.0599 - val_loss: 3161969655808.0000 - val_mean_absolute_percentage_error: 18.6039
# Epoch 21/3000
# 680/680 - 3s - 4ms/step - loss: 2685779836928.0000 - mean_absolute_percentage_error: 21.0128 - val_loss: 3115786698752.0000 - val_mean_absolute_percentage_error: 18.4850
# Epoch 22/3000
# 680/680 - 3s - 4ms/step - loss: 2681546473472.0000 - mean_absolute_percentage_error: 21.0155 - val_loss: 3107025846272.0000 - val_mean_absolute_percentage_error: 18.4562
# Epoch 23/3000
# 680/680 - 2s - 3ms/step - loss: 2678111600640.0000 - mean_absolute_percentage_error: 20.9987 - val_loss: 3129664339968.0000 - val_mean_absolute_percentage_error: 18.5036
# Epoch 24/3000
# 680/680 - 2s - 4ms/step - loss: 2675135741952.0000 - mean_absolute_percentage_error: 20.9765 - val_loss: 3110894567424.0000 - val_mean_absolute_percentage_error: 18.4664
# Epoch 25/3000
# 680/680 - 3s - 4ms/step - loss: 2672454008832.0000 - mean_absolute_percentage_error: 20.9758 - val_loss: 3090194366464.0000 - val_mean_absolute_percentage_error: 18.4010
# Epoch 26/3000
# 680/680 - 3s - 4ms/step - loss: 2670384906240.0000 - mean_absolute_percentage_error: 20.9711 - val_loss: 3128057397248.0000 - val_mean_absolute_percentage_error: 18.4972
# Epoch 27/3000
# 680/680 - 3s - 5ms/step - loss: 2669113769984.0000 - mean_absolute_percentage_error: 20.9525 - val_loss: 3092844118016.0000 - val_mean_absolute_percentage_error: 18.4060
# Epoch 28/3000
# 680/680 - 2s - 2ms/step - loss: 2667648385024.0000 - mean_absolute_percentage_error: 20.9652 - val_loss: 3122553421824.0000 - val_mean_absolute_percentage_error: 18.4750
# Epoch 29/3000
# 680/680 - 3s - 4ms/step - loss: 2666392977408.0000 - mean_absolute_percentage_error: 20.9413 - val_loss: 3085589544960.0000 - val_mean_absolute_percentage_error: 18.3748
# Epoch 30/3000
# 680/680 - 3s - 4ms/step - loss: 2664727576576.0000 - mean_absolute_percentage_error: 20.9384 - val_loss: 3024903471104.0000 - val_mean_absolute_percentage_error: 18.2199
# Epoch 31/3000
# 680/680 - 3s - 4ms/step - loss: 2663709671424.0000 - mean_absolute_percentage_error: 20.9545 - val_loss: 3124062584832.0000 - val_mean_absolute_percentage_error: 18.4870
# Epoch 32/3000
# 680/680 - 3s - 5ms/step - loss: 2663201898496.0000 - mean_absolute_percentage_error: 20.9339 - val_loss: 3130840842240.0000 - val_mean_absolute_percentage_error: 18.4846
# Epoch 33/3000
# 680/680 - 2s - 3ms/step - loss: 2662853509120.0000 - mean_absolute_percentage_error: 20.9402 - val_loss: 3075648520192.0000 - val_mean_absolute_percentage_error: 18.3456
# Epoch 34/3000
# 680/680 - 3s - 4ms/step - loss: 2662315851776.0000 - mean_absolute_percentage_error: 20.9337 - val_loss: 3090688770048.0000 - val_mean_absolute_percentage_error: 18.3930
# Epoch 35/3000
# 680/680 - 2s - 3ms/step - loss: 2661058084864.0000 - mean_absolute_percentage_error: 20.9421 - val_loss: 3192232869888.0000 - val_mean_absolute_percentage_error: 18.6487
# Epoch 36/3000
# 680/680 - 1s - 2ms/step - loss: 2660981800960.0000 - mean_absolute_percentage_error: 20.9067 - val_loss: 3034722336768.0000 - val_mean_absolute_percentage_error: 18.2401
# Epoch 37/3000
# 680/680 - 3s - 4ms/step - loss: 2660663033856.0000 - mean_absolute_percentage_error: 20.9367 - val_loss: 3136336429056.0000 - val_mean_absolute_percentage_error: 18.5058
# Epoch 38/3000
# 680/680 - 3s - 5ms/step - loss: 2660367597568.0000 - mean_absolute_percentage_error: 20.9298 - val_loss: 3129131925504.0000 - val_mean_absolute_percentage_error: 18.4818
# Epoch 39/3000
# 680/680 - 2s - 2ms/step - loss: 2659709616128.0000 - mean_absolute_percentage_error: 20.9247 - val_loss: 3131773812736.0000 - val_mean_absolute_percentage_error: 18.4805
# Epoch 40/3000
# 680/680 - 3s - 4ms/step - loss: 2659741335552.0000 - mean_absolute_percentage_error: 20.9125 - val_loss: 3077422710784.0000 - val_mean_absolute_percentage_error: 18.3425
# Epoch 41/3000
# 680/680 - 3s - 4ms/step - loss: 2659666624512.0000 - mean_absolute_percentage_error: 20.9283 - val_loss: 3115362025472.0000 - val_mean_absolute_percentage_error: 18.4399
# Epoch 42/3000
# 680/680 - 3s - 4ms/step - loss: 2659069460480.0000 - mean_absolute_percentage_error: 20.9234 - val_loss: 3088351494144.0000 - val_mean_absolute_percentage_error: 18.3712
# Epoch 43/3000
# 680/680 - 3s - 5ms/step - loss: 2658699837440.0000 - mean_absolute_percentage_error: 20.9216 - val_loss: 3147894095872.0000 - val_mean_absolute_percentage_error: 18.5317
# Epoch 44/3000
# 680/680 - 2s - 2ms/step - loss: 2658970894336.0000 - mean_absolute_percentage_error: 20.9129 - val_loss: 3105602404352.0000 - val_mean_absolute_percentage_error: 18.4185
# Epoch 45/3000
# 680/680 - 2s - 4ms/step - loss: 2658396012544.0000 - mean_absolute_percentage_error: 20.9148 - val_loss: 3101982982144.0000 - val_mean_absolute_percentage_error: 18.4096
# Epoch 46/3000
# 680/680 - 1s - 2ms/step - loss: 2658156412928.0000 - mean_absolute_percentage_error: 20.9283 - val_loss: 3138187165696.0000 - val_mean_absolute_percentage_error: 18.4930
# Epoch 47/3000
# 680/680 - 3s - 4ms/step - loss: 2657381253120.0000 - mean_absolute_percentage_error: 20.9081 - val_loss: 3091072024576.0000 - val_mean_absolute_percentage_error: 18.3649
# Epoch 48/3000
# 680/680 - 3s - 4ms/step - loss: 2657301299200.0000 - mean_absolute_percentage_error: 20.9087 - val_loss: 3037244948480.0000 - val_mean_absolute_percentage_error: 18.2268
# Epoch 49/3000
# 680/680 - 3s - 4ms/step - loss: 2657842626560.0000 - mean_absolute_percentage_error: 20.9111 - val_loss: 3087198322688.0000 - val_mean_absolute_percentage_error: 18.3592
# Epoch 50/3000
# 680/680 - 2s - 3ms/step - loss: 2657095516160.0000 - mean_absolute_percentage_error: 20.9127 - val_loss: 3128845139968.0000 - val_mean_absolute_percentage_error: 18.4664
# Epoch 51/3000
# 680/680 - 3s - 4ms/step - loss: 2657391476736.0000 - mean_absolute_percentage_error: 20.9053 - val_loss: 3098583498752.0000 - val_mean_absolute_percentage_error: 18.3868
# Epoch 52/3000
# 680/680 - 3s - 4ms/step - loss: 2657064058880.0000 - mean_absolute_percentage_error: 20.9099 - val_loss: 3090974244864.0000 - val_mean_absolute_percentage_error: 18.3751
# Epoch 53/3000
# 680/680 - 1s - 2ms/step - loss: 2656598491136.0000 - mean_absolute_percentage_error: 20.9163 - val_loss: 3101178462208.0000 - val_mean_absolute_percentage_error: 18.3918
# Epoch 54/3000
# 680/680 - 2s - 2ms/step - loss: 2657005862912.0000 - mean_absolute_percentage_error: 20.9047 - val_loss: 3102327701504.0000 - val_mean_absolute_percentage_error: 18.3999
# Epoch 55/3000
# 680/680 - 3s - 4ms/step - loss: 2655925829632.0000 - mean_absolute_percentage_error: 20.9143 - val_loss: 3149028917248.0000 - val_mean_absolute_percentage_error: 18.5236
# Epoch 56/3000
# 680/680 - 1s - 2ms/step - loss: 2656214450176.0000 - mean_absolute_percentage_error: 20.8964 - val_loss: 3091408879616.0000 - val_mean_absolute_percentage_error: 18.3745
# Epoch 57/3000
# 680/680 - 2s - 2ms/step - loss: 2655735775232.0000 - mean_absolute_percentage_error: 20.9073 - val_loss: 3143354023936.0000 - val_mean_absolute_percentage_error: 18.5087
# Epoch 58/3000
# 680/680 - 3s - 4ms/step - loss: 2656105922560.0000 - mean_absolute_percentage_error: 20.8894 - val_loss: 3081591586816.0000 - val_mean_absolute_percentage_error: 18.3433
# Epoch 59/3000
# 680/680 - 2s - 4ms/step - loss: 2655541264384.0000 - mean_absolute_percentage_error: 20.9193 - val_loss: 3134820712448.0000 - val_mean_absolute_percentage_error: 18.4882
# Epoch 60/3000
# 680/680 - 1s - 2ms/step - loss: 2655626723328.0000 - mean_absolute_percentage_error: 20.8872 - val_loss: 3056307798016.0000 - val_mean_absolute_percentage_error: 18.2831
# Epoch 61/3000
# 680/680 - 4s - 5ms/step - loss: 2655511642112.0000 - mean_absolute_percentage_error: 20.9078 - val_loss: 3119710208000.0000 - val_mean_absolute_percentage_error: 18.4428
# Epoch 62/3000
# 680/680 - 2s - 2ms/step - loss: 2655217254400.0000 - mean_absolute_percentage_error: 20.8927 - val_loss: 3070590713856.0000 - val_mean_absolute_percentage_error: 18.3099
# Epoch 63/3000
# 680/680 - 3s - 4ms/step - loss: 2654868865024.0000 - mean_absolute_percentage_error: 20.8914 - val_loss: 3024744087552.0000 - val_mean_absolute_percentage_error: 18.2103
# Epoch 64/3000
# 680/680 - 3s - 4ms/step - loss: 2655080153088.0000 - mean_absolute_percentage_error: 20.9037 - val_loss: 3072397410304.0000 - val_mean_absolute_percentage_error: 18.3191
# Epoch 65/3000
# 680/680 - 3s - 4ms/step - loss: 2654867292160.0000 - mean_absolute_percentage_error: 20.9087 - val_loss: 3150102659072.0000 - val_mean_absolute_percentage_error: 18.5239
# Epoch 66/3000
# 680/680 - 3s - 5ms/step - loss: 2654173659136.0000 - mean_absolute_percentage_error: 20.8706 - val_loss: 3033186697216.0000 - val_mean_absolute_percentage_error: 18.2246
# Epoch 67/3000
# 680/680 - 2s - 3ms/step - loss: 2654710530048.0000 - mean_absolute_percentage_error: 20.9187 - val_loss: 3163320745984.0000 - val_mean_absolute_percentage_error: 18.5623
# Epoch 68/3000
# 680/680 - 3s - 4ms/step - loss: 2654689558528.0000 - mean_absolute_percentage_error: 20.8893 - val_loss: 3122892374016.0000 - val_mean_absolute_percentage_error: 18.4580
# Epoch 69/3000
# 680/680 - 3s - 4ms/step - loss: 2654351917056.0000 - mean_absolute_percentage_error: 20.8840 - val_loss: 3102765219840.0000 - val_mean_absolute_percentage_error: 18.4082
# Epoch 70/3000
# 680/680 - 3s - 5ms/step - loss: 2654337236992.0000 - mean_absolute_percentage_error: 20.8985 - val_loss: 3052464766976.0000 - val_mean_absolute_percentage_error: 18.2702
# Epoch 71/3000
# 680/680 - 3s - 4ms/step - loss: 2654049402880.0000 - mean_absolute_percentage_error: 20.8832 - val_loss: 3052781436928.0000 - val_mean_absolute_percentage_error: 18.2689
# Epoch 72/3000
# 680/680 - 2s - 3ms/step - loss: 2653910728704.0000 - mean_absolute_percentage_error: 20.9027 - val_loss: 3092846477312.0000 - val_mean_absolute_percentage_error: 18.3794
# Epoch 73/3000
# 680/680 - 2s - 3ms/step - loss: 2653752393728.0000 - mean_absolute_percentage_error: 20.8826 - val_loss: 3107623534592.0000 - val_mean_absolute_percentage_error: 18.4123
# Epoch 74/3000
# 680/680 - 2s - 2ms/step - loss: 2653178560512.0000 - mean_absolute_percentage_error: 20.8937 - val_loss: 3168672153600.0000 - val_mean_absolute_percentage_error: 18.5839
# Epoch 75/3000
# 680/680 - 3s - 4ms/step - loss: 2653464035328.0000 - mean_absolute_percentage_error: 20.8937 - val_loss: 3143865991168.0000 - val_mean_absolute_percentage_error: 18.5047
# Epoch 76/3000
# 680/680 - 3s - 4ms/step - loss: 2653550542848.0000 - mean_absolute_percentage_error: 20.9010 - val_loss: 3170899329024.0000 - val_mean_absolute_percentage_error: 18.5750
# Epoch 77/3000
# 680/680 - 3s - 5ms/step - loss: 2653546086400.0000 - mean_absolute_percentage_error: 20.8809 - val_loss: 3100665446400.0000 - val_mean_absolute_percentage_error: 18.3919
# Epoch 78/3000
# 680/680 - 2s - 3ms/step - loss: 2653033857024.0000 - mean_absolute_percentage_error: 20.8846 - val_loss: 3087731261440.0000 - val_mean_absolute_percentage_error: 18.3526
# Epoch 79/3000
# 680/680 - 3s - 4ms/step - loss: 2652477849600.0000 - mean_absolute_percentage_error: 20.8874 - val_loss: 3063747969024.0000 - val_mean_absolute_percentage_error: 18.3038
# Epoch 80/3000
# 680/680 - 3s - 4ms/step - loss: 2652661088256.0000 - mean_absolute_percentage_error: 20.8897 - val_loss: 3082978590720.0000 - val_mean_absolute_percentage_error: 18.3523
# Epoch 81/3000
# 680/680 - 2s - 4ms/step - loss: 2653324050432.0000 - mean_absolute_percentage_error: 20.8882 - val_loss: 3072115867648.0000 - val_mean_absolute_percentage_error: 18.3187
# Epoch 82/3000
# 680/680 - 3s - 5ms/step - loss: 2652549152768.0000 - mean_absolute_percentage_error: 20.8727 - val_loss: 3037931241472.0000 - val_mean_absolute_percentage_error: 18.2431
# Epoch 83/3000
# 680/680 - 2s - 3ms/step - loss: 2652790325248.0000 - mean_absolute_percentage_error: 20.9043 - val_loss: 3098850623488.0000 - val_mean_absolute_percentage_error: 18.3935
# Epoch 84/3000
# 680/680 - 2s - 4ms/step - loss: 2652912746496.0000 - mean_absolute_percentage_error: 20.8782 - val_loss: 3089986486272.0000 - val_mean_absolute_percentage_error: 18.3675
# Epoch 85/3000
# 680/680 - 2s - 2ms/step - loss: 2651876753408.0000 - mean_absolute_percentage_error: 20.8980 - val_loss: 3134068097024.0000 - val_mean_absolute_percentage_error: 18.4767
# Epoch 86/3000
# 680/680 - 3s - 4ms/step - loss: 2652739731456.0000 - mean_absolute_percentage_error: 20.8833 - val_loss: 3154679431168.0000 - val_mean_absolute_percentage_error: 18.5387
# Epoch 87/3000
# 680/680 - 3s - 4ms/step - loss: 2652475490304.0000 - mean_absolute_percentage_error: 20.8857 - val_loss: 3136648118272.0000 - val_mean_absolute_percentage_error: 18.4825
# Epoch 88/3000
# 680/680 - 3s - 5ms/step - loss: 2651342241792.0000 - mean_absolute_percentage_error: 20.8812 - val_loss: 3119532998656.0000 - val_mean_absolute_percentage_error: 18.4306
# Epoch 89/3000
# 680/680 - 2s - 3ms/step - loss: 2652362768384.0000 - mean_absolute_percentage_error: 20.8752 - val_loss: 3123252559872.0000 - val_mean_absolute_percentage_error: 18.4631
# Epoch 90/3000
# 680/680 - 2s - 2ms/step - loss: 2651944124416.0000 - mean_absolute_percentage_error: 20.8695 - val_loss: 3032660574208.0000 - val_mean_absolute_percentage_error: 18.2131
# Epoch 91/3000
# 680/680 - 2s - 2ms/step - loss: 2652478373888.0000 - mean_absolute_percentage_error: 20.9027 - val_loss: 3133438689280.0000 - val_mean_absolute_percentage_error: 18.4729
# Epoch 92/3000
# 680/680 - 3s - 4ms/step - loss: 2651535179776.0000 - mean_absolute_percentage_error: 20.8790 - val_loss: 3104465747968.0000 - val_mean_absolute_percentage_error: 18.3995
# Epoch 93/3000
# 680/680 - 3s - 4ms/step - loss: 2651723923456.0000 - mean_absolute_percentage_error: 20.8829 - val_loss: 3119492628480.0000 - val_mean_absolute_percentage_error: 18.4368
# Epoch 94/3000
# 680/680 - 3s - 4ms/step - loss: 2651340144640.0000 - mean_absolute_percentage_error: 20.8768 - val_loss: 3074913992704.0000 - val_mean_absolute_percentage_error: 18.3308
# Epoch 95/3000
# 680/680 - 2s - 3ms/step - loss: 2651428225024.0000 - mean_absolute_percentage_error: 20.8703 - val_loss: 3022173503488.0000 - val_mean_absolute_percentage_error: 18.1960
# Epoch 96/3000
# 680/680 - 3s - 4ms/step - loss: 2651214315520.0000 - mean_absolute_percentage_error: 20.8880 - val_loss: 3108466327552.0000 - val_mean_absolute_percentage_error: 18.4244
# Epoch 97/3000
# 680/680 - 3s - 4ms/step - loss: 2651298201600.0000 - mean_absolute_percentage_error: 20.8809 - val_loss: 3114212524032.0000 - val_mean_absolute_percentage_error: 18.4308
# Epoch 98/3000
# 680/680 - 2s - 3ms/step - loss: 2651034222592.0000 - mean_absolute_percentage_error: 20.8637 - val_loss: 3017051471872.0000 - val_mean_absolute_percentage_error: 18.1788
# Epoch 99/3000
# 680/680 - 2s - 3ms/step - loss: 2651754594304.0000 - mean_absolute_percentage_error: 20.8961 - val_loss: 3104834060288.0000 - val_mean_absolute_percentage_error: 18.4036
# Epoch 100/3000
# 680/680 - 2s - 4ms/step - loss: 2650893189120.0000 - mean_absolute_percentage_error: 20.8848 - val_loss: 3124566163456.0000 - val_mean_absolute_percentage_error: 18.4511
# Epoch 101/3000
# 680/680 - 2s - 2ms/step - loss: 2651107098624.0000 - mean_absolute_percentage_error: 20.8693 - val_loss: 3084868386816.0000 - val_mean_absolute_percentage_error: 18.3527
# Epoch 102/3000
# 680/680 - 3s - 4ms/step - loss: 2650943782912.0000 - mean_absolute_percentage_error: 20.8891 - val_loss: 3142984138752.0000 - val_mean_absolute_percentage_error: 18.5085
# Epoch 103/3000
# 680/680 - 3s - 4ms/step - loss: 2650978385920.0000 - mean_absolute_percentage_error: 20.8644 - val_loss: 3038458150912.0000 - val_mean_absolute_percentage_error: 18.2388
# Epoch 104/3000
# 680/680 - 2s - 2ms/step - loss: 2650993590272.0000 - mean_absolute_percentage_error: 20.8808 - val_loss: 3049499918336.0000 - val_mean_absolute_percentage_error: 18.2550
# Epoch 105/3000
# 680/680 - 3s - 4ms/step - loss: 2650855178240.0000 - mean_absolute_percentage_error: 20.8919 - val_loss: 3145654337536.0000 - val_mean_absolute_percentage_error: 18.5137
# Epoch 106/3000
# 680/680 - 3s - 4ms/step - loss: 2650647298048.0000 - mean_absolute_percentage_error: 20.8701 - val_loss: 3131623079936.0000 - val_mean_absolute_percentage_error: 18.4855
# Epoch 107/3000
# 680/680 - 2s - 3ms/step - loss: 2650408222720.0000 - mean_absolute_percentage_error: 20.8915 - val_loss: 3124620165120.0000 - val_mean_absolute_percentage_error: 18.4553
# Epoch 108/3000
# 680/680 - 2s - 4ms/step - loss: 2650504691712.0000 - mean_absolute_percentage_error: 20.8470 - val_loss: 3012135485440.0000 - val_mean_absolute_percentage_error: 18.1729
# Epoch 109/3000
# 680/680 - 3s - 4ms/step - loss: 2650396688384.0000 - mean_absolute_percentage_error: 20.8784 - val_loss: 3033336643584.0000 - val_mean_absolute_percentage_error: 18.2158
# Epoch 110/3000
# 680/680 - 1s - 2ms/step - loss: 2650637860864.0000 - mean_absolute_percentage_error: 20.8788 - val_loss: 3033489735680.0000 - val_mean_absolute_percentage_error: 18.2211
# Epoch 111/3000
# 680/680 - 3s - 5ms/step - loss: 2650440728576.0000 - mean_absolute_percentage_error: 20.8770 - val_loss: 3055564881920.0000 - val_mean_absolute_percentage_error: 18.2775
# Epoch 112/3000
# 680/680 - 2s - 3ms/step - loss: 2649961791488.0000 - mean_absolute_percentage_error: 20.8769 - val_loss: 3054176567296.0000 - val_mean_absolute_percentage_error: 18.2656
# Epoch 113/3000
# 680/680 - 2s - 3ms/step - loss: 2650120912896.0000 - mean_absolute_percentage_error: 20.8934 - val_loss: 3115915673600.0000 - val_mean_absolute_percentage_error: 18.4238
# Epoch 114/3000
# 680/680 - 3s - 4ms/step - loss: 2650551615488.0000 - mean_absolute_percentage_error: 20.8621 - val_loss: 3077307891712.0000 - val_mean_absolute_percentage_error: 18.3325
# Epoch 115/3000
# 680/680 - 3s - 4ms/step - loss: 2650070319104.0000 - mean_absolute_percentage_error: 20.8833 - val_loss: 3051285118976.0000 - val_mean_absolute_percentage_error: 18.2636
# Epoch 116/3000
# 680/680 - 2s - 2ms/step - loss: 2649155436544.0000 - mean_absolute_percentage_error: 20.8759 - val_loss: 3156947238912.0000 - val_mean_absolute_percentage_error: 18.5448
# Epoch 117/3000
# 680/680 - 3s - 5ms/step - loss: 2650142408704.0000 - mean_absolute_percentage_error: 20.8650 - val_loss: 3116321734656.0000 - val_mean_absolute_percentage_error: 18.4311
# Epoch 118/3000
# 680/680 - 2s - 2ms/step - loss: 2649995608064.0000 - mean_absolute_percentage_error: 20.8800 - val_loss: 3103168921600.0000 - val_mean_absolute_percentage_error: 18.3995
# Epoch 119/3000
# 680/680 - 1s - 2ms/step - loss: 2649914081280.0000 - mean_absolute_percentage_error: 20.8771 - val_loss: 3140931813376.0000 - val_mean_absolute_percentage_error: 18.4989
# Epoch 120/3000
# 680/680 - 3s - 4ms/step - loss: 2649840156672.0000 - mean_absolute_percentage_error: 20.8764 - val_loss: 3147511103488.0000 - val_mean_absolute_percentage_error: 18.5119
# Epoch 121/3000
# 680/680 - 2s - 4ms/step - loss: 2649740279808.0000 - mean_absolute_percentage_error: 20.8719 - val_loss: 3121873944576.0000 - val_mean_absolute_percentage_error: 18.4438
# Epoch 122/3000
# 680/680 - 3s - 4ms/step - loss: 2649642500096.0000 - mean_absolute_percentage_error: 20.8702 - val_loss: 3139528556544.0000 - val_mean_absolute_percentage_error: 18.4990
# Epoch 123/3000
# 680/680 - 3s - 4ms/step - loss: 2649540788224.0000 - mean_absolute_percentage_error: 20.8816 - val_loss: 3187379535872.0000 - val_mean_absolute_percentage_error: 18.6283
# Epoch 124/3000
# 680/680 - 2s - 3ms/step - loss: 2649439600640.0000 - mean_absolute_percentage_error: 20.8597 - val_loss: 3135294144512.0000 - val_mean_absolute_percentage_error: 18.4873
# Epoch 125/3000
# 680/680 - 2s - 4ms/step - loss: 2649398444032.0000 - mean_absolute_percentage_error: 20.8748 - val_loss: 3139917840384.0000 - val_mean_absolute_percentage_error: 18.4910
# Epoch 126/3000
# 680/680 - 2s - 2ms/step - loss: 2649928761344.0000 - mean_absolute_percentage_error: 20.8709 - val_loss: 3108533960704.0000 - val_mean_absolute_percentage_error: 18.4023
# Epoch 127/3000
# 680/680 - 3s - 4ms/step - loss: 2648519475200.0000 - mean_absolute_percentage_error: 20.8726 - val_loss: 3166252826624.0000 - val_mean_absolute_percentage_error: 18.5551
# Epoch 128/3000
# 680/680 - 2s - 3ms/step - loss: 2649770426368.0000 - mean_absolute_percentage_error: 20.8540 - val_loss: 3076709941248.0000 - val_mean_absolute_percentage_error: 18.3235
# Epoch 129/3000
# 680/680 - 3s - 4ms/step - loss: 2649410240512.0000 - mean_absolute_percentage_error: 20.8725 - val_loss: 3094462070784.0000 - val_mean_absolute_percentage_error: 18.3754
# Epoch 130/3000
# 680/680 - 2s - 3ms/step - loss: 2649446416384.0000 - mean_absolute_percentage_error: 20.8746 - val_loss: 3085053198336.0000 - val_mean_absolute_percentage_error: 18.3553
# Epoch 131/3000
# 680/680 - 2s - 4ms/step - loss: 2649104318464.0000 - mean_absolute_percentage_error: 20.8703 - val_loss: 3066350796800.0000 - val_mean_absolute_percentage_error: 18.3003
# Epoch 132/3000
# 680/680 - 3s - 4ms/step - loss: 2648790794240.0000 - mean_absolute_percentage_error: 20.8708 - val_loss: 3070779195392.0000 - val_mean_absolute_percentage_error: 18.3209
# Epoch 133/3000
# 680/680 - 1s - 2ms/step - loss: 2648885952512.0000 - mean_absolute_percentage_error: 20.8657 - val_loss: 3056040935424.0000 - val_mean_absolute_percentage_error: 18.2843
# Epoch 134/3000
# 680/680 - 2s - 2ms/step - loss: 2649038520320.0000 - mean_absolute_percentage_error: 20.8726 - val_loss: 3069197680640.0000 - val_mean_absolute_percentage_error: 18.3050
# Epoch 135/3000
# 680/680 - 3s - 5ms/step - loss: 2649260294144.0000 - mean_absolute_percentage_error: 20.8798 - val_loss: 3093829779456.0000 - val_mean_absolute_percentage_error: 18.3798
# Epoch 136/3000
# 680/680 - 2s - 2ms/step - loss: 2648385781760.0000 - mean_absolute_percentage_error: 20.8665 - val_loss: 3088618356736.0000 - val_mean_absolute_percentage_error: 18.3684
# Epoch 137/3000
# 680/680 - 3s - 4ms/step - loss: 2648903778304.0000 - mean_absolute_percentage_error: 20.8774 - val_loss: 3093292122112.0000 - val_mean_absolute_percentage_error: 18.3789
# Epoch 138/3000
# 680/680 - 3s - 4ms/step - loss: 2648383422464.0000 - mean_absolute_percentage_error: 20.8511 - val_loss: 3063935926272.0000 - val_mean_absolute_percentage_error: 18.3118
# Epoch 139/3000
# 680/680 - 2s - 2ms/step - loss: 2648192057344.0000 - mean_absolute_percentage_error: 20.8742 - val_loss: 3079721451520.0000 - val_mean_absolute_percentage_error: 18.3403
# Epoch 140/3000
# 680/680 - 3s - 4ms/step - loss: 2648833261568.0000 - mean_absolute_percentage_error: 20.8688 - val_loss: 3045999771648.0000 - val_mean_absolute_percentage_error: 18.2502
# Epoch 141/3000
# 680/680 - 3s - 4ms/step - loss: 2648718704640.0000 - mean_absolute_percentage_error: 20.8748 - val_loss: 3082372775936.0000 - val_mean_absolute_percentage_error: 18.3368
# Epoch 142/3000
# 680/680 - 2s - 2ms/step - loss: 2648754880512.0000 - mean_absolute_percentage_error: 20.8575 - val_loss: 3100144041984.0000 - val_mean_absolute_percentage_error: 18.3909
# Epoch 143/3000
# 680/680 - 3s - 4ms/step - loss: 2648619089920.0000 - mean_absolute_percentage_error: 20.8764 - val_loss: 3077458100224.0000 - val_mean_absolute_percentage_error: 18.3344
# Epoch 144/3000
# 680/680 - 3s - 4ms/step - loss: 2648569544704.0000 - mean_absolute_percentage_error: 20.8656 - val_loss: 3080963227648.0000 - val_mean_absolute_percentage_error: 18.3490
# Epoch 145/3000
# 680/680 - 2s - 2ms/step - loss: 2648316313600.0000 - mean_absolute_percentage_error: 20.8569 - val_loss: 2980354457600.0000 - val_mean_absolute_percentage_error: 18.0844
# Epoch 146/3000
# 680/680 - 3s - 4ms/step - loss: 2648400461824.0000 - mean_absolute_percentage_error: 20.8935 - val_loss: 3185661181952.0000 - val_mean_absolute_percentage_error: 18.6095
# Epoch 147/3000
# 680/680 - 2s - 4ms/step - loss: 2648438210560.0000 - mean_absolute_percentage_error: 20.8715 - val_loss: 3165875339264.0000 - val_mean_absolute_percentage_error: 18.5521
# Epoch 148/3000
# 680/680 - 2s - 3ms/step - loss: 2648296914944.0000 - mean_absolute_percentage_error: 20.8502 - val_loss: 3081619636224.0000 - val_mean_absolute_percentage_error: 18.3541
# Epoch 149/3000
# 680/680 - 2s - 4ms/step - loss: 2647599611904.0000 - mean_absolute_percentage_error: 20.8800 - val_loss: 3138383249408.0000 - val_mean_absolute_percentage_error: 18.4782
# Epoch 150/3000
# 680/680 - 3s - 4ms/step - loss: 2647947214848.0000 - mean_absolute_percentage_error: 20.8598 - val_loss: 3137191280640.0000 - val_mean_absolute_percentage_error: 18.4898
# Epoch 151/3000
# 680/680 - 2s - 2ms/step - loss: 2648228495360.0000 - mean_absolute_percentage_error: 20.8721 - val_loss: 3140832722944.0000 - val_mean_absolute_percentage_error: 18.4888
# Epoch 152/3000
# 680/680 - 3s - 4ms/step - loss: 2647617961984.0000 - mean_absolute_percentage_error: 20.8545 - val_loss: 3071560384512.0000 - val_mean_absolute_percentage_error: 18.3112
# Epoch 153/3000
# 680/680 - 2s - 3ms/step - loss: 2647641030656.0000 - mean_absolute_percentage_error: 20.8565 - val_loss: 3046110920704.0000 - val_mean_absolute_percentage_error: 18.2538
# Epoch 154/3000
# 680/680 - 3s - 4ms/step - loss: 2647873552384.0000 - mean_absolute_percentage_error: 20.8917 - val_loss: 3171406839808.0000 - val_mean_absolute_percentage_error: 18.5808
# Epoch 155/3000
# 680/680 - 2s - 4ms/step - loss: 2647896621056.0000 - mean_absolute_percentage_error: 20.8584 - val_loss: 3088672096256.0000 - val_mean_absolute_percentage_error: 18.3642
# Epoch 156/3000
# 680/680 - 3s - 4ms/step - loss: 2647802511360.0000 - mean_absolute_percentage_error: 20.8535 - val_loss: 3089570988032.0000 - val_mean_absolute_percentage_error: 18.3625
# Epoch 157/3000
# 680/680 - 3s - 5ms/step - loss: 2647073226752.0000 - mean_absolute_percentage_error: 20.8625 - val_loss: 3062343663616.0000 - val_mean_absolute_percentage_error: 18.3024
# Epoch 158/3000
# 680/680 - 2s - 3ms/step - loss: 2647577329664.0000 - mean_absolute_percentage_error: 20.8678 - val_loss: 3119051440128.0000 - val_mean_absolute_percentage_error: 18.4343
# Epoch 159/3000
# 680/680 - 2s - 3ms/step - loss: 2647426334720.0000 - mean_absolute_percentage_error: 20.8719 - val_loss: 3146933862400.0000 - val_mean_absolute_percentage_error: 18.5182
# Epoch 160/3000
# 680/680 - 1s - 2ms/step - loss: 2647742742528.0000 - mean_absolute_percentage_error: 20.8596 - val_loss: 3080527020032.0000 - val_mean_absolute_percentage_error: 18.3425
# Epoch 161/3000
# 680/680 - 3s - 4ms/step - loss: 2647735140352.0000 - mean_absolute_percentage_error: 20.8649 - val_loss: 3095075487744.0000 - val_mean_absolute_percentage_error: 18.3738
# Epoch 162/3000
# 680/680 - 2s - 2ms/step - loss: 2647770267648.0000 - mean_absolute_percentage_error: 20.8688 - val_loss: 3126443900928.0000 - val_mean_absolute_percentage_error: 18.4591
# Epoch 163/3000
# 680/680 - 3s - 4ms/step - loss: 2647708401664.0000 - mean_absolute_percentage_error: 20.8607 - val_loss: 3097041305600.0000 - val_mean_absolute_percentage_error: 18.3851
# Epoch 164/3000
# 680/680 - 2s - 3ms/step - loss: 2647754276864.0000 - mean_absolute_percentage_error: 20.8613 - val_loss: 3050904485888.0000 - val_mean_absolute_percentage_error: 18.2631
# Epoch 165/3000
# 680/680 - 2s - 3ms/step - loss: 2647697653760.0000 - mean_absolute_percentage_error: 20.8817 - val_loss: 3129585958912.0000 - val_mean_absolute_percentage_error: 18.4687
# Epoch 166/3000
# 680/680 - 3s - 4ms/step - loss: 2647523590144.0000 - mean_absolute_percentage_error: 20.8599 - val_loss: 3070228168704.0000 - val_mean_absolute_percentage_error: 18.3098
# Epoch 167/3000
# 680/680 - 3s - 4ms/step - loss: 2647856513024.0000 - mean_absolute_percentage_error: 20.8792 - val_loss: 3142690537472.0000 - val_mean_absolute_percentage_error: 18.5006
# Epoch 168/3000
# 680/680 - 3s - 4ms/step - loss: 2647433936896.0000 - mean_absolute_percentage_error: 20.8667 - val_loss: 3178027024384.0000 - val_mean_absolute_percentage_error: 18.5959
# Epoch 169/3000
# 680/680 - 2s - 3ms/step - loss: 2647290544128.0000 - mean_absolute_percentage_error: 20.8415 - val_loss: 3041905606656.0000 - val_mean_absolute_percentage_error: 18.2424
# Epoch 170/3000
# 680/680 - 2s - 3ms/step - loss: 2647553736704.0000 - mean_absolute_percentage_error: 20.8799 - val_loss: 3080921022464.0000 - val_mean_absolute_percentage_error: 18.3361
# Epoch 171/3000
# 680/680 - 2s - 3ms/step - loss: 2647181754368.0000 - mean_absolute_percentage_error: 20.8692 - val_loss: 3077915541504.0000 - val_mean_absolute_percentage_error: 18.3215
# Epoch 172/3000
# 680/680 - 3s - 4ms/step - loss: 2647250173952.0000 - mean_absolute_percentage_error: 20.8468 - val_loss: 3043026272256.0000 - val_mean_absolute_percentage_error: 18.2461
# Epoch 173/3000
# 680/680 - 3s - 4ms/step - loss: 2647404576768.0000 - mean_absolute_percentage_error: 20.8756 - val_loss: 3098406027264.0000 - val_mean_absolute_percentage_error: 18.3881
# Epoch 174/3000
# 680/680 - 2s - 4ms/step - loss: 2647099441152.0000 - mean_absolute_percentage_error: 20.8594 - val_loss: 3111298793472.0000 - val_mean_absolute_percentage_error: 18.4111
# Epoch 175/3000
# 680/680 - 3s - 5ms/step - loss: 2647157637120.0000 - mean_absolute_percentage_error: 20.8541 - val_loss: 3062332653568.0000 - val_mean_absolute_percentage_error: 18.2906
# Epoch 176/3000
# 680/680 - 2s - 3ms/step - loss: 2647046225920.0000 - mean_absolute_percentage_error: 20.8752 - val_loss: 3093501313024.0000 - val_mean_absolute_percentage_error: 18.3689
# Epoch 177/3000
# 680/680 - 3s - 4ms/step - loss: 2647303913472.0000 - mean_absolute_percentage_error: 20.8671 - val_loss: 3093844197376.0000 - val_mean_absolute_percentage_error: 18.3771
# Epoch 178/3000
# 680/680 - 3s - 4ms/step - loss: 2647024205824.0000 - mean_absolute_percentage_error: 20.8511 - val_loss: 3046336364544.0000 - val_mean_absolute_percentage_error: 18.2531
# Epoch 179/3000
# 680/680 - 3s - 4ms/step - loss: 2646788800512.0000 - mean_absolute_percentage_error: 20.8965 - val_loss: 3164221997056.0000 - val_mean_absolute_percentage_error: 18.5491
# Epoch 180/3000
# 680/680 - 3s - 5ms/step - loss: 2647015292928.0000 - mean_absolute_percentage_error: 20.8611 - val_loss: 3159436034048.0000 - val_mean_absolute_percentage_error: 18.5369
# Epoch 181/3000
# 680/680 - 2s - 3ms/step - loss: 2646934552576.0000 - mean_absolute_percentage_error: 20.8533 - val_loss: 3141004427264.0000 - val_mean_absolute_percentage_error: 18.4938
# Epoch 182/3000
# 680/680 - 2s - 4ms/step - loss: 2646622863360.0000 - mean_absolute_percentage_error: 20.8655 - val_loss: 3123805159424.0000 - val_mean_absolute_percentage_error: 18.4458
# Epoch 183/3000
# 680/680 - 1s - 2ms/step - loss: 2646727983104.0000 - mean_absolute_percentage_error: 20.8519 - val_loss: 3055497248768.0000 - val_mean_absolute_percentage_error: 18.2631
# Epoch 184/3000
# 680/680 - 3s - 4ms/step - loss: 2646692331520.0000 - mean_absolute_percentage_error: 20.8669 - val_loss: 3106568142848.0000 - val_mean_absolute_percentage_error: 18.4004
# Epoch 185/3000
# 680/680 - 2s - 2ms/step - loss: 2646659039232.0000 - mean_absolute_percentage_error: 20.8710 - val_loss: 3151284928512.0000 - val_mean_absolute_percentage_error: 18.5165
# Epoch 186/3000
# 680/680 - 3s - 5ms/step - loss: 2646833364992.0000 - mean_absolute_percentage_error: 20.8556 - val_loss: 3125997469696.0000 - val_mean_absolute_percentage_error: 18.4583
# Epoch 187/3000
# 680/680 - 2s - 2ms/step - loss: 2646274473984.0000 - mean_absolute_percentage_error: 20.8675 - val_loss: 3126288711680.0000 - val_mean_absolute_percentage_error: 18.4534
# Epoch 188/3000
# 680/680 - 3s - 4ms/step - loss: 2646503849984.0000 - mean_absolute_percentage_error: 20.8509 - val_loss: 3059723010048.0000 - val_mean_absolute_percentage_error: 18.2858
# Epoch 189/3000
# 680/680 - 2s - 2ms/step - loss: 2646170140672.0000 - mean_absolute_percentage_error: 20.8498 - val_loss: 3015282262016.0000 - val_mean_absolute_percentage_error: 18.1679
# Epoch 190/3000
# 680/680 - 3s - 4ms/step - loss: 2646019670016.0000 - mean_absolute_percentage_error: 20.8759 - val_loss: 3136409829376.0000 - val_mean_absolute_percentage_error: 18.4796
# Epoch 191/3000
# 680/680 - 3s - 4ms/step - loss: 2645993193472.0000 - mean_absolute_percentage_error: 20.8481 - val_loss: 3105730854912.0000 - val_mean_absolute_percentage_error: 18.4135
# Epoch 192/3000
# 680/680 - 3s - 5ms/step - loss: 2646337650688.0000 - mean_absolute_percentage_error: 20.8737 - val_loss: 3069442785280.0000 - val_mean_absolute_percentage_error: 18.3039
# Epoch 193/3000
# 680/680 - 2s - 3ms/step - loss: 2645425913856.0000 - mean_absolute_percentage_error: 20.8467 - val_loss: 3067681964032.0000 - val_mean_absolute_percentage_error: 18.3098
# Epoch 194/3000
# 680/680 - 3s - 4ms/step - loss: 2646149955584.0000 - mean_absolute_percentage_error: 20.8790 - val_loss: 3099751350272.0000 - val_mean_absolute_percentage_error: 18.3951
# Epoch 195/3000
# 680/680 - 3s - 4ms/step - loss: 2645936832512.0000 - mean_absolute_percentage_error: 20.8627 - val_loss: 3132408201216.0000 - val_mean_absolute_percentage_error: 18.4711
# Epoch 196/3000
# 680/680 - 3s - 4ms/step - loss: 2645857927168.0000 - mean_absolute_percentage_error: 20.8587 - val_loss: 3140916346880.0000 - val_mean_absolute_percentage_error: 18.5035
# Epoch 197/3000
# 680/680 - 3s - 5ms/step - loss: 2646094118912.0000 - mean_absolute_percentage_error: 20.8564 - val_loss: 3065159090176.0000 - val_mean_absolute_percentage_error: 18.2979
# Epoch 198/3000
# 680/680 - 2s - 2ms/step - loss: 2645797634048.0000 - mean_absolute_percentage_error: 20.8522 - val_loss: 3037199335424.0000 - val_mean_absolute_percentage_error: 18.2288
# Epoch 199/3000
# 680/680 - 3s - 4ms/step - loss: 2645634580480.0000 - mean_absolute_percentage_error: 20.8681 - val_loss: 3109303615488.0000 - val_mean_absolute_percentage_error: 18.4051
# Epoch 200/3000
# 680/680 - 3s - 4ms/step - loss: 2645773778944.0000 - mean_absolute_percentage_error: 20.8503 - val_loss: 3081505603584.0000 - val_mean_absolute_percentage_error: 18.3492
# Epoch 201/3000
# 680/680 - 3s - 4ms/step - loss: 2645850062848.0000 - mean_absolute_percentage_error: 20.8729 - val_loss: 3102816337920.0000 - val_mean_absolute_percentage_error: 18.3902
# Epoch 202/3000
# 680/680 - 3s - 5ms/step - loss: 2645374271488.0000 - mean_absolute_percentage_error: 20.8622 - val_loss: 3164864249856.0000 - val_mean_absolute_percentage_error: 18.5522
# Epoch 203/3000
# 680/680 - 2s - 3ms/step - loss: 2645358280704.0000 - mean_absolute_percentage_error: 20.8571 - val_loss: 3116917850112.0000 - val_mean_absolute_percentage_error: 18.4292
# Epoch 204/3000
# 680/680 - 2s - 3ms/step - loss: 2645459468288.0000 - mean_absolute_percentage_error: 20.8495 - val_loss: 3109501534208.0000 - val_mean_absolute_percentage_error: 18.4154
# Epoch 205/3000
# 680/680 - 3s - 4ms/step - loss: 2645291171840.0000 - mean_absolute_percentage_error: 20.8521 - val_loss: 3053471662080.0000 - val_mean_absolute_percentage_error: 18.2664
# Epoch 206/3000
# 680/680 - 2s - 4ms/step - loss: 2644875673600.0000 - mean_absolute_percentage_error: 20.8571 - val_loss: 3083249123328.0000 - val_mean_absolute_percentage_error: 18.3577
# Epoch 207/3000
# 680/680 - 2s - 3ms/step - loss: 2645372174336.0000 - mean_absolute_percentage_error: 20.8603 - val_loss: 3066612678656.0000 - val_mean_absolute_percentage_error: 18.3000
# Epoch 208/3000
# 680/680 - 3s - 4ms/step - loss: 2645240053760.0000 - mean_absolute_percentage_error: 20.8635 - val_loss: 3121580867584.0000 - val_mean_absolute_percentage_error: 18.4416
# Epoch 209/3000
# 680/680 - 2s - 2ms/step - loss: 2644816429056.0000 - mean_absolute_percentage_error: 20.8368 - val_loss: 3007831867392.0000 - val_mean_absolute_percentage_error: 18.1494
# Epoch 210/3000
# 680/680 - 3s - 4ms/step - loss: 2645506916352.0000 - mean_absolute_percentage_error: 20.8830 - val_loss: 3129521733632.0000 - val_mean_absolute_percentage_error: 18.4645
# Epoch 211/3000
# 680/680 - 2s - 2ms/step - loss: 2645152497664.0000 - mean_absolute_percentage_error: 20.8572 - val_loss: 3126449143808.0000 - val_mean_absolute_percentage_error: 18.4483
# Epoch 212/3000
# 680/680 - 3s - 4ms/step - loss: 2645665775616.0000 - mean_absolute_percentage_error: 20.8600 - val_loss: 3099653570560.0000 - val_mean_absolute_percentage_error: 18.3791
# Epoch 213/3000
# 680/680 - 3s - 4ms/step - loss: 2645207547904.0000 - mean_absolute_percentage_error: 20.8561 - val_loss: 3136321748992.0000 - val_mean_absolute_percentage_error: 18.4862
# Epoch 214/3000
# 680/680 - 3s - 4ms/step - loss: 2645294579712.0000 - mean_absolute_percentage_error: 20.8508 - val_loss: 3045408636928.0000 - val_mean_absolute_percentage_error: 18.2453
# Epoch 215/3000
# 680/680 - 2s - 3ms/step - loss: 2645245034496.0000 - mean_absolute_percentage_error: 20.8655 - val_loss: 3088187916288.0000 - val_mean_absolute_percentage_error: 18.3537
# Epoch 216/3000
# 680/680 - 3s - 4ms/step - loss: 2645005959168.0000 - mean_absolute_percentage_error: 20.8425 - val_loss: 3073691090944.0000 - val_mean_absolute_percentage_error: 18.3212
# Epoch 217/3000
# 680/680 - 3s - 4ms/step - loss: 2644681687040.0000 - mean_absolute_percentage_error: 20.8518 - val_loss: 3057612226560.0000 - val_mean_absolute_percentage_error: 18.2760
# Epoch 218/3000
# 680/680 - 3s - 4ms/step - loss: 2644679065600.0000 - mean_absolute_percentage_error: 20.8612 - val_loss: 3076361027584.0000 - val_mean_absolute_percentage_error: 18.3258
# Epoch 219/3000
# 680/680 - 3s - 4ms/step - loss: 2644910800896.0000 - mean_absolute_percentage_error: 20.8599 - val_loss: 3090160287744.0000 - val_mean_absolute_percentage_error: 18.3601
# Epoch 220/3000
# 680/680 - 2s - 3ms/step - loss: 2644524662784.0000 - mean_absolute_percentage_error: 20.8472 - val_loss: 3050429480960.0000 - val_mean_absolute_percentage_error: 18.2592
# Epoch 221/3000
# 680/680 - 3s - 4ms/step - loss: 2644854439936.0000 - mean_absolute_percentage_error: 20.8567 - val_loss: 3038989516800.0000 - val_mean_absolute_percentage_error: 18.2294
# Epoch 222/3000
# 680/680 - 1s - 2ms/step - loss: 2644585742336.0000 - mean_absolute_percentage_error: 20.8679 - val_loss: 3144521351168.0000 - val_mean_absolute_percentage_error: 18.5032
# Epoch 223/3000
# 680/680 - 1s - 2ms/step - loss: 2644399620096.0000 - mean_absolute_percentage_error: 20.8522 - val_loss: 3098368802816.0000 - val_mean_absolute_percentage_error: 18.3887
# Epoch 224/3000
# 680/680 - 3s - 4ms/step - loss: 2644486389760.0000 - mean_absolute_percentage_error: 20.8437 - val_loss: 3081818603520.0000 - val_mean_absolute_percentage_error: 18.3459
# Epoch 225/3000
# 680/680 - 3s - 4ms/step - loss: 2644446019584.0000 - mean_absolute_percentage_error: 20.8681 - val_loss: 3132630499328.0000 - val_mean_absolute_percentage_error: 18.4621
# Epoch 226/3000
# 680/680 - 2s - 3ms/step - loss: 2644318617600.0000 - mean_absolute_percentage_error: 20.8522 - val_loss: 3127836934144.0000 - val_mean_absolute_percentage_error: 18.4510
# Epoch 227/3000
# 680/680 - 3s - 4ms/step - loss: 2644686143488.0000 - mean_absolute_percentage_error: 20.8549 - val_loss: 3111985610752.0000 - val_mean_absolute_percentage_error: 18.4134
# Epoch 228/3000
# 680/680 - 3s - 4ms/step - loss: 2644479836160.0000 - mean_absolute_percentage_error: 20.8534 - val_loss: 3098876313600.0000 - val_mean_absolute_percentage_error: 18.3816
# Epoch 229/3000
# 680/680 - 1s - 2ms/step - loss: 2644175486976.0000 - mean_absolute_percentage_error: 20.8529 - val_loss: 3144946024448.0000 - val_mean_absolute_percentage_error: 18.4932
# Epoch 230/3000
# 680/680 - 2s - 2ms/step - loss: 2643844399104.0000 - mean_absolute_percentage_error: 20.8542 - val_loss: 3158853025792.0000 - val_mean_absolute_percentage_error: 18.5440
# Epoch 231/3000
# 680/680 - 3s - 4ms/step - loss: 2644218740736.0000 - mean_absolute_percentage_error: 20.8496 - val_loss: 3059506741248.0000 - val_mean_absolute_percentage_error: 18.2813
# Epoch 232/3000
# 680/680 - 2s - 3ms/step - loss: 2644013219840.0000 - mean_absolute_percentage_error: 20.8658 - val_loss: 3150425882624.0000 - val_mean_absolute_percentage_error: 18.5101
# Epoch 233/3000
# 680/680 - 3s - 4ms/step - loss: 2644553760768.0000 - mean_absolute_percentage_error: 20.8418 - val_loss: 3071189188608.0000 - val_mean_absolute_percentage_error: 18.3189
# Epoch 234/3000
# 680/680 - 2s - 2ms/step - loss: 2643951353856.0000 - mean_absolute_percentage_error: 20.8652 - val_loss: 3119257485312.0000 - val_mean_absolute_percentage_error: 18.4253
# Epoch 235/3000
# 680/680 - 2s - 2ms/step - loss: 2644264615936.0000 - mean_absolute_percentage_error: 20.8374 - val_loss: 3072971767808.0000 - val_mean_absolute_percentage_error: 18.3170
# Epoch 236/3000
# 680/680 - 1s - 2ms/step - loss: 2644258324480.0000 - mean_absolute_percentage_error: 20.8559 - val_loss: 3047175225344.0000 - val_mean_absolute_percentage_error: 18.2486
# Epoch 237/3000
# 680/680 - 2s - 3ms/step - loss: 2643989364736.0000 - mean_absolute_percentage_error: 20.8579 - val_loss: 3047601995776.0000 - val_mean_absolute_percentage_error: 18.2556
# Epoch 238/3000
# 680/680 - 3s - 4ms/step - loss: 2644169457664.0000 - mean_absolute_percentage_error: 20.8406 - val_loss: 3005933944832.0000 - val_mean_absolute_percentage_error: 18.1448
# Epoch 239/3000
# 680/680 - 2s - 3ms/step - loss: 2643630227456.0000 - mean_absolute_percentage_error: 20.8567 - val_loss: 3058180030464.0000 - val_mean_absolute_percentage_error: 18.2758
# Epoch 240/3000
# 680/680 - 3s - 4ms/step - loss: 2643949518848.0000 - mean_absolute_percentage_error: 20.8520 - val_loss: 3064614879232.0000 - val_mean_absolute_percentage_error: 18.2904
# Epoch 241/3000
# 680/680 - 3s - 4ms/step - loss: 2644597276672.0000 - mean_absolute_percentage_error: 20.8580 - val_loss: 3043793305600.0000 - val_mean_absolute_percentage_error: 18.2331
# Epoch 242/3000
# 680/680 - 3s - 4ms/step - loss: 2644130660352.0000 - mean_absolute_percentage_error: 20.8595 - val_loss: 3088345989120.0000 - val_mean_absolute_percentage_error: 18.3599
# Epoch 243/3000
# 680/680 - 3s - 4ms/step - loss: 2644507099136.0000 - mean_absolute_percentage_error: 20.8500 - val_loss: 3071474925568.0000 - val_mean_absolute_percentage_error: 18.3129
# Epoch 244/3000
# 680/680 - 2s - 2ms/step - loss: 2643619741696.0000 - mean_absolute_percentage_error: 20.8515 - val_loss: 3074196766720.0000 - val_mean_absolute_percentage_error: 18.3211
# Epoch 245/3000
# 680/680 - 3s - 4ms/step - loss: 2644124631040.0000 - mean_absolute_percentage_error: 20.8615 - val_loss: 3090462801920.0000 - val_mean_absolute_percentage_error: 18.3574
# Epoch 246/3000
# 680/680 - 2s - 4ms/step - loss: 2644059357184.0000 - mean_absolute_percentage_error: 20.8598 - val_loss: 3095483121664.0000 - val_mean_absolute_percentage_error: 18.3697
# Epoch 247/3000
# 680/680 - 2s - 2ms/step - loss: 2643922518016.0000 - mean_absolute_percentage_error: 20.8342 - val_loss: 3043056943104.0000 - val_mean_absolute_percentage_error: 18.2348
# Epoch 248/3000
# 680/680 - 3s - 4ms/step - loss: 2644037074944.0000 - mean_absolute_percentage_error: 20.8626 - val_loss: 3073226833920.0000 - val_mean_absolute_percentage_error: 18.3084
# Epoch 249/3000
# 680/680 - 3s - 4ms/step - loss: 2643057442816.0000 - mean_absolute_percentage_error: 20.8415 - val_loss: 3031857889280.0000 - val_mean_absolute_percentage_error: 18.2039
# Epoch 250/3000
# 680/680 - 2s - 3ms/step - loss: 2644339589120.0000 - mean_absolute_percentage_error: 20.8648 - val_loss: 3096857542656.0000 - val_mean_absolute_percentage_error: 18.3737
# Epoch 251/3000
# 680/680 - 3s - 4ms/step - loss: 2643414220800.0000 - mean_absolute_percentage_error: 20.8497 - val_loss: 3058559877120.0000 - val_mean_absolute_percentage_error: 18.2685
# Epoch 252/3000
# 680/680 - 2s - 4ms/step - loss: 2643306217472.0000 - mean_absolute_percentage_error: 20.8540 - val_loss: 3121939480576.0000 - val_mean_absolute_percentage_error: 18.4341
# Epoch 253/3000
# 680/680 - 3s - 4ms/step - loss: 2643929071616.0000 - mean_absolute_percentage_error: 20.8425 - val_loss: 3045573525504.0000 - val_mean_absolute_percentage_error: 18.2461
# Epoch 254/3000
# 680/680 - 3s - 4ms/step - loss: 2643360481280.0000 - mean_absolute_percentage_error: 20.8569 - val_loss: 3042472361984.0000 - val_mean_absolute_percentage_error: 18.2371
# Epoch 255/3000
# 680/680 - 2s - 3ms/step - loss: 2643492864000.0000 - mean_absolute_percentage_error: 20.8523 - val_loss: 3085530038272.0000 - val_mean_absolute_percentage_error: 18.3423
# Epoch 256/3000
# 680/680 - 3s - 4ms/step - loss: 2643543195648.0000 - mean_absolute_percentage_error: 20.8308 - val_loss: 2998844260352.0000 - val_mean_absolute_percentage_error: 18.1282
# Epoch 257/3000
# 680/680 - 3s - 4ms/step - loss: 2642625167360.0000 - mean_absolute_percentage_error: 20.8850 - val_loss: 3190491447296.0000 - val_mean_absolute_percentage_error: 18.6167
# Epoch 258/3000
# 680/680 - 3s - 4ms/step - loss: 2643581992960.0000 - mean_absolute_percentage_error: 20.8382 - val_loss: 3100377088000.0000 - val_mean_absolute_percentage_error: 18.3804
# Epoch 259/3000
# 680/680 - 3s - 5ms/step - loss: 2643408191488.0000 - mean_absolute_percentage_error: 20.8424 - val_loss: 3059736117248.0000 - val_mean_absolute_percentage_error: 18.2772
# Epoch 260/3000
# 680/680 - 2s - 2ms/step - loss: 2642967265280.0000 - mean_absolute_percentage_error: 20.8555 - val_loss: 3105563082752.0000 - val_mean_absolute_percentage_error: 18.3974
# ...
# Epoch 891/3000
# 680/680 - 3s - 4ms/step - loss: 2392698650624.0000 - mean_absolute_percentage_error: 19.7149 - val_loss: 3085306429440.0000 - val_mean_absolute_percentage_error: 18.5208
# Epoch 892/3000
# 680/680 - 2s - 4ms/step - loss: 2392091525120.0000 - mean_absolute_percentage_error: 19.7094 - val_loss: 3151001550848.0000 - val_mean_absolute_percentage_error: 18.6852
# Epoch 893/3000
# 680/680 - 2s - 2ms/step - loss: 2392431525888.0000 - mean_absolute_percentage_error: 19.6995 - val_loss: 3115665326080.0000 - val_mean_absolute_percentage_error: 18.5982
# Epoch 894/3000
# 680/680 - 2s - 4ms/step - loss: 2391547838464.0000 - mean_absolute_percentage_error: 19.6841 - val_loss: 3063184621568.0000 - val_mean_absolute_percentage_error: 18.4587
# Epoch 895/3000
# 680/680 - 1s - 2ms/step - loss: 2391829905408.0000 - mean_absolute_percentage_error: 19.7067 - val_loss: 3099858042880.0000 - val_mean_absolute_percentage_error: 18.5559
# Epoch 896/3000
# 680/680 - 2s - 2ms/step - loss: 2391576936448.0000 - mean_absolute_percentage_error: 19.6947 - val_loss: 3119073198080.0000 - val_mean_absolute_percentage_error: 18.6109
# Epoch 897/3000
# 680/680 - 2s - 4ms/step - loss: 2391144660992.0000 - mean_absolute_percentage_error: 19.6948 - val_loss: 3115867439104.0000 - val_mean_absolute_percentage_error: 18.6049
# Epoch 898/3000
# 680/680 - 2s - 3ms/step - loss: 2391314268160.0000 - mean_absolute_percentage_error: 19.7057 - val_loss: 3146746691584.0000 - val_mean_absolute_percentage_error: 18.6774
# Epoch 899/3000
# 680/680 - 2s - 3ms/step - loss: 2391274946560.0000 - mean_absolute_percentage_error: 19.6940 - val_loss: 3140954095616.0000 - val_mean_absolute_percentage_error: 18.6638
# Epoch 900/3000
# 680/680 - 2s - 2ms/step - loss: 2390479339520.0000 - mean_absolute_percentage_error: 19.6813 - val_loss: 3130784481280.0000 - val_mean_absolute_percentage_error: 18.6408
# Epoch 901/3000
# 680/680 - 1s - 2ms/step - loss: 2390604906496.0000 - mean_absolute_percentage_error: 19.6917 - val_loss: 3086131658752.0000 - val_mean_absolute_percentage_error: 18.5278
# Epoch 902/3000
# 680/680 - 3s - 4ms/step - loss: 2390527311872.0000 - mean_absolute_percentage_error: 19.6866 - val_loss: 3088669212672.0000 - val_mean_absolute_percentage_error: 18.5361
# Epoch 903/3000
# 680/680 - 2s - 2ms/step - loss: 2390207496192.0000 - mean_absolute_percentage_error: 19.6979 - val_loss: 3106592260096.0000 - val_mean_absolute_percentage_error: 18.5780
# Epoch 904/3000
# 680/680 - 3s - 4ms/step - loss: 2389612691456.0000 - mean_absolute_percentage_error: 19.6786 - val_loss: 3055066546176.0000 - val_mean_absolute_percentage_error: 18.4472
# Epoch 905/3000
# 680/680 - 3s - 4ms/step - loss: 2390193864704.0000 - mean_absolute_percentage_error: 19.6871 - val_loss: 3077330960384.0000 - val_mean_absolute_percentage_error: 18.5128
# Epoch 906/3000
# 680/680 - 2s - 2ms/step - loss: 2390211690496.0000 - mean_absolute_percentage_error: 19.6887 - val_loss: 3079286292480.0000 - val_mean_absolute_percentage_error: 18.5176
# Epoch 907/3000
# 680/680 - 3s - 4ms/step - loss: 2389653848064.0000 - mean_absolute_percentage_error: 19.6937 - val_loss: 3116494487552.0000 - val_mean_absolute_percentage_error: 18.6113
# Epoch 908/3000
# 680/680 - 3s - 4ms/step - loss: 2389680324608.0000 - mean_absolute_percentage_error: 19.6877 - val_loss: 3094427205632.0000 - val_mean_absolute_percentage_error: 18.5538
# Epoch 909/3000
# 680/680 - 2s - 2ms/step - loss: 2388999536640.0000 - mean_absolute_percentage_error: 19.6783 - val_loss: 3072018612224.0000 - val_mean_absolute_percentage_error: 18.4962
# Epoch 910/3000
# 680/680 - 2s - 2ms/step - loss: 2389225504768.0000 - mean_absolute_percentage_error: 19.6854 - val_loss: 3085778288640.0000 - val_mean_absolute_percentage_error: 18.5312
# Epoch 911/3000
# 680/680 - 2s - 3ms/step - loss: 2389060354048.0000 - mean_absolute_percentage_error: 19.6947 - val_loss: 3109316984832.0000 - val_mean_absolute_percentage_error: 18.5923
# Epoch 912/3000
# 680/680 - 2s - 3ms/step - loss: 2388570406912.0000 - mean_absolute_percentage_error: 19.6821 - val_loss: 3128906743808.0000 - val_mean_absolute_percentage_error: 18.6371
# Epoch 913/3000
# 680/680 - 2s - 3ms/step - loss: 2388179812352.0000 - mean_absolute_percentage_error: 19.6801 - val_loss: 3147776393216.0000 - val_mean_absolute_percentage_error: 18.6839
# Epoch 914/3000
# 680/680 - 3s - 4ms/step - loss: 2388808695808.0000 - mean_absolute_percentage_error: 19.6756 - val_loss: 3119171239936.0000 - val_mean_absolute_percentage_error: 18.6189
# Epoch 915/3000
# 680/680 - 2s - 4ms/step - loss: 2388336050176.0000 - mean_absolute_percentage_error: 19.6781 - val_loss: 3075659792384.0000 - val_mean_absolute_percentage_error: 18.5055
# Epoch 916/3000
# 680/680 - 3s - 4ms/step - loss: 2388018593792.0000 - mean_absolute_percentage_error: 19.6981 - val_loss: 3147295883264.0000 - val_mean_absolute_percentage_error: 18.6906
# Epoch 917/3000
# 680/680 - 3s - 5ms/step - loss: 2388166180864.0000 - mean_absolute_percentage_error: 19.6718 - val_loss: 3097917652992.0000 - val_mean_absolute_percentage_error: 18.5648
# Epoch 918/3000
# 680/680 - 2s - 2ms/step - loss: 2387661291520.0000 - mean_absolute_percentage_error: 19.6724 - val_loss: 3070733582336.0000 - val_mean_absolute_percentage_error: 18.4948
# Epoch 919/3000
# 680/680 - 3s - 4ms/step - loss: 2387931561984.0000 - mean_absolute_percentage_error: 19.6825 - val_loss: 3113167093760.0000 - val_mean_absolute_percentage_error: 18.6032
# Epoch 920/3000
# 680/680 - 3s - 4ms/step - loss: 2388129480704.0000 - mean_absolute_percentage_error: 19.6807 - val_loss: 3108939497472.0000 - val_mean_absolute_percentage_error: 18.5974
# Epoch 921/3000
# 680/680 - 2s - 2ms/step - loss: 2387361660928.0000 - mean_absolute_percentage_error: 19.6768 - val_loss: 3115107221504.0000 - val_mean_absolute_percentage_error: 18.6137
# Epoch 922/3000
# 680/680 - 2s - 2ms/step - loss: 2386959532032.0000 - mean_absolute_percentage_error: 19.6716 - val_loss: 3076970774528.0000 - val_mean_absolute_percentage_error: 18.5113
# Epoch 923/3000
# 680/680 - 3s - 5ms/step - loss: 2386946424832.0000 - mean_absolute_percentage_error: 19.6750 - val_loss: 3048760410112.0000 - val_mean_absolute_percentage_error: 18.4429
# Epoch 924/3000
# 680/680 - 2s - 2ms/step - loss: 2386759516160.0000 - mean_absolute_percentage_error: 19.6688 - val_loss: 3038771412992.0000 - val_mean_absolute_percentage_error: 18.4204
# Epoch 925/3000
# 680/680 - 2s - 2ms/step - loss: 2386803294208.0000 - mean_absolute_percentage_error: 19.6822 - val_loss: 3094298230784.0000 - val_mean_absolute_percentage_error: 18.5570
# Epoch 926/3000
# 680/680 - 3s - 4ms/step - loss: 2386594627584.0000 - mean_absolute_percentage_error: 19.6725 - val_loss: 3087436349440.0000 - val_mean_absolute_percentage_error: 18.5460
# Epoch 927/3000
# 680/680 - 2s - 4ms/step - loss: 2386927288320.0000 - mean_absolute_percentage_error: 19.6748 - val_loss: 3085676052480.0000 - val_mean_absolute_percentage_error: 18.5354
# Epoch 928/3000
# 680/680 - 3s - 4ms/step - loss: 2386749554688.0000 - mean_absolute_percentage_error: 19.6785 - val_loss: 3106474557440.0000 - val_mean_absolute_percentage_error: 18.5895
# Epoch 929/3000
# 680/680 - 3s - 4ms/step - loss: 2385969938432.0000 - mean_absolute_percentage_error: 19.6703 - val_loss: 3143768997888.0000 - val_mean_absolute_percentage_error: 18.6877
# Epoch 930/3000
# 680/680 - 2s - 2ms/step - loss: 2386351882240.0000 - mean_absolute_percentage_error: 19.6618 - val_loss: 3097605439488.0000 - val_mean_absolute_percentage_error: 18.5686
# Epoch 931/3000
# 680/680 - 2s - 2ms/step - loss: 2385036181504.0000 - mean_absolute_percentage_error: 19.6783 - val_loss: 3135402409984.0000 - val_mean_absolute_percentage_error: 18.6668
# Epoch 932/3000
# 680/680 - 1s - 2ms/step - loss: 2385229643776.0000 - mean_absolute_percentage_error: 19.6536 - val_loss: 3063444144128.0000 - val_mean_absolute_percentage_error: 18.4859
# Epoch 933/3000
# 680/680 - 2s - 2ms/step - loss: 2385580130304.0000 - mean_absolute_percentage_error: 19.6761 - val_loss: 3116015288320.0000 - val_mean_absolute_percentage_error: 18.6163
# Epoch 934/3000
# 680/680 - 3s - 4ms/step - loss: 2385399250944.0000 - mean_absolute_percentage_error: 19.6624 - val_loss: 3087989997568.0000 - val_mean_absolute_percentage_error: 18.5469
# Epoch 935/3000
# 680/680 - 2s - 3ms/step - loss: 2385032511488.0000 - mean_absolute_percentage_error: 19.6778 - val_loss: 3127428513792.0000 - val_mean_absolute_percentage_error: 18.6412
# Epoch 936/3000
# 680/680 - 3s - 4ms/step - loss: 2385395843072.0000 - mean_absolute_percentage_error: 19.6540 - val_loss: 3081304276992.0000 - val_mean_absolute_percentage_error: 18.5222
# Epoch 937/3000
# 680/680 - 2s - 3ms/step - loss: 2385316151296.0000 - mean_absolute_percentage_error: 19.6770 - val_loss: 3123054379008.0000 - val_mean_absolute_percentage_error: 18.6370
# Epoch 938/3000
# 680/680 - 1s - 2ms/step - loss: 2385218633728.0000 - mean_absolute_percentage_error: 19.6530 - val_loss: 3069234380800.0000 - val_mean_absolute_percentage_error: 18.4951
# Epoch 939/3000
# 680/680 - 3s - 4ms/step - loss: 2384571138048.0000 - mean_absolute_percentage_error: 19.6756 - val_loss: 3118757052416.0000 - val_mean_absolute_percentage_error: 18.6262
# Epoch 940/3000
# 680/680 - 1s - 2ms/step - loss: 2384754114560.0000 - mean_absolute_percentage_error: 19.6587 - val_loss: 3118437498880.0000 - val_mean_absolute_percentage_error: 18.6252
# Epoch 941/3000
# 680/680 - 2s - 2ms/step - loss: 2384678617088.0000 - mean_absolute_percentage_error: 19.6614 - val_loss: 3100684582912.0000 - val_mean_absolute_percentage_error: 18.5791
# Epoch 942/3000
# 680/680 - 3s - 5ms/step - loss: 2384105046016.0000 - mean_absolute_percentage_error: 19.6693 - val_loss: 3128585879552.0000 - val_mean_absolute_percentage_error: 18.6479
# Epoch 943/3000
# 680/680 - 2s - 2ms/step - loss: 2384340189184.0000 - mean_absolute_percentage_error: 19.6660 - val_loss: 3097847922688.0000 - val_mean_absolute_percentage_error: 18.5686
# Epoch 944/3000
# 680/680 - 2s - 4ms/step - loss: 2383695314944.0000 - mean_absolute_percentage_error: 19.6556 - val_loss: 3123115982848.0000 - val_mean_absolute_percentage_error: 18.6353
# Epoch 945/3000
# 680/680 - 2s - 2ms/step - loss: 2383792046080.0000 - mean_absolute_percentage_error: 19.6615 - val_loss: 3120033693696.0000 - val_mean_absolute_percentage_error: 18.6299
# Epoch 946/3000
# 680/680 - 2s - 2ms/step - loss: 2383815376896.0000 - mean_absolute_percentage_error: 19.6539 - val_loss: 3091240583168.0000 - val_mean_absolute_percentage_error: 18.5522
# Epoch 947/3000
# 680/680 - 3s - 4ms/step - loss: 2383156871168.0000 - mean_absolute_percentage_error: 19.6566 - val_loss: 3073282670592.0000 - val_mean_absolute_percentage_error: 18.5087
# Epoch 948/3000
# 680/680 - 3s - 5ms/step - loss: 2384025616384.0000 - mean_absolute_percentage_error: 19.6657 - val_loss: 3135332679680.0000 - val_mean_absolute_percentage_error: 18.6669
# Epoch 949/3000
# 680/680 - 2s - 2ms/step - loss: 2382641233920.0000 - mean_absolute_percentage_error: 19.6499 - val_loss: 3114682023936.0000 - val_mean_absolute_percentage_error: 18.6135
# Epoch 950/3000
# 680/680 - 2s - 2ms/step - loss: 2383320973312.0000 - mean_absolute_percentage_error: 19.6623 - val_loss: 3144138883072.0000 - val_mean_absolute_percentage_error: 18.6893
# Epoch 951/3000
# 680/680 - 1s - 2ms/step - loss: 2382861172736.0000 - mean_absolute_percentage_error: 19.6580 - val_loss: 3162913636352.0000 - val_mean_absolute_percentage_error: 18.7397
# Epoch 952/3000
# 680/680 - 3s - 4ms/step - loss: 2382766014464.0000 - mean_absolute_percentage_error: 19.6594 - val_loss: 3207564361728.0000 - val_mean_absolute_percentage_error: 18.8618
# Epoch 953/3000
# 680/680 - 3s - 4ms/step - loss: 2383084257280.0000 - mean_absolute_percentage_error: 19.6448 - val_loss: 3114894884864.0000 - val_mean_absolute_percentage_error: 18.6238
# Epoch 954/3000
# 680/680 - 3s - 5ms/step - loss: 2382791704576.0000 - mean_absolute_percentage_error: 19.6543 - val_loss: 3111077281792.0000 - val_mean_absolute_percentage_error: 18.6102
# Epoch 955/3000
# 680/680 - 2s - 3ms/step - loss: 2382914650112.0000 - mean_absolute_percentage_error: 19.6570 - val_loss: 3107239755776.0000 - val_mean_absolute_percentage_error: 18.5959
# Epoch 956/3000
# 680/680 - 3s - 4ms/step - loss: 2382692352000.0000 - mean_absolute_percentage_error: 19.6470 - val_loss: 3101819928576.0000 - val_mean_absolute_percentage_error: 18.5884
# Epoch 957/3000
# 680/680 - 1s - 2ms/step - loss: 2382097547264.0000 - mean_absolute_percentage_error: 19.6576 - val_loss: 3043578609664.0000 - val_mean_absolute_percentage_error: 18.4377
# Epoch 958/3000
# 680/680 - 2s - 2ms/step - loss: 2382149451776.0000 - mean_absolute_percentage_error: 19.6618 - val_loss: 3167551225856.0000 - val_mean_absolute_percentage_error: 18.7635
# Epoch 959/3000
# 680/680 - 3s - 4ms/step - loss: 2382280523776.0000 - mean_absolute_percentage_error: 19.6487 - val_loss: 3137501134848.0000 - val_mean_absolute_percentage_error: 18.6728
# Epoch 960/3000
# 680/680 - 2s - 3ms/step - loss: 2381793460224.0000 - mean_absolute_percentage_error: 19.6594 - val_loss: 3153181278208.0000 - val_mean_absolute_percentage_error: 18.7188
# Epoch 961/3000
# 680/680 - 3s - 4ms/step - loss: 2381900677120.0000 - mean_absolute_percentage_error: 19.6375 - val_loss: 3094981115904.0000 - val_mean_absolute_percentage_error: 18.5707
# Epoch 962/3000
# 680/680 - 2s - 3ms/step - loss: 2380755894272.0000 - mean_absolute_percentage_error: 19.6677 - val_loss: 3226226130944.0000 - val_mean_absolute_percentage_error: 18.9067
# Epoch 963/3000
# 680/680 - 3s - 4ms/step - loss: 2381789790208.0000 - mean_absolute_percentage_error: 19.6312 - val_loss: 3112608727040.0000 - val_mean_absolute_percentage_error: 18.6162
# Epoch 964/3000
# 680/680 - 1s - 2ms/step - loss: 2380899811328.0000 - mean_absolute_percentage_error: 19.6406 - val_loss: 3062285729792.0000 - val_mean_absolute_percentage_error: 18.4881
# Epoch 965/3000
# 680/680 - 3s - 4ms/step - loss: 2381186072576.0000 - mean_absolute_percentage_error: 19.6617 - val_loss: 3130537803776.0000 - val_mean_absolute_percentage_error: 18.6608
# Epoch 966/3000
# 680/680 - 2s - 3ms/step - loss: 2381005979648.0000 - mean_absolute_percentage_error: 19.6555 - val_loss: 3148361760768.0000 - val_mean_absolute_percentage_error: 18.7053
# Epoch 967/3000
# 680/680 - 3s - 4ms/step - loss: 2380644745216.0000 - mean_absolute_percentage_error: 19.6435 - val_loss: 3145708077056.0000 - val_mean_absolute_percentage_error: 18.7000
# Epoch 968/3000
# 680/680 - 2s - 2ms/step - loss: 2380943327232.0000 - mean_absolute_percentage_error: 19.6486 - val_loss: 3169522810880.0000 - val_mean_absolute_percentage_error: 18.7634
# Epoch 969/3000
# 680/680 - 3s - 4ms/step - loss: 2380540936192.0000 - mean_absolute_percentage_error: 19.6366 - val_loss: 3128855363584.0000 - val_mean_absolute_percentage_error: 18.6603
# Epoch 970/3000
# 680/680 - 3s - 4ms/step - loss: 2380335415296.0000 - mean_absolute_percentage_error: 19.6500 - val_loss: 3160702189568.0000 - val_mean_absolute_percentage_error: 18.7365
# Epoch 971/3000
# 680/680 - 1s - 2ms/step - loss: 2379923587072.0000 - mean_absolute_percentage_error: 19.6348 - val_loss: 3087652356096.0000 - val_mean_absolute_percentage_error: 18.5486
# Epoch 972/3000
# 680/680 - 3s - 5ms/step - loss: 2379831574528.0000 - mean_absolute_percentage_error: 19.6539 - val_loss: 3195253030912.0000 - val_mean_absolute_percentage_error: 18.8333
# Epoch 973/3000
# 680/680 - 3s - 4ms/step - loss: 2380126486528.0000 - mean_absolute_percentage_error: 19.6379 - val_loss: 3105946599424.0000 - val_mean_absolute_percentage_error: 18.5993
# Epoch 974/3000
# 680/680 - 2s - 3ms/step - loss: 2379891343360.0000 - mean_absolute_percentage_error: 19.6517 - val_loss: 3184745775104.0000 - val_mean_absolute_percentage_error: 18.8019
# Epoch 975/3000
# 680/680 - 3s - 4ms/step - loss: 2379444387840.0000 - mean_absolute_percentage_error: 19.6494 - val_loss: 3189511815168.0000 - val_mean_absolute_percentage_error: 18.8117
# Epoch 976/3000
# 680/680 - 2s - 4ms/step - loss: 2379625267200.0000 - mean_absolute_percentage_error: 19.6307 - val_loss: 3147942330368.0000 - val_mean_absolute_percentage_error: 18.7149
# CPU times: user 30min 8s, sys: 1min 16s, total: 31min 25s
# Wall time: 37min 16s

# %%
new.save('model/model'+model_name+' '+str(data.columns.size-2)+'.keras')  # The file needs to end with the .keras extension
# uncomment to load
# new = tf.keras.models.load_model('model32-32-16 3.keras')
from sklearn.metrics import mean_squared_error
print(mean_squared_error(new.predict(X_train),y_train))
print(mean_squared_error(new.predict(X_val),y_val))
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2630553698304.0
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2966337093632.0

# %% [markdown]
# ### 2 Plots: mse loss and cross-validation loss

# %%
line1=plt.plot(history.history['loss'],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'],label='Validation Mean Squared Error')
plt.legend()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()
line1=plt.plot(history.history['loss'][100:],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'][100:],label='Validation Mean Squared Error')
plt.xticks( list(range(0,2000,200)), list(range(100,2000,200)))
list(range(len(line1)))
plt.legend()
plt.title('Loss after 100 epochs')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()

# %% [markdown]
# ### 3 Qualitative Plots

# %%
start_train=train_idx[0]
end_train=train_idx[15*24]
print(start_train)

start_val=val_idx[0]
end_val=val_idx[15*24]
print(start_val)

start_test=test_idx[45*24]
end_test=test_idx[45*24+15*24]
print(start_test)
# Out:
# 2018-08-02 04:00:00
# 2021-04-04 10:00:00
# 2021-11-16 17:00:00

# %%
y_train_prediction=new.predict(X_train)
y_val_prediction=new.predict(X_val)
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()

# %%
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas inflow", "predicted gas inflow"])

# %%
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas outflow", "predicted gas outflow"])

# %%
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

# %% [markdown]
# ## --

# %%
y_TEST_prediction=new.predict(X_test)

from sklearn.metrics import mean_absolute_percentage_error
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

mse_test_inflow=mean_squared_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mse_test_outflow=mean_squared_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse test inflow ',mse_test_inflow)
print('mse test outflow ',mse_test_outflow)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))

print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)

b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# mse_test:  3914797940736.0
# mse test inflow  3807094674229.8677
# mse test outflow  4022502095863.011
# mape_test:  0.193759486079216
# mape test inflow  0.17978856283150635
# mape test outflow  0.20773014985060528

# %%
X_total_train=np.append(X_train,values=X_val,axis=0)
y_total_train=np.append(y_train,values=y_val,axis=0)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error
regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_train_prediction=regressor.predict(X_train)
y_val_prediction=regressor.predict(X_val)
y_TEST_prediction=regressor.predict(X_test)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse_train: ',mean_squared_error(y_train,y_train_prediction))
print('mse_val: ',mean_squared_error(y_val,y_val_prediction))
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

print('mape_train: ',mean_absolute_percentage_error(y_train,y_train_prediction))
print('mape_val: ',mean_absolute_percentage_error(y_val,y_val_prediction))
print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))


print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)
## train
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Training data')
plt.show()
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Training data')
plt.show()
## val
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Validation data')
plt.show()

b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

## test
b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Test data')
plt.show()

# print('mape test inflow 2022 6 ',mean_absolute_percentage_error(y_test['2022-6-20':'2022-6']['sum(physicalFlow)0 inflow'],pd.DataFrame(y_TEST_prediction,index=test_idx)['2022-6-20':'2022-6'][0]))

# b['2022-6':'2022-6']['gas outflow'].plot()
# b['2022-6':'2022-6']['prediction gas outflow'].plot()
# plt.legend(["gas outflow", "predicted gas outflow"])
# plt.title('Test data')
# Out:
# mse_train:  2495186000199.182
# mse_val:  3283774487665.349
# mse_test:  3852757611181.9287
# mape_train:  0.20096472156614587
# mape_val:  0.1899900955017627
# mape_test:  0.18181033550773262
# mape test inflow  0.17604202406760325
# mape test outflow  0.1875786469478627
