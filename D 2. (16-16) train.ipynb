# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
from sklearn.metrics import mean_squared_error
# !pip install scikeras
# import scikeras

# %%
data=pd.read_csv('drive/MyDrive/Colab Notebooks/data.csv',delimiter=',',parse_dates=True,index_col=0)
# y=(data.iloc[:,-2]-data.iloc[:,-1])#.values
y=data.iloc[:,-2:]
X=data.iloc[:,:-2]#.values

# %%
y.std()
# Out:
# sum(physicalFlow)0 inflow     1.815534e+06
# sum(physicalFlow)1 outflow    2.205656e+06
# dtype: float64

# %%
y.mean()
# Out:
# sum(physicalFlow)0 inflow     7.223504e+06
# sum(physicalFlow)1 outflow    7.114683e+06
# dtype: float64

# %%
data
# Out:
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      sum(physicalFlow)0 inflow  sum(physicalFlow)1 outflow
# 2018-08-02 04:00:00                  5332486.0                   4084033.0
# 2018-08-02 05:00:00                  5425152.0                   4611564.0
# 2018-08-02 06:00:00                  5411656.0                   5204580.0
# 2018-08-02 07:00:00                  5792693.0                   5379787.0
# 2018-08-02 08:00:00                  5735920.0                   5706807.0
# ...                                        ...                         ...
# 2022-01-31 19:00:00                  7602602.0                  11077110.0
# 2022-01-31 20:00:00                  7418126.0                  10019737.0
# 2022-01-31 21:00:00                  7407216.0                   9476736.0
# 2022-01-31 22:00:00                  7398530.0                   8326807.0
# 2022-01-31 23:00:00                  7374867.0                   7325447.0
#
# [29001 rows x 5 columns]

# %% [markdown]
# # Feature engineering

# %%
f=lambda x: x.hour
ff=np.vectorize(f)
hour_of_day=ff(X.index.to_pydatetime())
X.loc[:, "hour"]=hour_of_day
X
# Out:
# <ipython-input-7-53c44885d1b3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, "hour"]=hour_of_day
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      hour
# 2018-08-02 04:00:00     4
# 2018-08-02 05:00:00     5
# 2018-08-02 06:00:00     6
# 2018-08-02 07:00:00     7
# 2018-08-02 08:00:00     8
# ...                   ...
# 2022-01-31 19:00:00    19
# 2022-01-31 20:00:00    20
# 2022-01-31 21:00:00    21
# 2022-01-31 22:00:00    22
# 2022-01-31 23:00:00    23
#
# [29001 rows x 4 columns]

# %% [markdown]
# # Split input data in 3 sets (train, validation, testing)

# %%
# https://datascience.stackexchange.com/questions/15135/train-test-validation-set-splitting-in-sklearn
from sklearn.model_selection import train_test_split

train_ratio = 0.75 # training
validation_ratio = 0.15 # hyperparameter tuning
test_ratio = 0.10 # final evaluation

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=test_ratio,shuffle=False, random_state=1234)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_ratio/(1-test_ratio),shuffle=False, random_state=1)

# print('train percent',X_train.index.size/X.index.size)
# print('validation percent',X_val.index.size/X.index.size)
# print('test percent',X_test.index.size/X.index.size)
print('train percent',y_train.index.size/X.index.size, '\ttrain days',y_train.index.size/24 )
print('validation percent',y_val.index.size/X.index.size,'\tvalid days',y_val.index.size/24)
print('test percent',y_test.index.size/X.index.size,'\ttest days',y_test.index.size/24)
# print('train percent',y_train.size/X.size, '\ttrain days',y_train.index.size/24 )
# Out:
# train percent 0.7499741388227992 	train days 906.25
# validation percent 0.14999482776455983 	valid days 181.25
# test percent 0.10003103341264094 	test days 120.875

# %%
train_idx=X_train.index
val_idx=X_val.index
test_idx=X_test.index
test_idx
# Out:
# DatetimeIndex(['2021-10-02 16:00:00', '2021-10-02 17:00:00',
#                '2021-10-02 18:00:00', '2021-10-02 19:00:00',
#                '2021-10-02 20:00:00', '2021-10-02 21:00:00',
#                '2021-10-02 22:00:00', '2021-10-02 23:00:00',
#                '2021-10-03 00:00:00', '2021-10-03 01:00:00',
#                ...
#                '2022-01-31 14:00:00', '2022-01-31 15:00:00',
#                '2022-01-31 16:00:00', '2022-01-31 17:00:00',
#                '2022-01-31 18:00:00', '2022-01-31 19:00:00',
#                '2022-01-31 20:00:00', '2022-01-31 21:00:00',
#                '2022-01-31 22:00:00', '2022-01-31 23:00:00'],
#               dtype='datetime64[ns]', length=2901, freq=None)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()


X_train=sc.fit_transform(X_train)
X_val=sc.transform(X_val)
X_test=sc.transform(X_test)

# %%
# from sklearn.utils import shuffle
# X_train_shuffled, y_train_shuffled = shuffle(X_train, y_train, random_state=42)

# %%
X_train
# Out:
# array([[-0.70473316, -0.44212536, -0.04271406, -1.08333581],
#        [-0.61317217,  0.11094688,  0.58407691, -0.93886447],
#        [-0.55823558,  0.79018873,  1.14383607, -0.79439312],
#        ...,
#        [ 1.11916167,  1.31215066, -0.59028562, -0.64992178],
#        [ 1.18142314,  1.83756929, -0.35001575, -0.50545043],
#        [ 1.18325436,  2.11756211, -0.22726918, -0.36097909]])

# %% [markdown]
# # Training neural networks

# %% [markdown]
# ## hidden layers: 16-16

# %% [markdown]
# ### 1 model creation + training process

# %%
# %%time
model_name='16-16'
def new_nn():
  ann=tf.keras.models.Sequential()
  ann.add(tf.keras.layers.Dense(units=16,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=16,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=2,activation='linear'))
  ann.compile(optimizer='adam',loss=tf.keras.losses.MeanSquaredError(),metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
  return ann

earlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',start_from_epoch=5, patience=2500,restore_best_weights=True)
modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath='{epoch:02d}-8-8-1.keras',save_freq='epoch')

new=new_nn()
history=new.fit(X_train,y_train,epochs=3000,validation_data=(X_val,y_val),callbacks=[earlyStop,modelCheckpoint],verbose=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 502/3000
# 680/680 - 2s - 2ms/step - loss: 2602644799488.0000 - mean_absolute_percentage_error: 20.6613 - val_loss: 3073229717504.0000 - val_mean_absolute_percentage_error: 18.2994
# Epoch 503/3000
# 680/680 - 3s - 4ms/step - loss: 2601822191616.0000 - mean_absolute_percentage_error: 20.6568 - val_loss: 3068101132288.0000 - val_mean_absolute_percentage_error: 18.2853
# Epoch 504/3000
# 680/680 - 3s - 4ms/step - loss: 2600892104704.0000 - mean_absolute_percentage_error: 20.6546 - val_loss: 3073381498880.0000 - val_mean_absolute_percentage_error: 18.2996
# Epoch 505/3000
# 680/680 - 3s - 4ms/step - loss: 2600034369536.0000 - mean_absolute_percentage_error: 20.6475 - val_loss: 3065261850624.0000 - val_mean_absolute_percentage_error: 18.2778
# Epoch 506/3000
# 680/680 - 2s - 3ms/step - loss: 2599082524672.0000 - mean_absolute_percentage_error: 20.6495 - val_loss: 3066311475200.0000 - val_mean_absolute_percentage_error: 18.2805
# Epoch 507/3000
# 680/680 - 2s - 3ms/step - loss: 2598157156352.0000 - mean_absolute_percentage_error: 20.6480 - val_loss: 3070588616704.0000 - val_mean_absolute_percentage_error: 18.2911
# Epoch 508/3000
# 680/680 - 3s - 4ms/step - loss: 2597238865920.0000 - mean_absolute_percentage_error: 20.6381 - val_loss: 3071210422272.0000 - val_mean_absolute_percentage_error: 18.2925
# Epoch 509/3000
# 680/680 - 3s - 4ms/step - loss: 2596318478336.0000 - mean_absolute_percentage_error: 20.6348 - val_loss: 3067457830912.0000 - val_mean_absolute_percentage_error: 18.2825
# Epoch 510/3000
# 680/680 - 3s - 4ms/step - loss: 2595366633472.0000 - mean_absolute_percentage_error: 20.6235 - val_loss: 3069821059072.0000 - val_mean_absolute_percentage_error: 18.2882
# Epoch 511/3000
# 680/680 - 3s - 4ms/step - loss: 2594423963648.0000 - mean_absolute_percentage_error: 20.6237 - val_loss: 3065548374016.0000 - val_mean_absolute_percentage_error: 18.2761
# Epoch 512/3000
# 680/680 - 2s - 3ms/step - loss: 2593486798848.0000 - mean_absolute_percentage_error: 20.6221 - val_loss: 3060668301312.0000 - val_mean_absolute_percentage_error: 18.2633
# Epoch 513/3000
# 680/680 - 2s - 2ms/step - loss: 2592465485824.0000 - mean_absolute_percentage_error: 20.6318 - val_loss: 3067916320768.0000 - val_mean_absolute_percentage_error: 18.2815
# Epoch 514/3000
# 680/680 - 2s - 2ms/step - loss: 2591500795904.0000 - mean_absolute_percentage_error: 20.6159 - val_loss: 3071625920512.0000 - val_mean_absolute_percentage_error: 18.2921
# Epoch 515/3000
# 680/680 - 3s - 4ms/step - loss: 2590587748352.0000 - mean_absolute_percentage_error: 20.5916 - val_loss: 3062149152768.0000 - val_mean_absolute_percentage_error: 18.2660
# Epoch 516/3000
# 680/680 - 3s - 4ms/step - loss: 2589556998144.0000 - mean_absolute_percentage_error: 20.6172 - val_loss: 3068404957184.0000 - val_mean_absolute_percentage_error: 18.2821
# Epoch 517/3000
# 680/680 - 3s - 5ms/step - loss: 2588640280576.0000 - mean_absolute_percentage_error: 20.5983 - val_loss: 3065871073280.0000 - val_mean_absolute_percentage_error: 18.2753
# Epoch 518/3000
# 680/680 - 2s - 3ms/step - loss: 2587663007744.0000 - mean_absolute_percentage_error: 20.5882 - val_loss: 3062822076416.0000 - val_mean_absolute_percentage_error: 18.2665
# Epoch 519/3000
# 680/680 - 2s - 2ms/step - loss: 2586628063232.0000 - mean_absolute_percentage_error: 20.6073 - val_loss: 3072680525824.0000 - val_mean_absolute_percentage_error: 18.2929
# Epoch 520/3000
# 680/680 - 3s - 4ms/step - loss: 2585660751872.0000 - mean_absolute_percentage_error: 20.5858 - val_loss: 3062573563904.0000 - val_mean_absolute_percentage_error: 18.2658
# Epoch 521/3000
# 680/680 - 2s - 4ms/step - loss: 2584701566976.0000 - mean_absolute_percentage_error: 20.5717 - val_loss: 3057495310336.0000 - val_mean_absolute_percentage_error: 18.2519
# Epoch 522/3000
# 680/680 - 3s - 5ms/step - loss: 2583673438208.0000 - mean_absolute_percentage_error: 20.5885 - val_loss: 3065363300352.0000 - val_mean_absolute_percentage_error: 18.2724
# Epoch 523/3000
# 680/680 - 2s - 4ms/step - loss: 2582677553152.0000 - mean_absolute_percentage_error: 20.5845 - val_loss: 3070806196224.0000 - val_mean_absolute_percentage_error: 18.2862
# Epoch 524/3000
# 680/680 - 2s - 3ms/step - loss: 2581675900928.0000 - mean_absolute_percentage_error: 20.5508 - val_loss: 3060540637184.0000 - val_mean_absolute_percentage_error: 18.2588
# Epoch 525/3000
# 680/680 - 2s - 4ms/step - loss: 2580613431296.0000 - mean_absolute_percentage_error: 20.5707 - val_loss: 3067632943104.0000 - val_mean_absolute_percentage_error: 18.2780
# Epoch 526/3000
# 680/680 - 3s - 4ms/step - loss: 2579557515264.0000 - mean_absolute_percentage_error: 20.5657 - val_loss: 3069335568384.0000 - val_mean_absolute_percentage_error: 18.2828
# Epoch 527/3000
# 680/680 - 1s - 2ms/step - loss: 2578580766720.0000 - mean_absolute_percentage_error: 20.5493 - val_loss: 3061707964416.0000 - val_mean_absolute_percentage_error: 18.2622
# Epoch 528/3000
# 680/680 - 3s - 5ms/step - loss: 2577487626240.0000 - mean_absolute_percentage_error: 20.5410 - val_loss: 3053844692992.0000 - val_mean_absolute_percentage_error: 18.2402
# Epoch 529/3000
# 680/680 - 2s - 3ms/step - loss: 2576399728640.0000 - mean_absolute_percentage_error: 20.5517 - val_loss: 3057852088320.0000 - val_mean_absolute_percentage_error: 18.2501
# Epoch 530/3000
# 680/680 - 1s - 2ms/step - loss: 2575396765696.0000 - mean_absolute_percentage_error: 20.5391 - val_loss: 3059585646592.0000 - val_mean_absolute_percentage_error: 18.2544
# Epoch 531/3000
# 680/680 - 2s - 2ms/step - loss: 2574336393216.0000 - mean_absolute_percentage_error: 20.5406 - val_loss: 3059697057792.0000 - val_mean_absolute_percentage_error: 18.2543
# Epoch 532/3000
# 680/680 - 1s - 2ms/step - loss: 2573290962944.0000 - mean_absolute_percentage_error: 20.5247 - val_loss: 3055907241984.0000 - val_mean_absolute_percentage_error: 18.2437
# Epoch 533/3000
# 680/680 - 3s - 4ms/step - loss: 2572217221120.0000 - mean_absolute_percentage_error: 20.5282 - val_loss: 3054620901376.0000 - val_mean_absolute_percentage_error: 18.2402
# Epoch 534/3000
# 680/680 - 2s - 2ms/step - loss: 2571217403904.0000 - mean_absolute_percentage_error: 20.5309 - val_loss: 3061147762688.0000 - val_mean_absolute_percentage_error: 18.2573
# Epoch 535/3000
# 680/680 - 3s - 4ms/step - loss: 2570105389056.0000 - mean_absolute_percentage_error: 20.5188 - val_loss: 3060592279552.0000 - val_mean_absolute_percentage_error: 18.2552
# Epoch 536/3000
# 680/680 - 2s - 3ms/step - loss: 2569021947904.0000 - mean_absolute_percentage_error: 20.5165 - val_loss: 3065177178112.0000 - val_mean_absolute_percentage_error: 18.2670
# Epoch 537/3000
# 680/680 - 2s - 3ms/step - loss: 2567977828352.0000 - mean_absolute_percentage_error: 20.4951 - val_loss: 3054286929920.0000 - val_mean_absolute_percentage_error: 18.2386
# Epoch 538/3000
# 680/680 - 3s - 4ms/step - loss: 2566922960896.0000 - mean_absolute_percentage_error: 20.5077 - val_loss: 3060564492288.0000 - val_mean_absolute_percentage_error: 18.2548
# Epoch 539/3000
# 680/680 - 2s - 4ms/step - loss: 2565861539840.0000 - mean_absolute_percentage_error: 20.4972 - val_loss: 3060205092864.0000 - val_mean_absolute_percentage_error: 18.2546
# Epoch 540/3000
# 680/680 - 3s - 4ms/step - loss: 2564767612928.0000 - mean_absolute_percentage_error: 20.4859 - val_loss: 3053237829632.0000 - val_mean_absolute_percentage_error: 18.2360
# Epoch 541/3000
# 680/680 - 3s - 4ms/step - loss: 2563739746304.0000 - mean_absolute_percentage_error: 20.4891 - val_loss: 3057834000384.0000 - val_mean_absolute_percentage_error: 18.2477
# Epoch 542/3000
# 680/680 - 2s - 3ms/step - loss: 2562666004480.0000 - mean_absolute_percentage_error: 20.4778 - val_loss: 3049226502144.0000 - val_mean_absolute_percentage_error: 18.2246
# Epoch 543/3000
# 680/680 - 2s - 2ms/step - loss: 2561636827136.0000 - mean_absolute_percentage_error: 20.4992 - val_loss: 3068632760320.0000 - val_mean_absolute_percentage_error: 18.2751
# Epoch 544/3000
# 680/680 - 1s - 2ms/step - loss: 2560560726016.0000 - mean_absolute_percentage_error: 20.4689 - val_loss: 3060959281152.0000 - val_mean_absolute_percentage_error: 18.2550
# Epoch 545/3000
# 680/680 - 3s - 4ms/step - loss: 2559492227072.0000 - mean_absolute_percentage_error: 20.4642 - val_loss: 3060022640640.0000 - val_mean_absolute_percentage_error: 18.2523
# Epoch 546/3000
# 680/680 - 1s - 2ms/step - loss: 2558463574016.0000 - mean_absolute_percentage_error: 20.4687 - val_loss: 3061806792704.0000 - val_mean_absolute_percentage_error: 18.2561
# Epoch 547/3000
# 680/680 - 2s - 3ms/step - loss: 2557359685632.0000 - mean_absolute_percentage_error: 20.4498 - val_loss: 3051580293120.0000 - val_mean_absolute_percentage_error: 18.2294
# Epoch 548/3000
# 680/680 - 2s - 4ms/step - loss: 2556327886848.0000 - mean_absolute_percentage_error: 20.4689 - val_loss: 3062285729792.0000 - val_mean_absolute_percentage_error: 18.2576
# Epoch 549/3000
# 680/680 - 2s - 2ms/step - loss: 2555245494272.0000 - mean_absolute_percentage_error: 20.4559 - val_loss: 3069403987968.0000 - val_mean_absolute_percentage_error: 18.2759
# Epoch 550/3000
# 680/680 - 2s - 2ms/step - loss: 2554268483584.0000 - mean_absolute_percentage_error: 20.4339 - val_loss: 3064525750272.0000 - val_mean_absolute_percentage_error: 18.2633
# Epoch 551/3000
# 680/680 - 2s - 4ms/step - loss: 2553192382464.0000 - mean_absolute_percentage_error: 20.4387 - val_loss: 3056665886720.0000 - val_mean_absolute_percentage_error: 18.2420
# Epoch 552/3000
# 680/680 - 2s - 2ms/step - loss: 2552140136448.0000 - mean_absolute_percentage_error: 20.4281 - val_loss: 3055607087104.0000 - val_mean_absolute_percentage_error: 18.2397
# Epoch 553/3000
# 680/680 - 2s - 4ms/step - loss: 2551089201152.0000 - mean_absolute_percentage_error: 20.4428 - val_loss: 3061706653696.0000 - val_mean_absolute_percentage_error: 18.2553
# Epoch 554/3000
# 680/680 - 3s - 5ms/step - loss: 2550085451776.0000 - mean_absolute_percentage_error: 20.4085 - val_loss: 3056433889280.0000 - val_mean_absolute_percentage_error: 18.2420
# Epoch 555/3000
# 680/680 - 2s - 2ms/step - loss: 2549041070080.0000 - mean_absolute_percentage_error: 20.4157 - val_loss: 3055322136576.0000 - val_mean_absolute_percentage_error: 18.2397
# Epoch 556/3000
# 680/680 - 2s - 2ms/step - loss: 2548001931264.0000 - mean_absolute_percentage_error: 20.4212 - val_loss: 3055158296576.0000 - val_mean_absolute_percentage_error: 18.2381
# Epoch 557/3000
# 680/680 - 3s - 4ms/step - loss: 2547011026944.0000 - mean_absolute_percentage_error: 20.4241 - val_loss: 3060647329792.0000 - val_mean_absolute_percentage_error: 18.2525
# Epoch 558/3000
# 680/680 - 3s - 4ms/step - loss: 2545937809408.0000 - mean_absolute_percentage_error: 20.3875 - val_loss: 3052428853248.0000 - val_mean_absolute_percentage_error: 18.2305
# Epoch 559/3000
# 680/680 - 3s - 4ms/step - loss: 2545018994688.0000 - mean_absolute_percentage_error: 20.4048 - val_loss: 3056948215808.0000 - val_mean_absolute_percentage_error: 18.2422
# Epoch 560/3000
# 680/680 - 3s - 4ms/step - loss: 2543990865920.0000 - mean_absolute_percentage_error: 20.4047 - val_loss: 3059919880192.0000 - val_mean_absolute_percentage_error: 18.2502
# Epoch 561/3000
# 680/680 - 2s - 3ms/step - loss: 2543005728768.0000 - mean_absolute_percentage_error: 20.3921 - val_loss: 3061251833856.0000 - val_mean_absolute_percentage_error: 18.2529
# Epoch 562/3000
# 680/680 - 2s - 4ms/step - loss: 2541973405696.0000 - mean_absolute_percentage_error: 20.3966 - val_loss: 3069840982016.0000 - val_mean_absolute_percentage_error: 18.2766
# Epoch 563/3000
# 680/680 - 1s - 2ms/step - loss: 2540994560000.0000 - mean_absolute_percentage_error: 20.3597 - val_loss: 3057123328000.0000 - val_mean_absolute_percentage_error: 18.2428
# Epoch 564/3000
# 680/680 - 2s - 2ms/step - loss: 2540104056832.0000 - mean_absolute_percentage_error: 20.3783 - val_loss: 3056394305536.0000 - val_mean_absolute_percentage_error: 18.2414
# Epoch 565/3000
# 680/680 - 3s - 4ms/step - loss: 2539112890368.0000 - mean_absolute_percentage_error: 20.3862 - val_loss: 3063154212864.0000 - val_mean_absolute_percentage_error: 18.2584
# Epoch 566/3000
# 680/680 - 3s - 4ms/step - loss: 2538196959232.0000 - mean_absolute_percentage_error: 20.3600 - val_loss: 3057536991232.0000 - val_mean_absolute_percentage_error: 18.2438
# Epoch 567/3000
# 680/680 - 2s - 3ms/step - loss: 2537310126080.0000 - mean_absolute_percentage_error: 20.3652 - val_loss: 3061639806976.0000 - val_mean_absolute_percentage_error: 18.2551
# Epoch 568/3000
# 680/680 - 1s - 2ms/step - loss: 2536368766976.0000 - mean_absolute_percentage_error: 20.3668 - val_loss: 3063649665024.0000 - val_mean_absolute_percentage_error: 18.2613
# Epoch 569/3000
# 680/680 - 1s - 2ms/step - loss: 2535432912896.0000 - mean_absolute_percentage_error: 20.3643 - val_loss: 3069998792704.0000 - val_mean_absolute_percentage_error: 18.2778
# Epoch 570/3000
# 680/680 - 1s - 2ms/step - loss: 2534585401344.0000 - mean_absolute_percentage_error: 20.3366 - val_loss: 3066901823488.0000 - val_mean_absolute_percentage_error: 18.2694
# Epoch 571/3000
# 680/680 - 2s - 4ms/step - loss: 2533731336192.0000 - mean_absolute_percentage_error: 20.3427 - val_loss: 3057371054080.0000 - val_mean_absolute_percentage_error: 18.2444
# Epoch 572/3000
# 680/680 - 2s - 2ms/step - loss: 2532850532352.0000 - mean_absolute_percentage_error: 20.3472 - val_loss: 3066746109952.0000 - val_mean_absolute_percentage_error: 18.2690
# Epoch 573/3000
# 680/680 - 3s - 4ms/step - loss: 2531967107072.0000 - mean_absolute_percentage_error: 20.3335 - val_loss: 3062639362048.0000 - val_mean_absolute_percentage_error: 18.2584
# Epoch 574/3000
# 680/680 - 2s - 3ms/step - loss: 2531104915456.0000 - mean_absolute_percentage_error: 20.3250 - val_loss: 3058434834432.0000 - val_mean_absolute_percentage_error: 18.2481
# Epoch 575/3000
# 680/680 - 2s - 2ms/step - loss: 2530318483456.0000 - mean_absolute_percentage_error: 20.3301 - val_loss: 3059997999104.0000 - val_mean_absolute_percentage_error: 18.2528
# Epoch 576/3000
# 680/680 - 3s - 4ms/step - loss: 2529508458496.0000 - mean_absolute_percentage_error: 20.3333 - val_loss: 3064649744384.0000 - val_mean_absolute_percentage_error: 18.2652
# Epoch 577/3000
# 680/680 - 2s - 2ms/step - loss: 2528654917632.0000 - mean_absolute_percentage_error: 20.3194 - val_loss: 3059555237888.0000 - val_mean_absolute_percentage_error: 18.2523
# Epoch 578/3000
# 680/680 - 3s - 4ms/step - loss: 2527849086976.0000 - mean_absolute_percentage_error: 20.3205 - val_loss: 3060107575296.0000 - val_mean_absolute_percentage_error: 18.2540
# Epoch 579/3000
# 680/680 - 3s - 4ms/step - loss: 2527069208576.0000 - mean_absolute_percentage_error: 20.3152 - val_loss: 3062370402304.0000 - val_mean_absolute_percentage_error: 18.2602
# Epoch 580/3000
# 680/680 - 2s - 3ms/step - loss: 2526235066368.0000 - mean_absolute_percentage_error: 20.3055 - val_loss: 3061921349632.0000 - val_mean_absolute_percentage_error: 18.2598
# Epoch 581/3000
# 680/680 - 3s - 4ms/step - loss: 2525488218112.0000 - mean_absolute_percentage_error: 20.3185 - val_loss: 3069012869120.0000 - val_mean_absolute_percentage_error: 18.2774
# Epoch 582/3000
# 680/680 - 1s - 2ms/step - loss: 2524753690624.0000 - mean_absolute_percentage_error: 20.2994 - val_loss: 3066879279104.0000 - val_mean_absolute_percentage_error: 18.2727
# Epoch 583/3000
# 680/680 - 2s - 2ms/step - loss: 2523954413568.0000 - mean_absolute_percentage_error: 20.2963 - val_loss: 3062945021952.0000 - val_mean_absolute_percentage_error: 18.2623
# Epoch 584/3000
# 680/680 - 3s - 4ms/step - loss: 2523227750400.0000 - mean_absolute_percentage_error: 20.2884 - val_loss: 3062023847936.0000 - val_mean_absolute_percentage_error: 18.2596
# Epoch 585/3000
# 680/680 - 3s - 5ms/step - loss: 2522466484224.0000 - mean_absolute_percentage_error: 20.3052 - val_loss: 3071380029440.0000 - val_mean_absolute_percentage_error: 18.2842
# Epoch 586/3000
# 680/680 - 1s - 2ms/step - loss: 2521736151040.0000 - mean_absolute_percentage_error: 20.2725 - val_loss: 3058618335232.0000 - val_mean_absolute_percentage_error: 18.2523
# Epoch 587/3000
# 680/680 - 2s - 2ms/step - loss: 2521004769280.0000 - mean_absolute_percentage_error: 20.3003 - val_loss: 3070270111744.0000 - val_mean_absolute_percentage_error: 18.2824
# Epoch 588/3000
# 680/680 - 3s - 4ms/step - loss: 2520328699904.0000 - mean_absolute_percentage_error: 20.2789 - val_loss: 3072042467328.0000 - val_mean_absolute_percentage_error: 18.2876
# Epoch 589/3000
# 680/680 - 3s - 4ms/step - loss: 2519669669888.0000 - mean_absolute_percentage_error: 20.2703 - val_loss: 3067512356864.0000 - val_mean_absolute_percentage_error: 18.2759
# Epoch 590/3000
# 680/680 - 3s - 5ms/step - loss: 2518963978240.0000 - mean_absolute_percentage_error: 20.2679 - val_loss: 3065188188160.0000 - val_mean_absolute_percentage_error: 18.2705
# Epoch 591/3000
# 680/680 - 3s - 4ms/step - loss: 2518248325120.0000 - mean_absolute_percentage_error: 20.2581 - val_loss: 3061275164672.0000 - val_mean_absolute_percentage_error: 18.2613
# Epoch 592/3000
# 680/680 - 2s - 2ms/step - loss: 2517662433280.0000 - mean_absolute_percentage_error: 20.2735 - val_loss: 3064949374976.0000 - val_mean_absolute_percentage_error: 18.2708
# Epoch 593/3000
# 680/680 - 3s - 4ms/step - loss: 2516984791040.0000 - mean_absolute_percentage_error: 20.2671 - val_loss: 3066210549760.0000 - val_mean_absolute_percentage_error: 18.2746
# Epoch 594/3000
# 680/680 - 3s - 4ms/step - loss: 2516315537408.0000 - mean_absolute_percentage_error: 20.2501 - val_loss: 3060344553472.0000 - val_mean_absolute_percentage_error: 18.2601
# Epoch 595/3000
# 680/680 - 1s - 2ms/step - loss: 2515741704192.0000 - mean_absolute_percentage_error: 20.2624 - val_loss: 3064754864128.0000 - val_mean_absolute_percentage_error: 18.2721
# Epoch 596/3000
# 680/680 - 3s - 4ms/step - loss: 2515097616384.0000 - mean_absolute_percentage_error: 20.2560 - val_loss: 3067156627456.0000 - val_mean_absolute_percentage_error: 18.2796
# Epoch 597/3000
# 680/680 - 3s - 4ms/step - loss: 2514396119040.0000 - mean_absolute_percentage_error: 20.2685 - val_loss: 3081695920128.0000 - val_mean_absolute_percentage_error: 18.3163
# Epoch 598/3000
# 680/680 - 2s - 3ms/step - loss: 2513914822656.0000 - mean_absolute_percentage_error: 20.2344 - val_loss: 3071313707008.0000 - val_mean_absolute_percentage_error: 18.2906
# Epoch 599/3000
# 680/680 - 1s - 2ms/step - loss: 2513344397312.0000 - mean_absolute_percentage_error: 20.2412 - val_loss: 3074212757504.0000 - val_mean_absolute_percentage_error: 18.2989
# Epoch 600/3000
# 680/680 - 2s - 2ms/step - loss: 2512727048192.0000 - mean_absolute_percentage_error: 20.2464 - val_loss: 3073913651200.0000 - val_mean_absolute_percentage_error: 18.2986
# Epoch 601/3000
# 680/680 - 1s - 2ms/step - loss: 2512238149632.0000 - mean_absolute_percentage_error: 20.2354 - val_loss: 3071508217856.0000 - val_mean_absolute_percentage_error: 18.2927
# Epoch 602/3000
# 680/680 - 2s - 2ms/step - loss: 2511653830656.0000 - mean_absolute_percentage_error: 20.2406 - val_loss: 3077750915072.0000 - val_mean_absolute_percentage_error: 18.3094
# Epoch 603/3000
# 680/680 - 3s - 4ms/step - loss: 2511073968128.0000 - mean_absolute_percentage_error: 20.2290 - val_loss: 3073021575168.0000 - val_mean_absolute_percentage_error: 18.2978
# Epoch 604/3000
# 680/680 - 3s - 4ms/step - loss: 2510574583808.0000 - mean_absolute_percentage_error: 20.2315 - val_loss: 3074910060544.0000 - val_mean_absolute_percentage_error: 18.3029
# Epoch 605/3000
# 680/680 - 2s - 3ms/step - loss: 2510023294976.0000 - mean_absolute_percentage_error: 20.2247 - val_loss: 3072178782208.0000 - val_mean_absolute_percentage_error: 18.2959
# Epoch 606/3000
# 680/680 - 3s - 4ms/step - loss: 2509495074816.0000 - mean_absolute_percentage_error: 20.2313 - val_loss: 3077178654720.0000 - val_mean_absolute_percentage_error: 18.3096
# Epoch 607/3000
# 680/680 - 3s - 4ms/step - loss: 2508949553152.0000 - mean_absolute_percentage_error: 20.2080 - val_loss: 3070058823680.0000 - val_mean_absolute_percentage_error: 18.2920
# Epoch 608/3000
# 680/680 - 3s - 4ms/step - loss: 2508472451072.0000 - mean_absolute_percentage_error: 20.2207 - val_loss: 3074637430784.0000 - val_mean_absolute_percentage_error: 18.3041
# Epoch 609/3000
# 680/680 - 3s - 4ms/step - loss: 2507958910976.0000 - mean_absolute_percentage_error: 20.2102 - val_loss: 3069259546624.0000 - val_mean_absolute_percentage_error: 18.2898
# Epoch 610/3000
# 680/680 - 2s - 2ms/step - loss: 2507475779584.0000 - mean_absolute_percentage_error: 20.2129 - val_loss: 3065320308736.0000 - val_mean_absolute_percentage_error: 18.2796
# Epoch 611/3000
# 680/680 - 1s - 2ms/step - loss: 2507020173312.0000 - mean_absolute_percentage_error: 20.2215 - val_loss: 3072713031680.0000 - val_mean_absolute_percentage_error: 18.2997
# Epoch 612/3000
# 680/680 - 3s - 4ms/step - loss: 2506533896192.0000 - mean_absolute_percentage_error: 20.1975 - val_loss: 3067525726208.0000 - val_mean_absolute_percentage_error: 18.2871
# Epoch 613/3000
# 680/680 - 2s - 4ms/step - loss: 2506122067968.0000 - mean_absolute_percentage_error: 20.2131 - val_loss: 3073618739200.0000 - val_mean_absolute_percentage_error: 18.3033
# Epoch 614/3000
# 680/680 - 3s - 5ms/step - loss: 2505621372928.0000 - mean_absolute_percentage_error: 20.2029 - val_loss: 3070428446720.0000 - val_mean_absolute_percentage_error: 18.2951
# Epoch 615/3000
# 680/680 - 2s - 3ms/step - loss: 2505137455104.0000 - mean_absolute_percentage_error: 20.2203 - val_loss: 3082771234816.0000 - val_mean_absolute_percentage_error: 18.3282
# Epoch 616/3000
# 680/680 - 2s - 3ms/step - loss: 2504710160384.0000 - mean_absolute_percentage_error: 20.1888 - val_loss: 3078568280064.0000 - val_mean_absolute_percentage_error: 18.3170
# Epoch 617/3000
# 680/680 - 3s - 4ms/step - loss: 2504294400000.0000 - mean_absolute_percentage_error: 20.2026 - val_loss: 3081768796160.0000 - val_mean_absolute_percentage_error: 18.3266
# Epoch 618/3000
# 680/680 - 3s - 4ms/step - loss: 2503825686528.0000 - mean_absolute_percentage_error: 20.1949 - val_loss: 3082106961920.0000 - val_mean_absolute_percentage_error: 18.3274
# Epoch 619/3000
# 680/680 - 1s - 2ms/step - loss: 2503421198336.0000 - mean_absolute_percentage_error: 20.1827 - val_loss: 3079585660928.0000 - val_mean_absolute_percentage_error: 18.3216
# Epoch 620/3000
# 680/680 - 3s - 5ms/step - loss: 2503031914496.0000 - mean_absolute_percentage_error: 20.1892 - val_loss: 3080401190912.0000 - val_mean_absolute_percentage_error: 18.3233
# Epoch 621/3000
# 680/680 - 2s - 3ms/step - loss: 2502532530176.0000 - mean_absolute_percentage_error: 20.1988 - val_loss: 3079633371136.0000 - val_mean_absolute_percentage_error: 18.3222
# Epoch 622/3000
# 680/680 - 2s - 3ms/step - loss: 2502125420544.0000 - mean_absolute_percentage_error: 20.1651 - val_loss: 3070055940096.0000 - val_mean_absolute_percentage_error: 18.2982
# Epoch 623/3000
# 680/680 - 1s - 2ms/step - loss: 2501755535360.0000 - mean_absolute_percentage_error: 20.1920 - val_loss: 3077041815552.0000 - val_mean_absolute_percentage_error: 18.3172
# Epoch 624/3000
# 680/680 - 3s - 4ms/step - loss: 2501207916544.0000 - mean_absolute_percentage_error: 20.2148 - val_loss: 3100847898624.0000 - val_mean_absolute_percentage_error: 18.3776
# Epoch 625/3000
# 680/680 - 2s - 2ms/step - loss: 2500968841216.0000 - mean_absolute_percentage_error: 20.1655 - val_loss: 3090708692992.0000 - val_mean_absolute_percentage_error: 18.3525
# Epoch 626/3000
# 680/680 - 2s - 3ms/step - loss: 2500578508800.0000 - mean_absolute_percentage_error: 20.1692 - val_loss: 3086876672000.0000 - val_mean_absolute_percentage_error: 18.3440
# Epoch 627/3000
# 680/680 - 3s - 4ms/step - loss: 2500141776896.0000 - mean_absolute_percentage_error: 20.1952 - val_loss: 3097377636352.0000 - val_mean_absolute_percentage_error: 18.3702
# Epoch 628/3000
# 680/680 - 2s - 3ms/step - loss: 2499852107776.0000 - mean_absolute_percentage_error: 20.1582 - val_loss: 3087677784064.0000 - val_mean_absolute_percentage_error: 18.3462
# Epoch 629/3000
# 680/680 - 3s - 4ms/step - loss: 2499452338176.0000 - mean_absolute_percentage_error: 20.1689 - val_loss: 3086541127680.0000 - val_mean_absolute_percentage_error: 18.3443
# Epoch 630/3000
# 680/680 - 3s - 4ms/step - loss: 2499116793856.0000 - mean_absolute_percentage_error: 20.1678 - val_loss: 3082454302720.0000 - val_mean_absolute_percentage_error: 18.3342
# Epoch 631/3000
# 680/680 - 3s - 4ms/step - loss: 2498734063616.0000 - mean_absolute_percentage_error: 20.1764 - val_loss: 3091722928128.0000 - val_mean_absolute_percentage_error: 18.3578
# Epoch 632/3000
# 680/680 - 3s - 5ms/step - loss: 2498400616448.0000 - mean_absolute_percentage_error: 20.1481 - val_loss: 3082021240832.0000 - val_mean_absolute_percentage_error: 18.3343
# Epoch 633/3000
# 680/680 - 2s - 2ms/step - loss: 2498065072128.0000 - mean_absolute_percentage_error: 20.1727 - val_loss: 3088661348352.0000 - val_mean_absolute_percentage_error: 18.3514
# Epoch 634/3000
# 680/680 - 3s - 4ms/step - loss: 2497724809216.0000 - mean_absolute_percentage_error: 20.1582 - val_loss: 3085974896640.0000 - val_mean_absolute_percentage_error: 18.3451
# Epoch 635/3000
# 680/680 - 2s - 4ms/step - loss: 2497337360384.0000 - mean_absolute_percentage_error: 20.1563 - val_loss: 3084313690112.0000 - val_mean_absolute_percentage_error: 18.3414
# Epoch 636/3000
# 680/680 - 1s - 2ms/step - loss: 2497011777536.0000 - mean_absolute_percentage_error: 20.1665 - val_loss: 3089692098560.0000 - val_mean_absolute_percentage_error: 18.3554
# Epoch 637/3000
# 680/680 - 2s - 2ms/step - loss: 2496732332032.0000 - mean_absolute_percentage_error: 20.1506 - val_loss: 3085218086912.0000 - val_mean_absolute_percentage_error: 18.3447
# Epoch 638/3000
# 680/680 - 2s - 3ms/step - loss: 2496373981184.0000 - mean_absolute_percentage_error: 20.1593 - val_loss: 3087739650048.0000 - val_mean_absolute_percentage_error: 18.3516
# Epoch 639/3000
# 680/680 - 2s - 4ms/step - loss: 2496027688960.0000 - mean_absolute_percentage_error: 20.1652 - val_loss: 3093237071872.0000 - val_mean_absolute_percentage_error: 18.3660
# Epoch 640/3000
# 680/680 - 2s - 2ms/step - loss: 2495685853184.0000 - mean_absolute_percentage_error: 20.1397 - val_loss: 3087677784064.0000 - val_mean_absolute_percentage_error: 18.3525
# Epoch 641/3000
# 680/680 - 2s - 4ms/step - loss: 2495341133824.0000 - mean_absolute_percentage_error: 20.1688 - val_loss: 3099983609856.0000 - val_mean_absolute_percentage_error: 18.3844
# Epoch 642/3000
# 680/680 - 3s - 4ms/step - loss: 2495094718464.0000 - mean_absolute_percentage_error: 20.1288 - val_loss: 3089009737728.0000 - val_mean_absolute_percentage_error: 18.3570
# Epoch 643/3000
# 680/680 - 3s - 4ms/step - loss: 2494719852544.0000 - mean_absolute_percentage_error: 20.1432 - val_loss: 3085002866688.0000 - val_mean_absolute_percentage_error: 18.3467
# Epoch 644/3000
# 680/680 - 2s - 4ms/step - loss: 2494429659136.0000 - mean_absolute_percentage_error: 20.1451 - val_loss: 3085979353088.0000 - val_mean_absolute_percentage_error: 18.3496
# Epoch 645/3000
# 680/680 - 2s - 3ms/step - loss: 2494107484160.0000 - mean_absolute_percentage_error: 20.1430 - val_loss: 3091226951680.0000 - val_mean_absolute_percentage_error: 18.3637
# Epoch 646/3000
# 680/680 - 2s - 2ms/step - loss: 2493847961600.0000 - mean_absolute_percentage_error: 20.1410 - val_loss: 3087256256512.0000 - val_mean_absolute_percentage_error: 18.3536
# Epoch 647/3000
# 680/680 - 3s - 4ms/step - loss: 2493521068032.0000 - mean_absolute_percentage_error: 20.1367 - val_loss: 3085106151424.0000 - val_mean_absolute_percentage_error: 18.3490
# Epoch 648/3000
# 680/680 - 2s - 4ms/step - loss: 2493263642624.0000 - mean_absolute_percentage_error: 20.1483 - val_loss: 3093481914368.0000 - val_mean_absolute_percentage_error: 18.3711
# Epoch 649/3000
# 680/680 - 3s - 4ms/step - loss: 2492911583232.0000 - mean_absolute_percentage_error: 20.1386 - val_loss: 3093203517440.0000 - val_mean_absolute_percentage_error: 18.3704
# Epoch 650/3000
# 680/680 - 3s - 5ms/step - loss: 2492655468544.0000 - mean_absolute_percentage_error: 20.1359 - val_loss: 3090941214720.0000 - val_mean_absolute_percentage_error: 18.3653
# Epoch 651/3000
# 680/680 - 2s - 2ms/step - loss: 2492368158720.0000 - mean_absolute_percentage_error: 20.1326 - val_loss: 3095508025344.0000 - val_mean_absolute_percentage_error: 18.3766
# Epoch 652/3000
# 680/680 - 3s - 4ms/step - loss: 2492045983744.0000 - mean_absolute_percentage_error: 20.1242 - val_loss: 3090290311168.0000 - val_mean_absolute_percentage_error: 18.3651
# Epoch 653/3000
# 680/680 - 3s - 4ms/step - loss: 2491754479616.0000 - mean_absolute_percentage_error: 20.1165 - val_loss: 3079805075456.0000 - val_mean_absolute_percentage_error: 18.3390
# Epoch 654/3000
# 680/680 - 1s - 2ms/step - loss: 2491413692416.0000 - mean_absolute_percentage_error: 20.1247 - val_loss: 3076075290624.0000 - val_mean_absolute_percentage_error: 18.3301
# Epoch 655/3000
# 680/680 - 3s - 4ms/step - loss: 2491201617920.0000 - mean_absolute_percentage_error: 20.1430 - val_loss: 3088994533376.0000 - val_mean_absolute_percentage_error: 18.3628
# Epoch 656/3000
# 680/680 - 3s - 4ms/step - loss: 2490862665728.0000 - mean_absolute_percentage_error: 20.1313 - val_loss: 3091684655104.0000 - val_mean_absolute_percentage_error: 18.3702
# Epoch 657/3000
# 680/680 - 2s - 3ms/step - loss: 2490621493248.0000 - mean_absolute_percentage_error: 20.1337 - val_loss: 3097951731712.0000 - val_mean_absolute_percentage_error: 18.3862
# Epoch 658/3000
# 680/680 - 3s - 4ms/step - loss: 2490324484096.0000 - mean_absolute_percentage_error: 20.1264 - val_loss: 3100798091264.0000 - val_mean_absolute_percentage_error: 18.3943
# Epoch 659/3000
# 680/680 - 3s - 4ms/step - loss: 2490091700224.0000 - mean_absolute_percentage_error: 20.1125 - val_loss: 3098099580928.0000 - val_mean_absolute_percentage_error: 18.3877
# Epoch 660/3000
# 680/680 - 1s - 2ms/step - loss: 2489764020224.0000 - mean_absolute_percentage_error: 20.1153 - val_loss: 3095813423104.0000 - val_mean_absolute_percentage_error: 18.3825
# Epoch 661/3000
# 680/680 - 2s - 3ms/step - loss: 2489516294144.0000 - mean_absolute_percentage_error: 20.1185 - val_loss: 3096084742144.0000 - val_mean_absolute_percentage_error: 18.3840
# Epoch 662/3000
# 680/680 - 2s - 3ms/step - loss: 2489227149312.0000 - mean_absolute_percentage_error: 20.1133 - val_loss: 3095844356096.0000 - val_mean_absolute_percentage_error: 18.3841
# Epoch 663/3000
# 680/680 - 2s - 3ms/step - loss: 2488982831104.0000 - mean_absolute_percentage_error: 20.1175 - val_loss: 3090780782592.0000 - val_mean_absolute_percentage_error: 18.3716
# Epoch 664/3000
# 680/680 - 3s - 4ms/step - loss: 2488713871360.0000 - mean_absolute_percentage_error: 20.1098 - val_loss: 3092896808960.0000 - val_mean_absolute_percentage_error: 18.3774
# Epoch 665/3000
# 680/680 - 3s - 4ms/step - loss: 2488456708096.0000 - mean_absolute_percentage_error: 20.1213 - val_loss: 3094701146112.0000 - val_mean_absolute_percentage_error: 18.3824
# Epoch 666/3000
# 680/680 - 2s - 2ms/step - loss: 2488176738304.0000 - mean_absolute_percentage_error: 20.1179 - val_loss: 3103646023680.0000 - val_mean_absolute_percentage_error: 18.4061
# Epoch 667/3000
# 680/680 - 2s - 2ms/step - loss: 2487894933504.0000 - mean_absolute_percentage_error: 20.0995 - val_loss: 3090479054848.0000 - val_mean_absolute_percentage_error: 18.3729
# Epoch 668/3000
# 680/680 - 3s - 5ms/step - loss: 2487579574272.0000 - mean_absolute_percentage_error: 20.1334 - val_loss: 3109384355840.0000 - val_mean_absolute_percentage_error: 18.4210
# Epoch 669/3000
# 680/680 - 2s - 3ms/step - loss: 2487411277824.0000 - mean_absolute_percentage_error: 20.1013 - val_loss: 3105366736896.0000 - val_mean_absolute_percentage_error: 18.4112
# Epoch 670/3000
# 680/680 - 2s - 4ms/step - loss: 2487166697472.0000 - mean_absolute_percentage_error: 20.1049 - val_loss: 3103103123456.0000 - val_mean_absolute_percentage_error: 18.4057
# Epoch 671/3000
# 680/680 - 3s - 4ms/step - loss: 2486934962176.0000 - mean_absolute_percentage_error: 20.1078 - val_loss: 3099036483584.0000 - val_mean_absolute_percentage_error: 18.3956
# Epoch 672/3000
# 680/680 - 3s - 4ms/step - loss: 2486643195904.0000 - mean_absolute_percentage_error: 20.0928 - val_loss: 3098413629440.0000 - val_mean_absolute_percentage_error: 18.3946
# Epoch 673/3000
# 680/680 - 3s - 5ms/step - loss: 2486423781376.0000 - mean_absolute_percentage_error: 20.1106 - val_loss: 3101501161472.0000 - val_mean_absolute_percentage_error: 18.4030
# Epoch 674/3000
# 680/680 - 2s - 3ms/step - loss: 2486124150784.0000 - mean_absolute_percentage_error: 20.1194 - val_loss: 3112833384448.0000 - val_mean_absolute_percentage_error: 18.4319
# Epoch 675/3000
# 680/680 - 2s - 2ms/step - loss: 2485852569600.0000 - mean_absolute_percentage_error: 20.0668 - val_loss: 3093277442048.0000 - val_mean_absolute_percentage_error: 18.3832
# Epoch 676/3000
# 680/680 - 3s - 4ms/step - loss: 2485616377856.0000 - mean_absolute_percentage_error: 20.0986 - val_loss: 3088484139008.0000 - val_mean_absolute_percentage_error: 18.3718
# Epoch 677/3000
# 680/680 - 1s - 2ms/step - loss: 2485414002688.0000 - mean_absolute_percentage_error: 20.1129 - val_loss: 3101447421952.0000 - val_mean_absolute_percentage_error: 18.4050
# Epoch 678/3000
# 680/680 - 2s - 2ms/step - loss: 2485174665216.0000 - mean_absolute_percentage_error: 20.0966 - val_loss: 3099845984256.0000 - val_mean_absolute_percentage_error: 18.4016
# Epoch 679/3000
# 680/680 - 2s - 2ms/step - loss: 2484951842816.0000 - mean_absolute_percentage_error: 20.0958 - val_loss: 3102724849664.0000 - val_mean_absolute_percentage_error: 18.4086
# Epoch 680/3000
# 680/680 - 2s - 3ms/step - loss: 2484736622592.0000 - mean_absolute_percentage_error: 20.0912 - val_loss: 3099575713792.0000 - val_mean_absolute_percentage_error: 18.4011
# Epoch 681/3000
# 680/680 - 2s - 3ms/step - loss: 2484483653632.0000 - mean_absolute_percentage_error: 20.1038 - val_loss: 3108571709440.0000 - val_mean_absolute_percentage_error: 18.4246
# Epoch 682/3000
# 680/680 - 2s - 3ms/step - loss: 2484257947648.0000 - mean_absolute_percentage_error: 20.0909 - val_loss: 3108525572096.0000 - val_mean_absolute_percentage_error: 18.4253
# Epoch 683/3000
# 680/680 - 2s - 2ms/step - loss: 2484038795264.0000 - mean_absolute_percentage_error: 20.0899 - val_loss: 3103372345344.0000 - val_mean_absolute_percentage_error: 18.4126
# Epoch 684/3000
# 680/680 - 3s - 4ms/step - loss: 2483766951936.0000 - mean_absolute_percentage_error: 20.0915 - val_loss: 3106444935168.0000 - val_mean_absolute_percentage_error: 18.4206
# Epoch 685/3000
# 680/680 - 3s - 4ms/step - loss: 2483535740928.0000 - mean_absolute_percentage_error: 20.0854 - val_loss: 3105676591104.0000 - val_mean_absolute_percentage_error: 18.4196
# Epoch 686/3000
# 680/680 - 3s - 4ms/step - loss: 2483366395904.0000 - mean_absolute_percentage_error: 20.0854 - val_loss: 3104069386240.0000 - val_mean_absolute_percentage_error: 18.4156
# Epoch 687/3000
# 680/680 - 3s - 4ms/step - loss: 2483080396800.0000 - mean_absolute_percentage_error: 20.0930 - val_loss: 3106628960256.0000 - val_mean_absolute_percentage_error: 18.4232
# Epoch 688/3000
# 680/680 - 2s - 3ms/step - loss: 2482875662336.0000 - mean_absolute_percentage_error: 20.0815 - val_loss: 3107025321984.0000 - val_mean_absolute_percentage_error: 18.4244
# Epoch 689/3000
# 680/680 - 3s - 4ms/step - loss: 2482601197568.0000 - mean_absolute_percentage_error: 20.0898 - val_loss: 3108500144128.0000 - val_mean_absolute_percentage_error: 18.4286
# Epoch 690/3000
# 680/680 - 1s - 2ms/step - loss: 2482379423744.0000 - mean_absolute_percentage_error: 20.0693 - val_loss: 3100283240448.0000 - val_mean_absolute_percentage_error: 18.4086
# Epoch 691/3000
# 680/680 - 3s - 4ms/step - loss: 2482210865152.0000 - mean_absolute_percentage_error: 20.0825 - val_loss: 3099886616576.0000 - val_mean_absolute_percentage_error: 18.4081
# Epoch 692/3000
# 680/680 - 3s - 5ms/step - loss: 2481988829184.0000 - mean_absolute_percentage_error: 20.0825 - val_loss: 3101851910144.0000 - val_mean_absolute_percentage_error: 18.4132
# Epoch 693/3000
# 680/680 - 2s - 3ms/step - loss: 2481775968256.0000 - mean_absolute_percentage_error: 20.0837 - val_loss: 3104482525184.0000 - val_mean_absolute_percentage_error: 18.4203
# Epoch 694/3000
# 680/680 - 2s - 3ms/step - loss: 2481485512704.0000 - mean_absolute_percentage_error: 20.0595 - val_loss: 3091556990976.0000 - val_mean_absolute_percentage_error: 18.3883
# Epoch 695/3000
# 680/680 - 3s - 4ms/step - loss: 2481359945728.0000 - mean_absolute_percentage_error: 20.0918 - val_loss: 3101841162240.0000 - val_mean_absolute_percentage_error: 18.4143
# Epoch 696/3000
# 680/680 - 3s - 4ms/step - loss: 2481109336064.0000 - mean_absolute_percentage_error: 20.0754 - val_loss: 3099142389760.0000 - val_mean_absolute_percentage_error: 18.4081
# Epoch 697/3000
# 680/680 - 2s - 2ms/step - loss: 2480868687872.0000 - mean_absolute_percentage_error: 20.0773 - val_loss: 3099780972544.0000 - val_mean_absolute_percentage_error: 18.4103
# Epoch 698/3000
# 680/680 - 3s - 5ms/step - loss: 2480658186240.0000 - mean_absolute_percentage_error: 20.0695 - val_loss: 3100154265600.0000 - val_mean_absolute_percentage_error: 18.4116
# Epoch 699/3000
# 680/680 - 2s - 3ms/step - loss: 2480475209728.0000 - mean_absolute_percentage_error: 20.0668 - val_loss: 3096946933760.0000 - val_mean_absolute_percentage_error: 18.4043
# Epoch 700/3000
# 680/680 - 2s - 2ms/step - loss: 2480267067392.0000 - mean_absolute_percentage_error: 20.0714 - val_loss: 3096476385280.0000 - val_mean_absolute_percentage_error: 18.4037
# Epoch 701/3000
# 680/680 - 2s - 2ms/step - loss: 2480091168768.0000 - mean_absolute_percentage_error: 20.0827 - val_loss: 3101573775360.0000 - val_mean_absolute_percentage_error: 18.4166
# Epoch 702/3000
# 680/680 - 2s - 4ms/step - loss: 2479860744192.0000 - mean_absolute_percentage_error: 20.0652 - val_loss: 3098345996288.0000 - val_mean_absolute_percentage_error: 18.4091
# Epoch 703/3000
# 680/680 - 3s - 4ms/step - loss: 2479711584256.0000 - mean_absolute_percentage_error: 20.0719 - val_loss: 3101120528384.0000 - val_mean_absolute_percentage_error: 18.4164
# Epoch 704/3000
# 680/680 - 3s - 5ms/step - loss: 2479393603584.0000 - mean_absolute_percentage_error: 20.0809 - val_loss: 3107875717120.0000 - val_mean_absolute_percentage_error: 18.4338
# Epoch 705/3000
# 680/680 - 2s - 3ms/step - loss: 2479245492224.0000 - mean_absolute_percentage_error: 20.0588 - val_loss: 3104480165888.0000 - val_mean_absolute_percentage_error: 18.4258
# Epoch 706/3000
# 680/680 - 2s - 3ms/step - loss: 2479037874176.0000 - mean_absolute_percentage_error: 20.0559 - val_loss: 3094455517184.0000 - val_mean_absolute_percentage_error: 18.4008
# Epoch 707/3000
# 680/680 - 3s - 4ms/step - loss: 2478822653952.0000 - mean_absolute_percentage_error: 20.0728 - val_loss: 3099103592448.0000 - val_mean_absolute_percentage_error: 18.4128
# Epoch 708/3000
# 680/680 - 3s - 4ms/step - loss: 2478609793024.0000 - mean_absolute_percentage_error: 20.0625 - val_loss: 3100722331648.0000 - val_mean_absolute_percentage_error: 18.4182
# Epoch 709/3000
# 680/680 - 3s - 5ms/step - loss: 2478386184192.0000 - mean_absolute_percentage_error: 20.0748 - val_loss: 3104917422080.0000 - val_mean_absolute_percentage_error: 18.4288
# Epoch 710/3000
# 680/680 - 3s - 4ms/step - loss: 2478214479872.0000 - mean_absolute_percentage_error: 20.0579 - val_loss: 3101573251072.0000 - val_mean_absolute_percentage_error: 18.4203
# Epoch 711/3000
# 680/680 - 2s - 3ms/step - loss: 2478038581248.0000 - mean_absolute_percentage_error: 20.0621 - val_loss: 3104143310848.0000 - val_mean_absolute_percentage_error: 18.4270
# Epoch 712/3000
# 680/680 - 3s - 4ms/step - loss: 2477814710272.0000 - mean_absolute_percentage_error: 20.0722 - val_loss: 3111109001216.0000 - val_mean_absolute_percentage_error: 18.4449
# Epoch 713/3000
# 680/680 - 3s - 4ms/step - loss: 2477593722880.0000 - mean_absolute_percentage_error: 20.0520 - val_loss: 3105419952128.0000 - val_mean_absolute_percentage_error: 18.4313
# Epoch 714/3000
# 680/680 - 2s - 2ms/step - loss: 2477377716224.0000 - mean_absolute_percentage_error: 20.0505 - val_loss: 3102138695680.0000 - val_mean_absolute_percentage_error: 18.4235
# Epoch 715/3000
# 680/680 - 3s - 5ms/step - loss: 2477193166848.0000 - mean_absolute_percentage_error: 20.0568 - val_loss: 3101286727680.0000 - val_mean_absolute_percentage_error: 18.4218
# Epoch 716/3000
# 680/680 - 2s - 3ms/step - loss: 2476999180288.0000 - mean_absolute_percentage_error: 20.0628 - val_loss: 3103252021248.0000 - val_mean_absolute_percentage_error: 18.4272
# Epoch 717/3000
# 680/680 - 2s - 2ms/step - loss: 2476785270784.0000 - mean_absolute_percentage_error: 20.0427 - val_loss: 3097377112064.0000 - val_mean_absolute_percentage_error: 18.4130
# Epoch 718/3000
# 680/680 - 3s - 4ms/step - loss: 2476632440832.0000 - mean_absolute_percentage_error: 20.0667 - val_loss: 3102757093376.0000 - val_mean_absolute_percentage_error: 18.4270
# Epoch 719/3000
# 680/680 - 2s - 4ms/step - loss: 2476394938368.0000 - mean_absolute_percentage_error: 20.0572 - val_loss: 3103788630016.0000 - val_mean_absolute_percentage_error: 18.4301
# Epoch 720/3000
# 680/680 - 3s - 4ms/step - loss: 2476130435072.0000 - mean_absolute_percentage_error: 20.0703 - val_loss: 3116053299200.0000 - val_mean_absolute_percentage_error: 18.4610
# Epoch 721/3000
# 680/680 - 3s - 5ms/step - loss: 2476038684672.0000 - mean_absolute_percentage_error: 20.0459 - val_loss: 3112083128320.0000 - val_mean_absolute_percentage_error: 18.4513
# Epoch 722/3000
# 680/680 - 2s - 3ms/step - loss: 2475799609344.0000 - mean_absolute_percentage_error: 20.0450 - val_loss: 3108118200320.0000 - val_mean_absolute_percentage_error: 18.4416
# Epoch 723/3000
# 680/680 - 2s - 2ms/step - loss: 2475633147904.0000 - mean_absolute_percentage_error: 20.0364 - val_loss: 3102084431872.0000 - val_mean_absolute_percentage_error: 18.4274
# Epoch 724/3000
# 680/680 - 3s - 4ms/step - loss: 2475468521472.0000 - mean_absolute_percentage_error: 20.0609 - val_loss: 3106361049088.0000 - val_mean_absolute_percentage_error: 18.4383
# Epoch 725/3000
# 680/680 - 2s - 4ms/step - loss: 2475206639616.0000 - mean_absolute_percentage_error: 20.0430 - val_loss: 3104105824256.0000 - val_mean_absolute_percentage_error: 18.4331
# Epoch 726/3000
# 680/680 - 3s - 5ms/step - loss: 2475015012352.0000 - mean_absolute_percentage_error: 20.0490 - val_loss: 3108290166784.0000 - val_mean_absolute_percentage_error: 18.4442
# Epoch 727/3000
# 680/680 - 3s - 4ms/step - loss: 2474857201664.0000 - mean_absolute_percentage_error: 20.0458 - val_loss: 3107818831872.0000 - val_mean_absolute_percentage_error: 18.4436
# Epoch 728/3000
# 680/680 - 2s - 3ms/step - loss: 2474649059328.0000 - mean_absolute_percentage_error: 20.0454 - val_loss: 3104503234560.0000 - val_mean_absolute_percentage_error: 18.4358
# Epoch 729/3000
# 680/680 - 1s - 2ms/step - loss: 2474477355008.0000 - mean_absolute_percentage_error: 20.0472 - val_loss: 3106340864000.0000 - val_mean_absolute_percentage_error: 18.4406
# Epoch 730/3000
# 680/680 - 2s - 2ms/step - loss: 2474296999936.0000 - mean_absolute_percentage_error: 20.0445 - val_loss: 3107901931520.0000 - val_mean_absolute_percentage_error: 18.4449
# Epoch 731/3000
# 680/680 - 3s - 4ms/step - loss: 2474106421248.0000 - mean_absolute_percentage_error: 20.0456 - val_loss: 3103762677760.0000 - val_mean_absolute_percentage_error: 18.4349
# Epoch 732/3000
# 680/680 - 3s - 4ms/step - loss: 2473948086272.0000 - mean_absolute_percentage_error: 20.0473 - val_loss: 3109857525760.0000 - val_mean_absolute_percentage_error: 18.4505
# Epoch 733/3000
# 680/680 - 3s - 4ms/step - loss: 2473699573760.0000 - mean_absolute_percentage_error: 20.0385 - val_loss: 3109830787072.0000 - val_mean_absolute_percentage_error: 18.4508
# Epoch 734/3000
# 680/680 - 2s - 3ms/step - loss: 2473575841792.0000 - mean_absolute_percentage_error: 20.0350 - val_loss: 3103389384704.0000 - val_mean_absolute_percentage_error: 18.4354
# Epoch 735/3000
# 680/680 - 3s - 4ms/step - loss: 2473356427264.0000 - mean_absolute_percentage_error: 20.0297 - val_loss: 3100888268800.0000 - val_mean_absolute_percentage_error: 18.4294
# Epoch 736/3000
# 680/680 - 3s - 4ms/step - loss: 2473222471680.0000 - mean_absolute_percentage_error: 20.0534 - val_loss: 3108283613184.0000 - val_mean_absolute_percentage_error: 18.4483
# Epoch 737/3000
# 680/680 - 2s - 2ms/step - loss: 2473041854464.0000 - mean_absolute_percentage_error: 20.0276 - val_loss: 3099140030464.0000 - val_mean_absolute_percentage_error: 18.4258
# Epoch 738/3000
# 680/680 - 2s - 3ms/step - loss: 2472805924864.0000 - mean_absolute_percentage_error: 20.0363 - val_loss: 3098563837952.0000 - val_mean_absolute_percentage_error: 18.4245
# Epoch 739/3000
# 680/680 - 3s - 4ms/step - loss: 2472681406464.0000 - mean_absolute_percentage_error: 20.0412 - val_loss: 3097642401792.0000 - val_mean_absolute_percentage_error: 18.4227
# Epoch 740/3000
# 680/680 - 2s - 3ms/step - loss: 2472486633472.0000 - mean_absolute_percentage_error: 20.0405 - val_loss: 3101839327232.0000 - val_mean_absolute_percentage_error: 18.4339
# Epoch 741/3000
# 680/680 - 3s - 4ms/step - loss: 2472261451776.0000 - mean_absolute_percentage_error: 20.0364 - val_loss: 3104848478208.0000 - val_mean_absolute_percentage_error: 18.4414
# Epoch 742/3000
# 680/680 - 2s - 4ms/step - loss: 2472102330368.0000 - mean_absolute_percentage_error: 20.0422 - val_loss: 3109955567616.0000 - val_mean_absolute_percentage_error: 18.4542
# Epoch 743/3000
# 680/680 - 2s - 2ms/step - loss: 2471901003776.0000 - mean_absolute_percentage_error: 20.0221 - val_loss: 3103643140096.0000 - val_mean_absolute_percentage_error: 18.4391
# Epoch 744/3000
# 680/680 - 2s - 2ms/step - loss: 2471732445184.0000 - mean_absolute_percentage_error: 20.0273 - val_loss: 3100036825088.0000 - val_mean_absolute_percentage_error: 18.4305
# Epoch 745/3000
# 680/680 - 3s - 4ms/step - loss: 2471541866496.0000 - mean_absolute_percentage_error: 20.0460 - val_loss: 3107697197056.0000 - val_mean_absolute_percentage_error: 18.4500
# Epoch 746/3000
# 680/680 - 2s - 2ms/step - loss: 2471350763520.0000 - mean_absolute_percentage_error: 20.0236 - val_loss: 3104342540288.0000 - val_mean_absolute_percentage_error: 18.4422
# Epoch 747/3000
# 680/680 - 3s - 4ms/step - loss: 2471178534912.0000 - mean_absolute_percentage_error: 20.0515 - val_loss: 3111954153472.0000 - val_mean_absolute_percentage_error: 18.4615
# Epoch 748/3000
# 680/680 - 3s - 4ms/step - loss: 2471017054208.0000 - mean_absolute_percentage_error: 20.0124 - val_loss: 3103589400576.0000 - val_mean_absolute_percentage_error: 18.4408
# Epoch 749/3000
# 680/680 - 2s - 2ms/step - loss: 2470838272000.0000 - mean_absolute_percentage_error: 20.0323 - val_loss: 3104424067072.0000 - val_mean_absolute_percentage_error: 18.4434
# Epoch 750/3000
# 680/680 - 3s - 4ms/step - loss: 2470666829824.0000 - mean_absolute_percentage_error: 20.0241 - val_loss: 3103242321920.0000 - val_mean_absolute_percentage_error: 18.4409
# Epoch 751/3000
# 680/680 - 3s - 4ms/step - loss: 2470511640576.0000 - mean_absolute_percentage_error: 20.0251 - val_loss: 3101180821504.0000 - val_mean_absolute_percentage_error: 18.4361
# Epoch 752/3000
# 680/680 - 2s - 3ms/step - loss: 2470387384320.0000 - mean_absolute_percentage_error: 20.0302 - val_loss: 3105154924544.0000 - val_mean_absolute_percentage_error: 18.4461
# Epoch 753/3000
# 680/680 - 1s - 2ms/step - loss: 2470156173312.0000 - mean_absolute_percentage_error: 20.0399 - val_loss: 3111300628480.0000 - val_mean_absolute_percentage_error: 18.4616
# Epoch 754/3000
# 680/680 - 3s - 4ms/step - loss: 2469997051904.0000 - mean_absolute_percentage_error: 20.0169 - val_loss: 3111787167744.0000 - val_mean_absolute_percentage_error: 18.4635
# Epoch 755/3000
# 680/680 - 3s - 4ms/step - loss: 2469812240384.0000 - mean_absolute_percentage_error: 20.0153 - val_loss: 3100751167488.0000 - val_mean_absolute_percentage_error: 18.4368
# Epoch 756/3000
# 680/680 - 2s - 3ms/step - loss: 2469646303232.0000 - mean_absolute_percentage_error: 20.0165 - val_loss: 3103660965888.0000 - val_mean_absolute_percentage_error: 18.4442
# Epoch 757/3000
# 680/680 - 3s - 4ms/step - loss: 2469503434752.0000 - mean_absolute_percentage_error: 20.0316 - val_loss: 3103515738112.0000 - val_mean_absolute_percentage_error: 18.4440
# Epoch 758/3000
# 680/680 - 2s - 2ms/step - loss: 2469303943168.0000 - mean_absolute_percentage_error: 20.0255 - val_loss: 3108517183488.0000 - val_mean_absolute_percentage_error: 18.4571
# Epoch 759/3000
# 680/680 - 2s - 4ms/step - loss: 2469166317568.0000 - mean_absolute_percentage_error: 20.0278 - val_loss: 3111776419840.0000 - val_mean_absolute_percentage_error: 18.4657
# Epoch 760/3000
# 680/680 - 3s - 4ms/step - loss: 2468999331840.0000 - mean_absolute_percentage_error: 20.0225 - val_loss: 3115802165248.0000 - val_mean_absolute_percentage_error: 18.4760
# Epoch 761/3000
# ...
# Epoch 2916/3000
# 680/680 - 1s - 2ms/step - loss: 2357013512192.0000 - mean_absolute_percentage_error: 19.5916 - val_loss: 3187272056832.0000 - val_mean_absolute_percentage_error: 18.8660
# Epoch 2917/3000
# 680/680 - 3s - 4ms/step - loss: 2356995424256.0000 - mean_absolute_percentage_error: 19.5959 - val_loss: 3192972115968.0000 - val_mean_absolute_percentage_error: 18.8809
# Epoch 2918/3000
# 680/680 - 3s - 4ms/step - loss: 2356956364800.0000 - mean_absolute_percentage_error: 19.5817 - val_loss: 3187972767744.0000 - val_mean_absolute_percentage_error: 18.8681
# Epoch 2919/3000
# 680/680 - 3s - 4ms/step - loss: 2356922023936.0000 - mean_absolute_percentage_error: 19.6036 - val_loss: 3199039700992.0000 - val_mean_absolute_percentage_error: 18.8976
# Epoch 2920/3000
# 680/680 - 2s - 2ms/step - loss: 2356907606016.0000 - mean_absolute_percentage_error: 19.5806 - val_loss: 3192637358080.0000 - val_mean_absolute_percentage_error: 18.8802
# Epoch 2921/3000
# 680/680 - 1s - 2ms/step - loss: 2356887158784.0000 - mean_absolute_percentage_error: 19.5739 - val_loss: 3182374944768.0000 - val_mean_absolute_percentage_error: 18.8535
# Epoch 2922/3000
# 680/680 - 3s - 4ms/step - loss: 2356816904192.0000 - mean_absolute_percentage_error: 19.6060 - val_loss: 3194675527680.0000 - val_mean_absolute_percentage_error: 18.8853
# Epoch 2923/3000
# 680/680 - 1s - 2ms/step - loss: 2356858585088.0000 - mean_absolute_percentage_error: 19.5725 - val_loss: 3186968231936.0000 - val_mean_absolute_percentage_error: 18.8654
# Epoch 2924/3000
# 680/680 - 3s - 4ms/step - loss: 2356894760960.0000 - mean_absolute_percentage_error: 19.5917 - val_loss: 3190310043648.0000 - val_mean_absolute_percentage_error: 18.8735
# Epoch 2925/3000
# 680/680 - 3s - 4ms/step - loss: 2356753989632.0000 - mean_absolute_percentage_error: 19.6061 - val_loss: 3198044078080.0000 - val_mean_absolute_percentage_error: 18.8941
# Epoch 2926/3000
# 680/680 - 2s - 3ms/step - loss: 2356750057472.0000 - mean_absolute_percentage_error: 19.5955 - val_loss: 3202390687744.0000 - val_mean_absolute_percentage_error: 18.9056
# Epoch 2927/3000
# 680/680 - 2s - 4ms/step - loss: 2356746125312.0000 - mean_absolute_percentage_error: 19.5784 - val_loss: 3198765760512.0000 - val_mean_absolute_percentage_error: 18.8961
# Epoch 2928/3000
# 680/680 - 3s - 4ms/step - loss: 2356668006400.0000 - mean_absolute_percentage_error: 19.5701 - val_loss: 3178657480704.0000 - val_mean_absolute_percentage_error: 18.8432
# Epoch 2929/3000
# 680/680 - 2s - 4ms/step - loss: 2356708900864.0000 - mean_absolute_percentage_error: 19.5834 - val_loss: 3181112983552.0000 - val_mean_absolute_percentage_error: 18.8498
# Epoch 2930/3000
# 680/680 - 3s - 5ms/step - loss: 2356662239232.0000 - mean_absolute_percentage_error: 19.6010 - val_loss: 3186760089600.0000 - val_mean_absolute_percentage_error: 18.8644
# Epoch 2931/3000
# 680/680 - 1s - 2ms/step - loss: 2356668792832.0000 - mean_absolute_percentage_error: 19.5955 - val_loss: 3192884297728.0000 - val_mean_absolute_percentage_error: 18.8803
# Epoch 2932/3000
# 680/680 - 3s - 4ms/step - loss: 2356614791168.0000 - mean_absolute_percentage_error: 19.6016 - val_loss: 3204297785344.0000 - val_mean_absolute_percentage_error: 18.9104
# Epoch 2933/3000
# 680/680 - 3s - 4ms/step - loss: 2356642316288.0000 - mean_absolute_percentage_error: 19.5748 - val_loss: 3194769375232.0000 - val_mean_absolute_percentage_error: 18.8854
# Epoch 2934/3000
# 680/680 - 1s - 2ms/step - loss: 2356612431872.0000 - mean_absolute_percentage_error: 19.5810 - val_loss: 3183684616192.0000 - val_mean_absolute_percentage_error: 18.8563
# Epoch 2935/3000
# 680/680 - 3s - 4ms/step - loss: 2356539031552.0000 - mean_absolute_percentage_error: 19.5800 - val_loss: 3183165571072.0000 - val_mean_absolute_percentage_error: 18.8551
# Epoch 2936/3000
# 680/680 - 3s - 4ms/step - loss: 2356496826368.0000 - mean_absolute_percentage_error: 19.5849 - val_loss: 3180696698880.0000 - val_mean_absolute_percentage_error: 18.8478
# Epoch 2937/3000
# 680/680 - 2s - 3ms/step - loss: 2356498399232.0000 - mean_absolute_percentage_error: 19.6019 - val_loss: 3189565554688.0000 - val_mean_absolute_percentage_error: 18.8713
# Epoch 2938/3000
# 680/680 - 3s - 4ms/step - loss: 2356487127040.0000 - mean_absolute_percentage_error: 19.5870 - val_loss: 3187711148032.0000 - val_mean_absolute_percentage_error: 18.8665
# Epoch 2939/3000
# 680/680 - 3s - 4ms/step - loss: 2356446232576.0000 - mean_absolute_percentage_error: 19.5935 - val_loss: 3198521180160.0000 - val_mean_absolute_percentage_error: 18.8950
# Epoch 2940/3000
# 680/680 - 2s - 2ms/step - loss: 2356378075136.0000 - mean_absolute_percentage_error: 19.5764 - val_loss: 3190081454080.0000 - val_mean_absolute_percentage_error: 18.8726
# Epoch 2941/3000
# 680/680 - 3s - 5ms/step - loss: 2356432863232.0000 - mean_absolute_percentage_error: 19.5981 - val_loss: 3194397392896.0000 - val_mean_absolute_percentage_error: 18.8841
# Epoch 2942/3000
# 680/680 - 2s - 2ms/step - loss: 2356374929408.0000 - mean_absolute_percentage_error: 19.5851 - val_loss: 3193155354624.0000 - val_mean_absolute_percentage_error: 18.8808
# Epoch 2943/3000
# 680/680 - 3s - 4ms/step - loss: 2356327219200.0000 - mean_absolute_percentage_error: 19.5994 - val_loss: 3200884932608.0000 - val_mean_absolute_percentage_error: 18.9016
# Epoch 2944/3000
# 680/680 - 1s - 2ms/step - loss: 2356319354880.0000 - mean_absolute_percentage_error: 19.5802 - val_loss: 3198172004352.0000 - val_mean_absolute_percentage_error: 18.8944
# Epoch 2945/3000
# 680/680 - 3s - 4ms/step - loss: 2356303364096.0000 - mean_absolute_percentage_error: 19.5863 - val_loss: 3203927375872.0000 - val_mean_absolute_percentage_error: 18.9093
# Epoch 2946/3000
# 680/680 - 1s - 2ms/step - loss: 2356304412672.0000 - mean_absolute_percentage_error: 19.5858 - val_loss: 3197159342080.0000 - val_mean_absolute_percentage_error: 18.8915
# Epoch 2947/3000
# 680/680 - 2s - 3ms/step - loss: 2356258537472.0000 - mean_absolute_percentage_error: 19.5719 - val_loss: 3185784389632.0000 - val_mean_absolute_percentage_error: 18.8615
# Epoch 2948/3000
# 680/680 - 2s - 3ms/step - loss: 2356270858240.0000 - mean_absolute_percentage_error: 19.5898 - val_loss: 3188577796096.0000 - val_mean_absolute_percentage_error: 18.8690
# Epoch 2949/3000
# 680/680 - 2s - 3ms/step - loss: 2356210040832.0000 - mean_absolute_percentage_error: 19.5882 - val_loss: 3185732747264.0000 - val_mean_absolute_percentage_error: 18.8608
# Epoch 2950/3000
# 680/680 - 2s - 2ms/step - loss: 2356199817216.0000 - mean_absolute_percentage_error: 19.5982 - val_loss: 3195758706688.0000 - val_mean_absolute_percentage_error: 18.8876
# Epoch 2951/3000
# 680/680 - 1s - 2ms/step - loss: 2356149485568.0000 - mean_absolute_percentage_error: 19.5907 - val_loss: 3200764608512.0000 - val_mean_absolute_percentage_error: 18.9011
# Epoch 2952/3000
# 680/680 - 3s - 4ms/step - loss: 2356169670656.0000 - mean_absolute_percentage_error: 19.5791 - val_loss: 3195221049344.0000 - val_mean_absolute_percentage_error: 18.8865
# Epoch 2953/3000
# 680/680 - 1s - 2ms/step - loss: 2356044103680.0000 - mean_absolute_percentage_error: 19.5702 - val_loss: 3185127718912.0000 - val_mean_absolute_percentage_error: 18.8596
# Epoch 2954/3000
# 680/680 - 2s - 2ms/step - loss: 2356094697472.0000 - mean_absolute_percentage_error: 19.5844 - val_loss: 3178167009280.0000 - val_mean_absolute_percentage_error: 18.8418
# Epoch 2955/3000
# 680/680 - 3s - 4ms/step - loss: 2356102823936.0000 - mean_absolute_percentage_error: 19.5974 - val_loss: 3191661395968.0000 - val_mean_absolute_percentage_error: 18.8773
# Epoch 2956/3000
# 680/680 - 1s - 2ms/step - loss: 2356080541696.0000 - mean_absolute_percentage_error: 19.5880 - val_loss: 3189459648512.0000 - val_mean_absolute_percentage_error: 18.8715
# Epoch 2957/3000
# 680/680 - 3s - 4ms/step - loss: 2356005830656.0000 - mean_absolute_percentage_error: 19.5812 - val_loss: 3187987185664.0000 - val_mean_absolute_percentage_error: 18.8672
# Epoch 2958/3000
# 680/680 - 2s - 2ms/step - loss: 2356000587776.0000 - mean_absolute_percentage_error: 19.5974 - val_loss: 3197623861248.0000 - val_mean_absolute_percentage_error: 18.8933
# Epoch 2959/3000
# 680/680 - 2s - 2ms/step - loss: 2355921944576.0000 - mean_absolute_percentage_error: 19.5611 - val_loss: 3180296404992.0000 - val_mean_absolute_percentage_error: 18.8469
# Epoch 2960/3000
# 680/680 - 2s - 4ms/step - loss: 2355937935360.0000 - mean_absolute_percentage_error: 19.6119 - val_loss: 3200915079168.0000 - val_mean_absolute_percentage_error: 18.9012
# Epoch 2961/3000
# 680/680 - 3s - 5ms/step - loss: 2355961790464.0000 - mean_absolute_percentage_error: 19.5855 - val_loss: 3202604335104.0000 - val_mean_absolute_percentage_error: 18.9055
# Epoch 2962/3000
# 680/680 - 2s - 3ms/step - loss: 2355962839040.0000 - mean_absolute_percentage_error: 19.5744 - val_loss: 3195353694208.0000 - val_mean_absolute_percentage_error: 18.8862
# Epoch 2963/3000
# 680/680 - 3s - 4ms/step - loss: 2355849592832.0000 - mean_absolute_percentage_error: 19.5782 - val_loss: 3187208355840.0000 - val_mean_absolute_percentage_error: 18.8647
# Epoch 2964/3000
# 680/680 - 1s - 2ms/step - loss: 2355831504896.0000 - mean_absolute_percentage_error: 19.5902 - val_loss: 3187520045056.0000 - val_mean_absolute_percentage_error: 18.8654
# Epoch 2965/3000
# 680/680 - 3s - 4ms/step - loss: 2355886817280.0000 - mean_absolute_percentage_error: 19.5849 - val_loss: 3193408847872.0000 - val_mean_absolute_percentage_error: 18.8814
# Epoch 2966/3000
# 680/680 - 3s - 5ms/step - loss: 2355807911936.0000 - mean_absolute_percentage_error: 19.5937 - val_loss: 3196608053248.0000 - val_mean_absolute_percentage_error: 18.8897
# Epoch 2967/3000
# 680/680 - 2s - 3ms/step - loss: 2355796377600.0000 - mean_absolute_percentage_error: 19.5792 - val_loss: 3187946291200.0000 - val_mean_absolute_percentage_error: 18.8671
# Epoch 2968/3000
# 680/680 - 2s - 3ms/step - loss: 2355774357504.0000 - mean_absolute_percentage_error: 19.5896 - val_loss: 3194688372736.0000 - val_mean_absolute_percentage_error: 18.8850
# Epoch 2969/3000
# 680/680 - 1s - 2ms/step - loss: 2355744210944.0000 - mean_absolute_percentage_error: 19.5756 - val_loss: 3189824815104.0000 - val_mean_absolute_percentage_error: 18.8718
# Epoch 2970/3000
# 680/680 - 2s - 2ms/step - loss: 2355707772928.0000 - mean_absolute_percentage_error: 19.5826 - val_loss: 3189460697088.0000 - val_mean_absolute_percentage_error: 18.8705
# Epoch 2971/3000
# 680/680 - 2s - 2ms/step - loss: 2355707248640.0000 - mean_absolute_percentage_error: 19.5748 - val_loss: 3179247828992.0000 - val_mean_absolute_percentage_error: 18.8437
# Epoch 2972/3000
# 680/680 - 2s - 2ms/step - loss: 2355647741952.0000 - mean_absolute_percentage_error: 19.6082 - val_loss: 3201151795200.0000 - val_mean_absolute_percentage_error: 18.9016
# Epoch 2973/3000
# 680/680 - 2s - 2ms/step - loss: 2355609993216.0000 - mean_absolute_percentage_error: 19.5959 - val_loss: 3206237126656.0000 - val_mean_absolute_percentage_error: 18.9151
# Epoch 2974/3000
# 680/680 - 2s - 3ms/step - loss: 2355711180800.0000 - mean_absolute_percentage_error: 19.5777 - val_loss: 3201941635072.0000 - val_mean_absolute_percentage_error: 18.9042
# Epoch 2975/3000
# 680/680 - 2s - 3ms/step - loss: 2355606585344.0000 - mean_absolute_percentage_error: 19.5706 - val_loss: 3188755005440.0000 - val_mean_absolute_percentage_error: 18.8691
# Epoch 2976/3000
# 680/680 - 3s - 4ms/step - loss: 2355627819008.0000 - mean_absolute_percentage_error: 19.5894 - val_loss: 3193831948288.0000 - val_mean_absolute_percentage_error: 18.8822
# Epoch 2977/3000
# 680/680 - 3s - 4ms/step - loss: 2355549700096.0000 - mean_absolute_percentage_error: 19.5795 - val_loss: 3192918376448.0000 - val_mean_absolute_percentage_error: 18.8800
# Epoch 2978/3000
# 680/680 - 2s - 4ms/step - loss: 2355533709312.0000 - mean_absolute_percentage_error: 19.5688 - val_loss: 3182167064576.0000 - val_mean_absolute_percentage_error: 18.8515
# Epoch 2979/3000
# 680/680 - 4s - 5ms/step - loss: 2355541835776.0000 - mean_absolute_percentage_error: 19.5819 - val_loss: 3180306890752.0000 - val_mean_absolute_percentage_error: 18.8467
# Epoch 2980/3000
# 680/680 - 2s - 3ms/step - loss: 2355511164928.0000 - mean_absolute_percentage_error: 19.5947 - val_loss: 3184838574080.0000 - val_mean_absolute_percentage_error: 18.8580
# Epoch 2981/3000
# 680/680 - 2s - 2ms/step - loss: 2355446939648.0000 - mean_absolute_percentage_error: 19.5967 - val_loss: 3196637937664.0000 - val_mean_absolute_percentage_error: 18.8896
# Epoch 2982/3000
# 680/680 - 3s - 4ms/step - loss: 2355392151552.0000 - mean_absolute_percentage_error: 19.5637 - val_loss: 3185332715520.0000 - val_mean_absolute_percentage_error: 18.8598
# Epoch 2983/3000
# 680/680 - 2s - 2ms/step - loss: 2355407618048.0000 - mean_absolute_percentage_error: 19.5958 - val_loss: 3192447827968.0000 - val_mean_absolute_percentage_error: 18.8784
# Epoch 2984/3000
# 680/680 - 3s - 4ms/step - loss: 2355415482368.0000 - mean_absolute_percentage_error: 19.5798 - val_loss: 3192832655360.0000 - val_mean_absolute_percentage_error: 18.8793
# Epoch 2985/3000
# 680/680 - 3s - 5ms/step - loss: 2355365412864.0000 - mean_absolute_percentage_error: 19.5887 - val_loss: 3193016942592.0000 - val_mean_absolute_percentage_error: 18.8800
# Epoch 2986/3000
# 680/680 - 2s - 3ms/step - loss: 2355338936320.0000 - mean_absolute_percentage_error: 19.5659 - val_loss: 3183337013248.0000 - val_mean_absolute_percentage_error: 18.8549
# Epoch 2987/3000
# 680/680 - 2s - 3ms/step - loss: 2355337887744.0000 - mean_absolute_percentage_error: 19.6009 - val_loss: 3200368246784.0000 - val_mean_absolute_percentage_error: 18.8996
# Epoch 2988/3000
# 680/680 - 3s - 4ms/step - loss: 2355311411200.0000 - mean_absolute_percentage_error: 19.5859 - val_loss: 3201414725632.0000 - val_mean_absolute_percentage_error: 18.9024
# Epoch 2989/3000
# 680/680 - 3s - 4ms/step - loss: 2355316654080.0000 - mean_absolute_percentage_error: 19.5841 - val_loss: 3196840574976.0000 - val_mean_absolute_percentage_error: 18.8905
# Epoch 2990/3000
# 680/680 - 3s - 4ms/step - loss: 2355264225280.0000 - mean_absolute_percentage_error: 19.5906 - val_loss: 3206647906304.0000 - val_mean_absolute_percentage_error: 18.9162
# Epoch 2991/3000
# 680/680 - 2s - 3ms/step - loss: 2355217039360.0000 - mean_absolute_percentage_error: 19.5789 - val_loss: 3199435538432.0000 - val_mean_absolute_percentage_error: 18.8973
# Epoch 2992/3000
# 680/680 - 2s - 3ms/step - loss: 2355225427968.0000 - mean_absolute_percentage_error: 19.5812 - val_loss: 3195851767808.0000 - val_mean_absolute_percentage_error: 18.8879
# Epoch 2993/3000
# 680/680 - 2s - 2ms/step - loss: 2355209961472.0000 - mean_absolute_percentage_error: 19.5810 - val_loss: 3194670022656.0000 - val_mean_absolute_percentage_error: 18.8844
# Epoch 2994/3000
# 680/680 - 2s - 2ms/step - loss: 2355174309888.0000 - mean_absolute_percentage_error: 19.5784 - val_loss: 3193711886336.0000 - val_mean_absolute_percentage_error: 18.8818
# Epoch 2995/3000
# 680/680 - 1s - 2ms/step - loss: 2355136036864.0000 - mean_absolute_percentage_error: 19.5751 - val_loss: 3191827857408.0000 - val_mean_absolute_percentage_error: 18.8770
# Epoch 2996/3000
# 680/680 - 3s - 4ms/step - loss: 2355136823296.0000 - mean_absolute_percentage_error: 19.5858 - val_loss: 3194403946496.0000 - val_mean_absolute_percentage_error: 18.8839
# Epoch 2997/3000
# 680/680 - 3s - 4ms/step - loss: 2355072073728.0000 - mean_absolute_percentage_error: 19.5928 - val_loss: 3202349268992.0000 - val_mean_absolute_percentage_error: 18.9045
# Epoch 2998/3000
# 680/680 - 2s - 3ms/step - loss: 2355088064512.0000 - mean_absolute_percentage_error: 19.5881 - val_loss: 3201238302720.0000 - val_mean_absolute_percentage_error: 18.9013
# Epoch 2999/3000
# 680/680 - 2s - 3ms/step - loss: 2355028819968.0000 - mean_absolute_percentage_error: 19.5645 - val_loss: 3193436372992.0000 - val_mean_absolute_percentage_error: 18.8811
# Epoch 3000/3000
# 680/680 - 2s - 2ms/step - loss: 2355001819136.0000 - mean_absolute_percentage_error: 19.5706 - val_loss: 3185996726272.0000 - val_mean_absolute_percentage_error: 18.8609
# CPU times: user 1h 31min 44s, sys: 3min 58s, total: 1h 35min 43s
# Wall time: 1h 51min 26s

# %%
new.save('model/model'+model_name+' '+str(data.columns.size-2)+'.keras')  # The file needs to end with the .keras extension
# uncomment to load
# new = tf.keras.models.load_model('model16-16 3.keras')
from sklearn.metrics import mean_squared_error
print(mean_squared_error(new.predict(X_train),y_train))
print(mean_squared_error(new.predict(X_val),y_val))
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2561922301952.0
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3049222307840.0

# %% [markdown]
# ### 2 Plots: mse loss and cross-validation loss

# %%
line1=plt.plot(history.history['loss'],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'],label='Validation Mean Squared Error')
plt.legend()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()
line1=plt.plot(history.history['loss'][100:],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'][100:],label='Validation Mean Squared Error')
plt.xticks( list(range(0,2000,200)), list(range(100,2000,200)))
list(range(len(line1)))
plt.legend()
plt.title('Loss after 100 epochs')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()

# %% [markdown]
# ### 3 Qualitative Plots

# %%
start_train=train_idx[0]
end_train=train_idx[15*24]
print(start_train)

start_val=val_idx[0]
end_val=val_idx[15*24]
print(start_val)

start_test=test_idx[45*24]
end_test=test_idx[45*24+15*24]
print(start_test)
# Out:
# 2018-08-02 04:00:00
# 2021-04-04 10:00:00
# 2021-11-16 17:00:00

# %%
y_train_prediction=new.predict(X_train)
y_val_prediction=new.predict(X_val)
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()

# %%
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas inflow", "predicted gas inflow"])

# %%
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas outflow", "predicted gas outflow"])

# %%
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

# %% [markdown]
# ## --

# %%
y_TEST_prediction=new.predict(X_test)

from sklearn.metrics import mean_absolute_percentage_error
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

mse_test_inflow=mean_squared_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mse_test_outflow=mean_squared_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse test inflow ',mse_test_inflow)
print('mse test outflow ',mse_test_outflow)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))

print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)

b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# mse_test:  3962687193088.0
# mse test inflow  3855884529861.1626
# mse test outflow  4069487864600.793
# mape_test:  0.1911945641040802
# mape test inflow  0.17915469776070056
# mape test outflow  0.20323475971171498

# %%
X_total_train=np.append(X_train,values=X_val,axis=0)
y_total_train=np.append(y_train,values=y_val,axis=0)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error
regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_train_prediction=regressor.predict(X_train)
y_val_prediction=regressor.predict(X_val)
y_TEST_prediction=regressor.predict(X_test)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse_train: ',mean_squared_error(y_train,y_train_prediction))
print('mse_val: ',mean_squared_error(y_val,y_val_prediction))
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

print('mape_train: ',mean_absolute_percentage_error(y_train,y_train_prediction))
print('mape_val: ',mean_absolute_percentage_error(y_val,y_val_prediction))
print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))


print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)
## train
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Training data')
plt.show()
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Training data')
plt.show()
## val
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Validation data')
plt.show()

b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

## test
b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Test data')
plt.show()

# print('mape test inflow 2022 6 ',mean_absolute_percentage_error(y_test['2022-6-20':'2022-6']['sum(physicalFlow)0 inflow'],pd.DataFrame(y_TEST_prediction,index=test_idx)['2022-6-20':'2022-6'][0]))

# b['2022-6':'2022-6']['gas outflow'].plot()
# b['2022-6':'2022-6']['prediction gas outflow'].plot()
# plt.legend(["gas outflow", "predicted gas outflow"])
# plt.title('Test data')
# Out:
# mse_train:  2495186000199.182
# mse_val:  3283774487665.349
# mse_test:  3852757611181.9287
# mape_train:  0.20096472156614587
# mape_val:  0.1899900955017627
# mape_test:  0.18181033550773262
# mape test inflow  0.17604202406760325
# mape test outflow  0.1875786469478627
