# %% [markdown]
# # Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import tensorflow as tf
from sklearn.metrics import mean_squared_error
# !pip install scikeras
# import scikeras

# %%
data=pd.read_csv('drive/MyDrive/Colab Notebooks/data.csv',delimiter=',',parse_dates=True,index_col=0)
# y=(data.iloc[:,-2]-data.iloc[:,-1])#.values
y=data.iloc[:,-2:]
X=data.iloc[:,:-2]#.values

# %%
y.std()
# Out:
# sum(physicalFlow)0 inflow     1.815534e+06
# sum(physicalFlow)1 outflow    2.205656e+06
# dtype: float64

# %%
y.mean()
# Out:
# sum(physicalFlow)0 inflow     7.223504e+06
# sum(physicalFlow)1 outflow    7.114683e+06
# dtype: float64

# %%
data
# Out:
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      sum(physicalFlow)0 inflow  sum(physicalFlow)1 outflow
# 2018-08-02 04:00:00                  5332486.0                   4084033.0
# 2018-08-02 05:00:00                  5425152.0                   4611564.0
# 2018-08-02 06:00:00                  5411656.0                   5204580.0
# 2018-08-02 07:00:00                  5792693.0                   5379787.0
# 2018-08-02 08:00:00                  5735920.0                   5706807.0
# ...                                        ...                         ...
# 2022-01-31 19:00:00                  7602602.0                  11077110.0
# 2022-01-31 20:00:00                  7418126.0                  10019737.0
# 2022-01-31 21:00:00                  7407216.0                   9476736.0
# 2022-01-31 22:00:00                  7398530.0                   8326807.0
# 2022-01-31 23:00:00                  7374867.0                   7325447.0
#
# [29001 rows x 5 columns]

# %% [markdown]
# # Feature engineering

# %%
f=lambda x: x.hour
ff=np.vectorize(f)
hour_of_day=ff(X.index.to_pydatetime())
X.loc[:, "hour"]=hour_of_day
X
# Out:
# <ipython-input-7-53c44885d1b3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:, "hour"]=hour_of_day
#                      WindGenForecast  SolarGenForecast  TotalLoadForecast  \
# 2018-08-02 04:00:00            470.0             158.0             5745.0
# 2018-08-02 05:00:00            520.0             478.0             6465.0
# 2018-08-02 06:00:00            550.0             871.0             7108.0
# 2018-08-02 07:00:00            570.0            1227.0             7494.0
# 2018-08-02 08:00:00            580.0            1473.0             7779.0
# ...                              ...               ...                ...
# 2022-01-31 19:00:00           1483.0               0.0             7594.0
# 2022-01-31 20:00:00           1594.0               0.0             6893.0
# 2022-01-31 21:00:00           1668.0               0.0             6406.0
# 2022-01-31 22:00:00           1740.0               0.0             5799.0
# 2022-01-31 23:00:00           1705.0               0.0             5223.0
#
#                      hour
# 2018-08-02 04:00:00     4
# 2018-08-02 05:00:00     5
# 2018-08-02 06:00:00     6
# 2018-08-02 07:00:00     7
# 2018-08-02 08:00:00     8
# ...                   ...
# 2022-01-31 19:00:00    19
# 2022-01-31 20:00:00    20
# 2022-01-31 21:00:00    21
# 2022-01-31 22:00:00    22
# 2022-01-31 23:00:00    23
#
# [29001 rows x 4 columns]

# %% [markdown]
# # Split input data in 3 sets (train, validation, testing)

# %%
# https://datascience.stackexchange.com/questions/15135/train-test-validation-set-splitting-in-sklearn
from sklearn.model_selection import train_test_split

train_ratio = 0.75 # training
validation_ratio = 0.15 # hyperparameter tuning
test_ratio = 0.10 # final evaluation

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=test_ratio,shuffle=False, random_state=1234)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=validation_ratio/(1-test_ratio),shuffle=False, random_state=1)

# print('train percent',X_train.index.size/X.index.size)
# print('validation percent',X_val.index.size/X.index.size)
# print('test percent',X_test.index.size/X.index.size)
print('train percent',y_train.index.size/X.index.size, '\ttrain days',y_train.index.size/24 )
print('validation percent',y_val.index.size/X.index.size,'\tvalid days',y_val.index.size/24)
print('test percent',y_test.index.size/X.index.size,'\ttest days',y_test.index.size/24)
# print('train percent',y_train.size/X.size, '\ttrain days',y_train.index.size/24 )
# Out:
# train percent 0.7499741388227992 	train days 906.25
# validation percent 0.14999482776455983 	valid days 181.25
# test percent 0.10003103341264094 	test days 120.875

# %%
train_idx=X_train.index
val_idx=X_val.index
test_idx=X_test.index
test_idx
# Out:
# DatetimeIndex(['2021-10-02 16:00:00', '2021-10-02 17:00:00',
#                '2021-10-02 18:00:00', '2021-10-02 19:00:00',
#                '2021-10-02 20:00:00', '2021-10-02 21:00:00',
#                '2021-10-02 22:00:00', '2021-10-02 23:00:00',
#                '2021-10-03 00:00:00', '2021-10-03 01:00:00',
#                ...
#                '2022-01-31 14:00:00', '2022-01-31 15:00:00',
#                '2022-01-31 16:00:00', '2022-01-31 17:00:00',
#                '2022-01-31 18:00:00', '2022-01-31 19:00:00',
#                '2022-01-31 20:00:00', '2022-01-31 21:00:00',
#                '2022-01-31 22:00:00', '2022-01-31 23:00:00'],
#               dtype='datetime64[ns]', length=2901, freq=None)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()


X_train=sc.fit_transform(X_train)
X_val=sc.transform(X_val)
X_test=sc.transform(X_test)

# %%
# from sklearn.utils import shuffle
# X_train_shuffled, y_train_shuffled = shuffle(X_train, y_train, random_state=42)

# %%
X_train
# Out:
# array([[-0.70473316, -0.44212536, -0.04271406, -1.08333581],
#        [-0.61317217,  0.11094688,  0.58407691, -0.93886447],
#        [-0.55823558,  0.79018873,  1.14383607, -0.79439312],
#        ...,
#        [ 1.11916167,  1.31215066, -0.59028562, -0.64992178],
#        [ 1.18142314,  1.83756929, -0.35001575, -0.50545043],
#        [ 1.18325436,  2.11756211, -0.22726918, -0.36097909]])

# %% [markdown]
# # Training neural networks

# %% [markdown]
# ## hidden layers: 32-32

# %% [markdown]
# ### 1 model creation + training process

# %%
# %%time
model_name='32-32'
def new_nn():
  ann=tf.keras.models.Sequential()
  ann.add(tf.keras.layers.Dense(units=32,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=32,activation='relu'))
  ann.add(tf.keras.layers.Dense(units=2,activation='linear'))
  ann.compile(optimizer='adam',loss=tf.keras.losses.MeanSquaredError(),metrics=[tf.keras.metrics.MeanAbsolutePercentageError()])
  return ann

earlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',start_from_epoch=5, patience=2500,restore_best_weights=True)
modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath='{epoch:02d}-32-32-1.keras',save_freq='epoch')

new=new_nn()
history=new.fit(X_train,y_train,epochs=3000,validation_data=(X_val,y_val),callbacks=[earlyStop,modelCheckpoint],verbose=2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 317/3000
# 680/680 - 2s - 3ms/step - loss: 2581090271232.0000 - mean_absolute_percentage_error: 20.5800 - val_loss: 3057860214784.0000 - val_mean_absolute_percentage_error: 18.2254
# Epoch 318/3000
# 680/680 - 2s - 2ms/step - loss: 2579585302528.0000 - mean_absolute_percentage_error: 20.5629 - val_loss: 3056926982144.0000 - val_mean_absolute_percentage_error: 18.2222
# Epoch 319/3000
# 680/680 - 3s - 4ms/step - loss: 2577995661312.0000 - mean_absolute_percentage_error: 20.5606 - val_loss: 3071149080576.0000 - val_mean_absolute_percentage_error: 18.2603
# Epoch 320/3000
# 680/680 - 3s - 4ms/step - loss: 2576496459776.0000 - mean_absolute_percentage_error: 20.5379 - val_loss: 3056934584320.0000 - val_mean_absolute_percentage_error: 18.2207
# Epoch 321/3000
# 680/680 - 2s - 3ms/step - loss: 2574872739840.0000 - mean_absolute_percentage_error: 20.5300 - val_loss: 3053384630272.0000 - val_mean_absolute_percentage_error: 18.2109
# Epoch 322/3000
# 680/680 - 3s - 4ms/step - loss: 2573264748544.0000 - mean_absolute_percentage_error: 20.5247 - val_loss: 3046951092224.0000 - val_mean_absolute_percentage_error: 18.1941
# Epoch 323/3000
# 680/680 - 2s - 2ms/step - loss: 2571758993408.0000 - mean_absolute_percentage_error: 20.5319 - val_loss: 3054225326080.0000 - val_mean_absolute_percentage_error: 18.2138
# Epoch 324/3000
# 680/680 - 2s - 2ms/step - loss: 2570126360576.0000 - mean_absolute_percentage_error: 20.5093 - val_loss: 3047209566208.0000 - val_mean_absolute_percentage_error: 18.1938
# Epoch 325/3000
# 680/680 - 3s - 4ms/step - loss: 2568620605440.0000 - mean_absolute_percentage_error: 20.5261 - val_loss: 3058926616576.0000 - val_mean_absolute_percentage_error: 18.2243
# Epoch 326/3000
# 680/680 - 2s - 4ms/step - loss: 2567007633408.0000 - mean_absolute_percentage_error: 20.4961 - val_loss: 3057443143680.0000 - val_mean_absolute_percentage_error: 18.2205
# Epoch 327/3000
# 680/680 - 3s - 5ms/step - loss: 2565461245952.0000 - mean_absolute_percentage_error: 20.4968 - val_loss: 3053206634496.0000 - val_mean_absolute_percentage_error: 18.2098
# Epoch 328/3000
# 680/680 - 2s - 4ms/step - loss: 2563793223680.0000 - mean_absolute_percentage_error: 20.4832 - val_loss: 3048886501376.0000 - val_mean_absolute_percentage_error: 18.1976
# Epoch 329/3000
# 680/680 - 2s - 2ms/step - loss: 2562163998720.0000 - mean_absolute_percentage_error: 20.4749 - val_loss: 3047654686720.0000 - val_mean_absolute_percentage_error: 18.1937
# Epoch 330/3000
# 680/680 - 3s - 4ms/step - loss: 2560561774592.0000 - mean_absolute_percentage_error: 20.4867 - val_loss: 3057440522240.0000 - val_mean_absolute_percentage_error: 18.2191
# Epoch 331/3000
# 680/680 - 3s - 4ms/step - loss: 2558897160192.0000 - mean_absolute_percentage_error: 20.4530 - val_loss: 3042902016000.0000 - val_mean_absolute_percentage_error: 18.1818
# Epoch 332/3000
# 680/680 - 2s - 2ms/step - loss: 2557301227520.0000 - mean_absolute_percentage_error: 20.4647 - val_loss: 3047446806528.0000 - val_mean_absolute_percentage_error: 18.1932
# Epoch 333/3000
# 680/680 - 4s - 5ms/step - loss: 2555602010112.0000 - mean_absolute_percentage_error: 20.4526 - val_loss: 3047643938816.0000 - val_mean_absolute_percentage_error: 18.1927
# Epoch 334/3000
# 680/680 - 4s - 6ms/step - loss: 2553883656192.0000 - mean_absolute_percentage_error: 20.4694 - val_loss: 3076984930304.0000 - val_mean_absolute_percentage_error: 18.2701
# Epoch 335/3000
# 680/680 - 2s - 4ms/step - loss: 2552151146496.0000 - mean_absolute_percentage_error: 20.4030 - val_loss: 3037709991936.0000 - val_mean_absolute_percentage_error: 18.1654
# Epoch 336/3000
# 680/680 - 2s - 2ms/step - loss: 2550758637568.0000 - mean_absolute_percentage_error: 20.4412 - val_loss: 3054273822720.0000 - val_mean_absolute_percentage_error: 18.2102
# Epoch 337/3000
# 680/680 - 2s - 2ms/step - loss: 2549160607744.0000 - mean_absolute_percentage_error: 20.4244 - val_loss: 3054455488512.0000 - val_mean_absolute_percentage_error: 18.2107
# Epoch 338/3000
# 680/680 - 2s - 3ms/step - loss: 2547479478272.0000 - mean_absolute_percentage_error: 20.4088 - val_loss: 3048268365824.0000 - val_mean_absolute_percentage_error: 18.1946
# Epoch 339/3000
# 680/680 - 3s - 4ms/step - loss: 2545928372224.0000 - mean_absolute_percentage_error: 20.4083 - val_loss: 3044110761984.0000 - val_mean_absolute_percentage_error: 18.1828
# Epoch 340/3000
# 680/680 - 2s - 3ms/step - loss: 2544332701696.0000 - mean_absolute_percentage_error: 20.3980 - val_loss: 3045342052352.0000 - val_mean_absolute_percentage_error: 18.1879
# Epoch 341/3000
# 680/680 - 2s - 2ms/step - loss: 2542773993472.0000 - mean_absolute_percentage_error: 20.3965 - val_loss: 3048554889216.0000 - val_mean_absolute_percentage_error: 18.1961
# Epoch 342/3000
# 680/680 - 2s - 4ms/step - loss: 2541268500480.0000 - mean_absolute_percentage_error: 20.3906 - val_loss: 3050766073856.0000 - val_mean_absolute_percentage_error: 18.2019
# Epoch 343/3000
# 680/680 - 2s - 2ms/step - loss: 2539639799808.0000 - mean_absolute_percentage_error: 20.3917 - val_loss: 3069174349824.0000 - val_mean_absolute_percentage_error: 18.2510
# Epoch 344/3000
# 680/680 - 3s - 4ms/step - loss: 2538089480192.0000 - mean_absolute_percentage_error: 20.3469 - val_loss: 3040951140352.0000 - val_mean_absolute_percentage_error: 18.1757
# Epoch 345/3000
# 680/680 - 3s - 4ms/step - loss: 2536736030720.0000 - mean_absolute_percentage_error: 20.3725 - val_loss: 3051220631552.0000 - val_mean_absolute_percentage_error: 18.2019
# Epoch 346/3000
# 680/680 - 2s - 2ms/step - loss: 2535193313280.0000 - mean_absolute_percentage_error: 20.3589 - val_loss: 3049170927616.0000 - val_mean_absolute_percentage_error: 18.1968
# Epoch 347/3000
# 680/680 - 3s - 4ms/step - loss: 2533724782592.0000 - mean_absolute_percentage_error: 20.3570 - val_loss: 3054196752384.0000 - val_mean_absolute_percentage_error: 18.2125
# Epoch 348/3000
# 680/680 - 2s - 2ms/step - loss: 2532341710848.0000 - mean_absolute_percentage_error: 20.3410 - val_loss: 3055192637440.0000 - val_mean_absolute_percentage_error: 18.2143
# Epoch 349/3000
# 680/680 - 2s - 2ms/step - loss: 2530797682688.0000 - mean_absolute_percentage_error: 20.3220 - val_loss: 3043937746944.0000 - val_mean_absolute_percentage_error: 18.1858
# Epoch 350/3000
# 680/680 - 2s - 2ms/step - loss: 2529475166208.0000 - mean_absolute_percentage_error: 20.3499 - val_loss: 3056037789696.0000 - val_mean_absolute_percentage_error: 18.2176
# Epoch 351/3000
# 680/680 - 3s - 5ms/step - loss: 2528081084416.0000 - mean_absolute_percentage_error: 20.3119 - val_loss: 3050003759104.0000 - val_mean_absolute_percentage_error: 18.2025
# Epoch 352/3000
# 680/680 - 4s - 6ms/step - loss: 2526715314176.0000 - mean_absolute_percentage_error: 20.3171 - val_loss: 3049779625984.0000 - val_mean_absolute_percentage_error: 18.2016
# Epoch 353/3000
# 680/680 - 3s - 4ms/step - loss: 2525421109248.0000 - mean_absolute_percentage_error: 20.3219 - val_loss: 3064723931136.0000 - val_mean_absolute_percentage_error: 18.2424
# Epoch 354/3000
# 680/680 - 2s - 2ms/step - loss: 2524120612864.0000 - mean_absolute_percentage_error: 20.2975 - val_loss: 3055960195072.0000 - val_mean_absolute_percentage_error: 18.2197
# Epoch 355/3000
# 680/680 - 3s - 4ms/step - loss: 2522799669248.0000 - mean_absolute_percentage_error: 20.3074 - val_loss: 3064888557568.0000 - val_mean_absolute_percentage_error: 18.2453
# Epoch 356/3000
# 680/680 - 3s - 4ms/step - loss: 2521640730624.0000 - mean_absolute_percentage_error: 20.2816 - val_loss: 3049343680512.0000 - val_mean_absolute_percentage_error: 18.2051
# Epoch 357/3000
# 680/680 - 4s - 6ms/step - loss: 2520362516480.0000 - mean_absolute_percentage_error: 20.3063 - val_loss: 3074525757440.0000 - val_mean_absolute_percentage_error: 18.2730
# Epoch 358/3000
# 680/680 - 2s - 2ms/step - loss: 2519226908672.0000 - mean_absolute_percentage_error: 20.2631 - val_loss: 3056027303936.0000 - val_mean_absolute_percentage_error: 18.2249
# Epoch 359/3000
# 680/680 - 2s - 2ms/step - loss: 2518019735552.0000 - mean_absolute_percentage_error: 20.2918 - val_loss: 3078028263424.0000 - val_mean_absolute_percentage_error: 18.2829
# Epoch 360/3000
# 680/680 - 3s - 4ms/step - loss: 2516950188032.0000 - mean_absolute_percentage_error: 20.2512 - val_loss: 3049775431680.0000 - val_mean_absolute_percentage_error: 18.2083
# Epoch 361/3000
# 680/680 - 4s - 5ms/step - loss: 2515800424448.0000 - mean_absolute_percentage_error: 20.2831 - val_loss: 3074209873920.0000 - val_mean_absolute_percentage_error: 18.2740
# Epoch 362/3000
# 680/680 - 2s - 2ms/step - loss: 2514758926336.0000 - mean_absolute_percentage_error: 20.2461 - val_loss: 3059937968128.0000 - val_mean_absolute_percentage_error: 18.2368
# Epoch 363/3000
# 680/680 - 2s - 4ms/step - loss: 2513601560576.0000 - mean_absolute_percentage_error: 20.2770 - val_loss: 3085639090176.0000 - val_mean_absolute_percentage_error: 18.3064
# Epoch 364/3000
# 680/680 - 2s - 2ms/step - loss: 2512694542336.0000 - mean_absolute_percentage_error: 20.2201 - val_loss: 3061822783488.0000 - val_mean_absolute_percentage_error: 18.2452
# Epoch 365/3000
# 680/680 - 2s - 2ms/step - loss: 2511680307200.0000 - mean_absolute_percentage_error: 20.2411 - val_loss: 3054641872896.0000 - val_mean_absolute_percentage_error: 18.2278
# Epoch 366/3000
# 680/680 - 2s - 2ms/step - loss: 2510658732032.0000 - mean_absolute_percentage_error: 20.2407 - val_loss: 3061612019712.0000 - val_mean_absolute_percentage_error: 18.2463
# Epoch 367/3000
# 680/680 - 4s - 5ms/step - loss: 2509787365376.0000 - mean_absolute_percentage_error: 20.2322 - val_loss: 3057998364672.0000 - val_mean_absolute_percentage_error: 18.2382
# Epoch 368/3000
# 680/680 - 4s - 6ms/step - loss: 2508666175488.0000 - mean_absolute_percentage_error: 20.2163 - val_loss: 3045364334592.0000 - val_mean_absolute_percentage_error: 18.2070
# Epoch 369/3000
# 680/680 - 3s - 4ms/step - loss: 2507902025728.0000 - mean_absolute_percentage_error: 20.2511 - val_loss: 3072671875072.0000 - val_mean_absolute_percentage_error: 18.2774
# Epoch 370/3000
# 680/680 - 3s - 4ms/step - loss: 2507017814016.0000 - mean_absolute_percentage_error: 20.2077 - val_loss: 3065931628544.0000 - val_mean_absolute_percentage_error: 18.2633
# Epoch 371/3000
# 680/680 - 3s - 5ms/step - loss: 2506168991744.0000 - mean_absolute_percentage_error: 20.2241 - val_loss: 3073859649536.0000 - val_mean_absolute_percentage_error: 18.2838
# Epoch 372/3000
# 680/680 - 2s - 3ms/step - loss: 2505286877184.0000 - mean_absolute_percentage_error: 20.2027 - val_loss: 3064966938624.0000 - val_mean_absolute_percentage_error: 18.2609
# Epoch 373/3000
# 680/680 - 2s - 3ms/step - loss: 2504497823744.0000 - mean_absolute_percentage_error: 20.2209 - val_loss: 3078419906560.0000 - val_mean_absolute_percentage_error: 18.2967
# Epoch 374/3000
# 680/680 - 2s - 4ms/step - loss: 2503698546688.0000 - mean_absolute_percentage_error: 20.1857 - val_loss: 3061030322176.0000 - val_mean_absolute_percentage_error: 18.2537
# Epoch 375/3000
# 680/680 - 3s - 4ms/step - loss: 2502942523392.0000 - mean_absolute_percentage_error: 20.2041 - val_loss: 3068052373504.0000 - val_mean_absolute_percentage_error: 18.2719
# Epoch 376/3000
# 680/680 - 2s - 4ms/step - loss: 2502229753856.0000 - mean_absolute_percentage_error: 20.1983 - val_loss: 3066676903936.0000 - val_mean_absolute_percentage_error: 18.2689
# Epoch 377/3000
# 680/680 - 3s - 4ms/step - loss: 2501446729728.0000 - mean_absolute_percentage_error: 20.1922 - val_loss: 3072564396032.0000 - val_mean_absolute_percentage_error: 18.2861
# Epoch 378/3000
# 680/680 - 2s - 3ms/step - loss: 2500583227392.0000 - mean_absolute_percentage_error: 20.2039 - val_loss: 3085949206528.0000 - val_mean_absolute_percentage_error: 18.3205
# Epoch 379/3000
# 680/680 - 2s - 3ms/step - loss: 2500098523136.0000 - mean_absolute_percentage_error: 20.1684 - val_loss: 3073380188160.0000 - val_mean_absolute_percentage_error: 18.2896
# Epoch 380/3000
# 680/680 - 3s - 4ms/step - loss: 2499272507392.0000 - mean_absolute_percentage_error: 20.1560 - val_loss: 3058048434176.0000 - val_mean_absolute_percentage_error: 18.2519
# Epoch 381/3000
# 680/680 - 3s - 4ms/step - loss: 2498671673344.0000 - mean_absolute_percentage_error: 20.1973 - val_loss: 3076215799808.0000 - val_mean_absolute_percentage_error: 18.2987
# Epoch 382/3000
# 680/680 - 2s - 2ms/step - loss: 2498039382016.0000 - mean_absolute_percentage_error: 20.1775 - val_loss: 3078638272512.0000 - val_mean_absolute_percentage_error: 18.3057
# Epoch 383/3000
# 680/680 - 4s - 5ms/step - loss: 2497294893056.0000 - mean_absolute_percentage_error: 20.1485 - val_loss: 3055020670976.0000 - val_mean_absolute_percentage_error: 18.2465
# Epoch 384/3000
# 680/680 - 2s - 2ms/step - loss: 2496809926656.0000 - mean_absolute_percentage_error: 20.1713 - val_loss: 3066532724736.0000 - val_mean_absolute_percentage_error: 18.2775
# Epoch 385/3000
# 680/680 - 2s - 2ms/step - loss: 2496095322112.0000 - mean_absolute_percentage_error: 20.1525 - val_loss: 3065184780288.0000 - val_mean_absolute_percentage_error: 18.2767
# Epoch 386/3000
# 680/680 - 3s - 4ms/step - loss: 2495657541632.0000 - mean_absolute_percentage_error: 20.1732 - val_loss: 3073641021440.0000 - val_mean_absolute_percentage_error: 18.2986
# Epoch 387/3000
# 680/680 - 3s - 4ms/step - loss: 2495101009920.0000 - mean_absolute_percentage_error: 20.1636 - val_loss: 3084547784704.0000 - val_mean_absolute_percentage_error: 18.3276
# Epoch 388/3000
# 680/680 - 2s - 2ms/step - loss: 2494456922112.0000 - mean_absolute_percentage_error: 20.1636 - val_loss: 3089947951104.0000 - val_mean_absolute_percentage_error: 18.3426
# Epoch 389/3000
# 680/680 - 3s - 5ms/step - loss: 2493875748864.0000 - mean_absolute_percentage_error: 20.1319 - val_loss: 3069177233408.0000 - val_mean_absolute_percentage_error: 18.2901
# Epoch 390/3000
# 680/680 - 2s - 3ms/step - loss: 2493316071424.0000 - mean_absolute_percentage_error: 20.1670 - val_loss: 3089726963712.0000 - val_mean_absolute_percentage_error: 18.3436
# Epoch 391/3000
# 680/680 - 2s - 2ms/step - loss: 2492824027136.0000 - mean_absolute_percentage_error: 20.1291 - val_loss: 3073768947712.0000 - val_mean_absolute_percentage_error: 18.3048
# Epoch 392/3000
# 680/680 - 3s - 4ms/step - loss: 2492362915840.0000 - mean_absolute_percentage_error: 20.1430 - val_loss: 3074095841280.0000 - val_mean_absolute_percentage_error: 18.3070
# Epoch 393/3000
# 680/680 - 3s - 4ms/step - loss: 2491871133696.0000 - mean_absolute_percentage_error: 20.1379 - val_loss: 3072855113728.0000 - val_mean_absolute_percentage_error: 18.3055
# Epoch 394/3000
# 680/680 - 3s - 5ms/step - loss: 2491271086080.0000 - mean_absolute_percentage_error: 20.1369 - val_loss: 3079166492672.0000 - val_mean_absolute_percentage_error: 18.3246
# Epoch 395/3000
# 680/680 - 2s - 3ms/step - loss: 2490823868416.0000 - mean_absolute_percentage_error: 20.1382 - val_loss: 3080328577024.0000 - val_mean_absolute_percentage_error: 18.3271
# Epoch 396/3000
# 680/680 - 2s - 3ms/step - loss: 2490336280576.0000 - mean_absolute_percentage_error: 20.1269 - val_loss: 3073613496320.0000 - val_mean_absolute_percentage_error: 18.3110
# Epoch 397/3000
# 680/680 - 2s - 4ms/step - loss: 2489893257216.0000 - mean_absolute_percentage_error: 20.1273 - val_loss: 3078267863040.0000 - val_mean_absolute_percentage_error: 18.3240
# Epoch 398/3000
# 680/680 - 3s - 4ms/step - loss: 2489458098176.0000 - mean_absolute_percentage_error: 20.1351 - val_loss: 3080912371712.0000 - val_mean_absolute_percentage_error: 18.3322
# Epoch 399/3000
# 680/680 - 3s - 4ms/step - loss: 2488969723904.0000 - mean_absolute_percentage_error: 20.1234 - val_loss: 3085495959552.0000 - val_mean_absolute_percentage_error: 18.3448
# Epoch 400/3000
# 680/680 - 4s - 5ms/step - loss: 2488505991168.0000 - mean_absolute_percentage_error: 20.1221 - val_loss: 3081915072512.0000 - val_mean_absolute_percentage_error: 18.3355
# Epoch 401/3000
# 680/680 - 2s - 2ms/step - loss: 2488055103488.0000 - mean_absolute_percentage_error: 20.1082 - val_loss: 3071291424768.0000 - val_mean_absolute_percentage_error: 18.3109
# Epoch 402/3000
# 680/680 - 2s - 2ms/step - loss: 2487697539072.0000 - mean_absolute_percentage_error: 20.1218 - val_loss: 3077006163968.0000 - val_mean_absolute_percentage_error: 18.3253
# Epoch 403/3000
# 680/680 - 3s - 4ms/step - loss: 2487234330624.0000 - mean_absolute_percentage_error: 20.1171 - val_loss: 3072488374272.0000 - val_mean_absolute_percentage_error: 18.3154
# Epoch 404/3000
# 680/680 - 2s - 2ms/step - loss: 2486749888512.0000 - mean_absolute_percentage_error: 20.1096 - val_loss: 3075305373696.0000 - val_mean_absolute_percentage_error: 18.3242
# Epoch 405/3000
# 680/680 - 3s - 4ms/step - loss: 2486401499136.0000 - mean_absolute_percentage_error: 20.1124 - val_loss: 3075144679424.0000 - val_mean_absolute_percentage_error: 18.3254
# Epoch 406/3000
# 680/680 - 4s - 5ms/step - loss: 2485859123200.0000 - mean_absolute_percentage_error: 20.1290 - val_loss: 3098252673024.0000 - val_mean_absolute_percentage_error: 18.3850
# Epoch 407/3000
# 680/680 - 4s - 6ms/step - loss: 2485611397120.0000 - mean_absolute_percentage_error: 20.0939 - val_loss: 3082824974336.0000 - val_mean_absolute_percentage_error: 18.3474
# Epoch 408/3000
# 680/680 - 3s - 4ms/step - loss: 2484988018688.0000 - mean_absolute_percentage_error: 20.0966 - val_loss: 3070697144320.0000 - val_mean_absolute_percentage_error: 18.3170
# Epoch 409/3000
# 680/680 - 2s - 4ms/step - loss: 2484710408192.0000 - mean_absolute_percentage_error: 20.1080 - val_loss: 3075057909760.0000 - val_mean_absolute_percentage_error: 18.3291
# Epoch 410/3000
# 680/680 - 4s - 5ms/step - loss: 2484279705600.0000 - mean_absolute_percentage_error: 20.1138 - val_loss: 3084860260352.0000 - val_mean_absolute_percentage_error: 18.3547
# Epoch 411/3000
# 680/680 - 4s - 6ms/step - loss: 2483872858112.0000 - mean_absolute_percentage_error: 20.1076 - val_loss: 3095939514368.0000 - val_mean_absolute_percentage_error: 18.3841
# Epoch 412/3000
# 680/680 - 3s - 4ms/step - loss: 2483458932736.0000 - mean_absolute_percentage_error: 20.0911 - val_loss: 3086475853824.0000 - val_mean_absolute_percentage_error: 18.3606
# Epoch 413/3000
# 680/680 - 2s - 4ms/step - loss: 2483094552576.0000 - mean_absolute_percentage_error: 20.0852 - val_loss: 3081184215040.0000 - val_mean_absolute_percentage_error: 18.3495
# Epoch 414/3000
# 680/680 - 4s - 5ms/step - loss: 2482644713472.0000 - mean_absolute_percentage_error: 20.1157 - val_loss: 3099772059648.0000 - val_mean_absolute_percentage_error: 18.3971
# Epoch 415/3000
# 680/680 - 2s - 3ms/step - loss: 2482428444672.0000 - mean_absolute_percentage_error: 20.0815 - val_loss: 3093526740992.0000 - val_mean_absolute_percentage_error: 18.3821
# Epoch 416/3000
# 680/680 - 2s - 3ms/step - loss: 2482032345088.0000 - mean_absolute_percentage_error: 20.0884 - val_loss: 3090368692224.0000 - val_mean_absolute_percentage_error: 18.3753
# Epoch 417/3000
# 680/680 - 2s - 2ms/step - loss: 2481551835136.0000 - mean_absolute_percentage_error: 20.0995 - val_loss: 3104018006016.0000 - val_mean_absolute_percentage_error: 18.4113
# Epoch 418/3000
# 680/680 - 2s - 2ms/step - loss: 2481339498496.0000 - mean_absolute_percentage_error: 20.0774 - val_loss: 3092492320768.0000 - val_mean_absolute_percentage_error: 18.3826
# Epoch 419/3000
# 680/680 - 3s - 4ms/step - loss: 2480894640128.0000 - mean_absolute_percentage_error: 20.0765 - val_loss: 3087666774016.0000 - val_mean_absolute_percentage_error: 18.3720
# Epoch 420/3000
# 680/680 - 3s - 5ms/step - loss: 2480504832000.0000 - mean_absolute_percentage_error: 20.0800 - val_loss: 3086880079872.0000 - val_mean_absolute_percentage_error: 18.3710
# Epoch 421/3000
# 680/680 - 2s - 3ms/step - loss: 2480237182976.0000 - mean_absolute_percentage_error: 20.0884 - val_loss: 3096567873536.0000 - val_mean_absolute_percentage_error: 18.3950
# Epoch 422/3000
# 680/680 - 2s - 3ms/step - loss: 2479808053248.0000 - mean_absolute_percentage_error: 20.0805 - val_loss: 3095017029632.0000 - val_mean_absolute_percentage_error: 18.3929
# Epoch 423/3000
# 680/680 - 2s - 2ms/step - loss: 2479511568384.0000 - mean_absolute_percentage_error: 20.0759 - val_loss: 3089948475392.0000 - val_mean_absolute_percentage_error: 18.3796
# Epoch 424/3000
# 680/680 - 3s - 4ms/step - loss: 2479122284544.0000 - mean_absolute_percentage_error: 20.0841 - val_loss: 3096529862656.0000 - val_mean_absolute_percentage_error: 18.3972
# Epoch 425/3000
# 680/680 - 3s - 4ms/step - loss: 2478770487296.0000 - mean_absolute_percentage_error: 20.0634 - val_loss: 3083916804096.0000 - val_mean_absolute_percentage_error: 18.3662
# Epoch 426/3000
# 680/680 - 4s - 6ms/step - loss: 2478576762880.0000 - mean_absolute_percentage_error: 20.0693 - val_loss: 3088077815808.0000 - val_mean_absolute_percentage_error: 18.3785
# Epoch 427/3000
# 680/680 - 4s - 6ms/step - loss: 2478113554432.0000 - mean_absolute_percentage_error: 20.0727 - val_loss: 3089782538240.0000 - val_mean_absolute_percentage_error: 18.3835
# Epoch 428/3000
# 680/680 - 3s - 4ms/step - loss: 2477833584640.0000 - mean_absolute_percentage_error: 20.0658 - val_loss: 3082846470144.0000 - val_mean_absolute_percentage_error: 18.3672
# Epoch 429/3000
# 680/680 - 2s - 3ms/step - loss: 2477436960768.0000 - mean_absolute_percentage_error: 20.0825 - val_loss: 3095781965824.0000 - val_mean_absolute_percentage_error: 18.4000
# Epoch 430/3000
# 680/680 - 2s - 3ms/step - loss: 2477136805888.0000 - mean_absolute_percentage_error: 20.0579 - val_loss: 3090931253248.0000 - val_mean_absolute_percentage_error: 18.3891
# Epoch 431/3000
# 680/680 - 4s - 6ms/step - loss: 2476599148544.0000 - mean_absolute_percentage_error: 20.0365 - val_loss: 3062941089792.0000 - val_mean_absolute_percentage_error: 18.3195
# Epoch 432/3000
# 680/680 - 2s - 3ms/step - loss: 2476552749056.0000 - mean_absolute_percentage_error: 20.0831 - val_loss: 3083513888768.0000 - val_mean_absolute_percentage_error: 18.3715
# Epoch 433/3000
# 680/680 - 2s - 3ms/step - loss: 2476202786816.0000 - mean_absolute_percentage_error: 20.0734 - val_loss: 3094273327104.0000 - val_mean_absolute_percentage_error: 18.3995
# Epoch 434/3000
# 680/680 - 2s - 4ms/step - loss: 2475875893248.0000 - mean_absolute_percentage_error: 20.0644 - val_loss: 3094829596672.0000 - val_mean_absolute_percentage_error: 18.4019
# Epoch 435/3000
# 680/680 - 3s - 4ms/step - loss: 2475557650432.0000 - mean_absolute_percentage_error: 20.0582 - val_loss: 3093107310592.0000 - val_mean_absolute_percentage_error: 18.3977
# Epoch 436/3000
# 680/680 - 3s - 5ms/step - loss: 2475240456192.0000 - mean_absolute_percentage_error: 20.0677 - val_loss: 3101458956288.0000 - val_mean_absolute_percentage_error: 18.4204
# Epoch 437/3000
# 680/680 - 2s - 3ms/step - loss: 2475087626240.0000 - mean_absolute_percentage_error: 20.0462 - val_loss: 3094572695552.0000 - val_mean_absolute_percentage_error: 18.4036
# Epoch 438/3000
# 680/680 - 2s - 3ms/step - loss: 2474581164032.0000 - mean_absolute_percentage_error: 20.0530 - val_loss: 3098415464448.0000 - val_mean_absolute_percentage_error: 18.4146
# Epoch 439/3000
# 680/680 - 2s - 2ms/step - loss: 2474331340800.0000 - mean_absolute_percentage_error: 20.0575 - val_loss: 3097358761984.0000 - val_mean_absolute_percentage_error: 18.4134
# Epoch 440/3000
# 680/680 - 3s - 4ms/step - loss: 2473971417088.0000 - mean_absolute_percentage_error: 20.0611 - val_loss: 3108727160832.0000 - val_mean_absolute_percentage_error: 18.4424
# Epoch 441/3000
# 680/680 - 3s - 4ms/step - loss: 2473678340096.0000 - mean_absolute_percentage_error: 20.0454 - val_loss: 3100701360128.0000 - val_mean_absolute_percentage_error: 18.4231
# Epoch 442/3000
# 680/680 - 4s - 6ms/step - loss: 2473323921408.0000 - mean_absolute_percentage_error: 20.0222 - val_loss: 3072746586112.0000 - val_mean_absolute_percentage_error: 18.3530
# Epoch 443/3000
# 680/680 - 2s - 3ms/step - loss: 2473088778240.0000 - mean_absolute_percentage_error: 20.0708 - val_loss: 3094081961984.0000 - val_mean_absolute_percentage_error: 18.4073
# Epoch 444/3000
# 680/680 - 2s - 3ms/step - loss: 2472765292544.0000 - mean_absolute_percentage_error: 20.0322 - val_loss: 3083010310144.0000 - val_mean_absolute_percentage_error: 18.3807
# Epoch 445/3000
# 680/680 - 3s - 4ms/step - loss: 2472515469312.0000 - mean_absolute_percentage_error: 20.0557 - val_loss: 3099161788416.0000 - val_mean_absolute_percentage_error: 18.4213
# Epoch 446/3000
# 680/680 - 3s - 4ms/step - loss: 2472230256640.0000 - mean_absolute_percentage_error: 20.0577 - val_loss: 3103677743104.0000 - val_mean_absolute_percentage_error: 18.4341
# Epoch 447/3000
# 680/680 - 3s - 5ms/step - loss: 2471949238272.0000 - mean_absolute_percentage_error: 20.0406 - val_loss: 3109976014848.0000 - val_mean_absolute_percentage_error: 18.4495
# Epoch 448/3000
# 680/680 - 2s - 3ms/step - loss: 2471570702336.0000 - mean_absolute_percentage_error: 20.0244 - val_loss: 3093473525760.0000 - val_mean_absolute_percentage_error: 18.4092
# Epoch 449/3000
# 680/680 - 2s - 3ms/step - loss: 2471267663872.0000 - mean_absolute_percentage_error: 20.0364 - val_loss: 3088363290624.0000 - val_mean_absolute_percentage_error: 18.3966
# Epoch 450/3000
# 680/680 - 2s - 2ms/step - loss: 2471038812160.0000 - mean_absolute_percentage_error: 20.0548 - val_loss: 3106112536576.0000 - val_mean_absolute_percentage_error: 18.4422
# Epoch 451/3000
# 680/680 - 2s - 2ms/step - loss: 2470791872512.0000 - mean_absolute_percentage_error: 20.0187 - val_loss: 3084201754624.0000 - val_mean_absolute_percentage_error: 18.3888
# Epoch 452/3000
# 680/680 - 2s - 2ms/step - loss: 2470386073600.0000 - mean_absolute_percentage_error: 20.0566 - val_loss: 3107705847808.0000 - val_mean_absolute_percentage_error: 18.4490
# Epoch 453/3000
# 680/680 - 3s - 4ms/step - loss: 2470285148160.0000 - mean_absolute_percentage_error: 20.0371 - val_loss: 3110478807040.0000 - val_mean_absolute_percentage_error: 18.4556
# Epoch 454/3000
# 680/680 - 3s - 4ms/step - loss: 2469928632320.0000 - mean_absolute_percentage_error: 20.0120 - val_loss: 3088335765504.0000 - val_mean_absolute_percentage_error: 18.4012
# Epoch 455/3000
# 680/680 - 2s - 3ms/step - loss: 2469578670080.0000 - mean_absolute_percentage_error: 20.0521 - val_loss: 3109896060928.0000 - val_mean_absolute_percentage_error: 18.4565
# Epoch 456/3000
# 680/680 - 2s - 3ms/step - loss: 2469437636608.0000 - mean_absolute_percentage_error: 20.0241 - val_loss: 3102440423424.0000 - val_mean_absolute_percentage_error: 18.4380
# Epoch 457/3000
# 680/680 - 2s - 4ms/step - loss: 2469221105664.0000 - mean_absolute_percentage_error: 20.0209 - val_loss: 3095123984384.0000 - val_mean_absolute_percentage_error: 18.4203
# Epoch 458/3000
# 680/680 - 3s - 4ms/step - loss: 2468813471744.0000 - mean_absolute_percentage_error: 20.0291 - val_loss: 3096119607296.0000 - val_mean_absolute_percentage_error: 18.4230
# Epoch 459/3000
# 680/680 - 3s - 4ms/step - loss: 2468559978496.0000 - mean_absolute_percentage_error: 20.0219 - val_loss: 3093395668992.0000 - val_mean_absolute_percentage_error: 18.4174
# Epoch 460/3000
# 680/680 - 3s - 4ms/step - loss: 2468390109184.0000 - mean_absolute_percentage_error: 20.0338 - val_loss: 3094142517248.0000 - val_mean_absolute_percentage_error: 18.4187
# Epoch 461/3000
# 680/680 - 4s - 6ms/step - loss: 2468095983616.0000 - mean_absolute_percentage_error: 20.0271 - val_loss: 3095327670272.0000 - val_mean_absolute_percentage_error: 18.4232
# Epoch 462/3000
# 680/680 - 3s - 4ms/step - loss: 2467644833792.0000 - mean_absolute_percentage_error: 20.0481 - val_loss: 3119205580800.0000 - val_mean_absolute_percentage_error: 18.4834
# Epoch 463/3000
# 680/680 - 3s - 4ms/step - loss: 2467639328768.0000 - mean_absolute_percentage_error: 20.0094 - val_loss: 3100226617344.0000 - val_mean_absolute_percentage_error: 18.4358
# Epoch 464/3000
# 680/680 - 2s - 3ms/step - loss: 2467288580096.0000 - mean_absolute_percentage_error: 20.0166 - val_loss: 3100354281472.0000 - val_mean_absolute_percentage_error: 18.4367
# Epoch 465/3000
# 680/680 - 3s - 4ms/step - loss: 2467048980480.0000 - mean_absolute_percentage_error: 20.0324 - val_loss: 3111027736576.0000 - val_mean_absolute_percentage_error: 18.4644
# Epoch 466/3000
# 680/680 - 2s - 2ms/step - loss: 2466831138816.0000 - mean_absolute_percentage_error: 20.0091 - val_loss: 3094579249152.0000 - val_mean_absolute_percentage_error: 18.4235
# Epoch 467/3000
# 680/680 - 3s - 4ms/step - loss: 2466479603712.0000 - mean_absolute_percentage_error: 20.0162 - val_loss: 3099386970112.0000 - val_mean_absolute_percentage_error: 18.4368
# Epoch 468/3000
# 680/680 - 3s - 4ms/step - loss: 2466232401920.0000 - mean_absolute_percentage_error: 20.0006 - val_loss: 3083579686912.0000 - val_mean_absolute_percentage_error: 18.3971
# Epoch 469/3000
# 680/680 - 3s - 4ms/step - loss: 2466062532608.0000 - mean_absolute_percentage_error: 20.0238 - val_loss: 3089693933568.0000 - val_mean_absolute_percentage_error: 18.4123
# Epoch 470/3000
# 680/680 - 3s - 4ms/step - loss: 2465754251264.0000 - mean_absolute_percentage_error: 20.0297 - val_loss: 3103436046336.0000 - val_mean_absolute_percentage_error: 18.4474
# Epoch 471/3000
# 680/680 - 2s - 3ms/step - loss: 2465574944768.0000 - mean_absolute_percentage_error: 20.0046 - val_loss: 3094929735680.0000 - val_mean_absolute_percentage_error: 18.4270
# Epoch 472/3000
# 680/680 - 2s - 2ms/step - loss: 2465276362752.0000 - mean_absolute_percentage_error: 20.0092 - val_loss: 3086840233984.0000 - val_mean_absolute_percentage_error: 18.4071
# Epoch 473/3000
# 680/680 - 2s - 2ms/step - loss: 2465078181888.0000 - mean_absolute_percentage_error: 20.0238 - val_loss: 3097873874944.0000 - val_mean_absolute_percentage_error: 18.4357
# Epoch 474/3000
# 680/680 - 3s - 4ms/step - loss: 2464661897216.0000 - mean_absolute_percentage_error: 19.9920 - val_loss: 3082742661120.0000 - val_mean_absolute_percentage_error: 18.3980
# Epoch 475/3000
# 680/680 - 3s - 4ms/step - loss: 2464698597376.0000 - mean_absolute_percentage_error: 20.0122 - val_loss: 3084547260416.0000 - val_mean_absolute_percentage_error: 18.4024
# Epoch 476/3000
# 680/680 - 2s - 3ms/step - loss: 2464390316032.0000 - mean_absolute_percentage_error: 20.0240 - val_loss: 3096035196928.0000 - val_mean_absolute_percentage_error: 18.4323
# Epoch 477/3000
# 680/680 - 2s - 3ms/step - loss: 2464086491136.0000 - mean_absolute_percentage_error: 19.9962 - val_loss: 3089616601088.0000 - val_mean_absolute_percentage_error: 18.4168
# Epoch 478/3000
# 680/680 - 2s - 2ms/step - loss: 2463921602560.0000 - mean_absolute_percentage_error: 20.0200 - val_loss: 3106938028032.0000 - val_mean_absolute_percentage_error: 18.4616
# Epoch 479/3000
# 680/680 - 3s - 4ms/step - loss: 2463681216512.0000 - mean_absolute_percentage_error: 19.9883 - val_loss: 3092488126464.0000 - val_mean_absolute_percentage_error: 18.4255
# Epoch 480/3000
# 680/680 - 2s - 2ms/step - loss: 2463495356416.0000 - mean_absolute_percentage_error: 20.0150 - val_loss: 3099701542912.0000 - val_mean_absolute_percentage_error: 18.4438
# Epoch 481/3000
# 680/680 - 3s - 4ms/step - loss: 2463214862336.0000 - mean_absolute_percentage_error: 20.0032 - val_loss: 3093420048384.0000 - val_mean_absolute_percentage_error: 18.4280
# Epoch 482/3000
# 680/680 - 3s - 5ms/step - loss: 2463026118656.0000 - mean_absolute_percentage_error: 20.0145 - val_loss: 3113965846528.0000 - val_mean_absolute_percentage_error: 18.4803
# Epoch 483/3000
# 680/680 - 2s - 3ms/step - loss: 2462836850688.0000 - mean_absolute_percentage_error: 19.9945 - val_loss: 3102649876480.0000 - val_mean_absolute_percentage_error: 18.4523
# Epoch 484/3000
# 680/680 - 2s - 3ms/step - loss: 2462680612864.0000 - mean_absolute_percentage_error: 19.9984 - val_loss: 3104305315840.0000 - val_mean_absolute_percentage_error: 18.4575
# Epoch 485/3000
# 680/680 - 3s - 4ms/step - loss: 2462347165696.0000 - mean_absolute_percentage_error: 19.9896 - val_loss: 3095629660160.0000 - val_mean_absolute_percentage_error: 18.4365
# Epoch 486/3000
# 680/680 - 2s - 4ms/step - loss: 2462228152320.0000 - mean_absolute_percentage_error: 20.0002 - val_loss: 3092030685184.0000 - val_mean_absolute_percentage_error: 18.4272
# Epoch 487/3000
# 680/680 - 3s - 4ms/step - loss: 2462017126400.0000 - mean_absolute_percentage_error: 20.0124 - val_loss: 3109214486528.0000 - val_mean_absolute_percentage_error: 18.4708
# Epoch 488/3000
# 680/680 - 3s - 4ms/step - loss: 2461772283904.0000 - mean_absolute_percentage_error: 19.9888 - val_loss: 3100255977472.0000 - val_mean_absolute_percentage_error: 18.4490
# Epoch 489/3000
# 680/680 - 2s - 3ms/step - loss: 2461520887808.0000 - mean_absolute_percentage_error: 19.9816 - val_loss: 3087894052864.0000 - val_mean_absolute_percentage_error: 18.4180
# Epoch 490/3000
# 680/680 - 3s - 4ms/step - loss: 2461438312448.0000 - mean_absolute_percentage_error: 20.0068 - val_loss: 3095894425600.0000 - val_mean_absolute_percentage_error: 18.4382
# Epoch 491/3000
# 680/680 - 3s - 4ms/step - loss: 2461171449856.0000 - mean_absolute_percentage_error: 20.0084 - val_loss: 3110467796992.0000 - val_mean_absolute_percentage_error: 18.4759
# Epoch 492/3000
# 680/680 - 2s - 4ms/step - loss: 2461029105664.0000 - mean_absolute_percentage_error: 19.9837 - val_loss: 3099125612544.0000 - val_mean_absolute_percentage_error: 18.4480
# Epoch 493/3000
# 680/680 - 2s - 4ms/step - loss: 2460668657664.0000 - mean_absolute_percentage_error: 19.9796 - val_loss: 3088098787328.0000 - val_mean_absolute_percentage_error: 18.4199
# Epoch 494/3000
# 680/680 - 2s - 3ms/step - loss: 2460549120000.0000 - mean_absolute_percentage_error: 20.0020 - val_loss: 3095105110016.0000 - val_mean_absolute_percentage_error: 18.4377
# Epoch 495/3000
# 680/680 - 2s - 2ms/step - loss: 2460394192896.0000 - mean_absolute_percentage_error: 19.9964 - val_loss: 3101691478016.0000 - val_mean_absolute_percentage_error: 18.4552
# Epoch 496/3000
# 680/680 - 2s - 2ms/step - loss: 2460189196288.0000 - mean_absolute_percentage_error: 19.9875 - val_loss: 3102896291840.0000 - val_mean_absolute_percentage_error: 18.4580
# Epoch 497/3000
# 680/680 - 2s - 2ms/step - loss: 2460067299328.0000 - mean_absolute_percentage_error: 19.9819 - val_loss: 3097749356544.0000 - val_mean_absolute_percentage_error: 18.4460
# Epoch 498/3000
# 680/680 - 3s - 4ms/step - loss: 2459809349632.0000 - mean_absolute_percentage_error: 19.9853 - val_loss: 3099695775744.0000 - val_mean_absolute_percentage_error: 18.4513
# Epoch 499/3000
# 680/680 - 3s - 4ms/step - loss: 2459660189696.0000 - mean_absolute_percentage_error: 19.9904 - val_loss: 3096814026752.0000 - val_mean_absolute_percentage_error: 18.4450
# Epoch 500/3000
# 680/680 - 3s - 4ms/step - loss: 2459449688064.0000 - mean_absolute_percentage_error: 19.9952 - val_loss: 3107954098176.0000 - val_mean_absolute_percentage_error: 18.4740
# Epoch 501/3000
# 680/680 - 2s - 3ms/step - loss: 2459231059968.0000 - mean_absolute_percentage_error: 19.9784 - val_loss: 3096343740416.0000 - val_mean_absolute_percentage_error: 18.4447
# Epoch 502/3000
# 680/680 - 3s - 4ms/step - loss: 2459097366528.0000 - mean_absolute_percentage_error: 19.9773 - val_loss: 3095662952448.0000 - val_mean_absolute_percentage_error: 18.4435
# Epoch 503/3000
# 680/680 - 2s - 2ms/step - loss: 2458933264384.0000 - mean_absolute_percentage_error: 19.9950 - val_loss: 3105958658048.0000 - val_mean_absolute_percentage_error: 18.4701
# Epoch 504/3000
# 680/680 - 3s - 4ms/step - loss: 2458683179008.0000 - mean_absolute_percentage_error: 20.0034 - val_loss: 3126351101952.0000 - val_mean_absolute_percentage_error: 18.5222
# Epoch 505/3000
# 680/680 - 2s - 3ms/step - loss: 2458571767808.0000 - mean_absolute_percentage_error: 19.9745 - val_loss: 3116621889536.0000 - val_mean_absolute_percentage_error: 18.4979
# Epoch 506/3000
# 680/680 - 3s - 4ms/step - loss: 2458459308032.0000 - mean_absolute_percentage_error: 19.9759 - val_loss: 3115728764928.0000 - val_mean_absolute_percentage_error: 18.4969
# Epoch 507/3000
# 680/680 - 2s - 3ms/step - loss: 2458152599552.0000 - mean_absolute_percentage_error: 19.9716 - val_loss: 3102379081728.0000 - val_mean_absolute_percentage_error: 18.4632
# Epoch 508/3000
# 680/680 - 3s - 4ms/step - loss: 2457996623872.0000 - mean_absolute_percentage_error: 19.9983 - val_loss: 3122868256768.0000 - val_mean_absolute_percentage_error: 18.5153
# Epoch 509/3000
# 680/680 - 2s - 4ms/step - loss: 2457795821568.0000 - mean_absolute_percentage_error: 19.9541 - val_loss: 3102006050816.0000 - val_mean_absolute_percentage_error: 18.4626
# Epoch 510/3000
# 680/680 - 2s - 4ms/step - loss: 2457648758784.0000 - mean_absolute_percentage_error: 19.9803 - val_loss: 3098888896512.0000 - val_mean_absolute_percentage_error: 18.4557
# Epoch 511/3000
# 680/680 - 3s - 4ms/step - loss: 2457497763840.0000 - mean_absolute_percentage_error: 19.9793 - val_loss: 3104811778048.0000 - val_mean_absolute_percentage_error: 18.4717
# Epoch 512/3000
# 680/680 - 4s - 6ms/step - loss: 2457328156672.0000 - mean_absolute_percentage_error: 19.9601 - val_loss: 3090267504640.0000 - val_mean_absolute_percentage_error: 18.4354
# Epoch 513/3000
# 680/680 - 2s - 2ms/step - loss: 2457191841792.0000 - mean_absolute_percentage_error: 19.9872 - val_loss: 3095715381248.0000 - val_mean_absolute_percentage_error: 18.4493
# Epoch 514/3000
# 680/680 - 2s - 2ms/step - loss: 2457005457408.0000 - mean_absolute_percentage_error: 19.9835 - val_loss: 3105882374144.0000 - val_mean_absolute_percentage_error: 18.4751
# Epoch 515/3000
# 680/680 - 3s - 4ms/step - loss: 2456926552064.0000 - mean_absolute_percentage_error: 19.9779 - val_loss: 3116563169280.0000 - val_mean_absolute_percentage_error: 18.5024
# Epoch 516/3000
# 680/680 - 4s - 5ms/step - loss: 2456723390464.0000 - mean_absolute_percentage_error: 19.9711 - val_loss: 3108112957440.0000 - val_mean_absolute_percentage_error: 18.4812
# Epoch 517/3000
# 680/680 - 4s - 6ms/step - loss: 2456559812608.0000 - mean_absolute_percentage_error: 19.9782 - val_loss: 3112898134016.0000 - val_mean_absolute_percentage_error: 18.4938
# Epoch 518/3000
# 680/680 - 3s - 4ms/step - loss: 2456364777472.0000 - mean_absolute_percentage_error: 19.9710 - val_loss: 3107071983616.0000 - val_mean_absolute_percentage_error: 18.4794
# Epoch 519/3000
# 680/680 - 2s - 2ms/step - loss: 2456181276672.0000 - mean_absolute_percentage_error: 19.9667 - val_loss: 3111116865536.0000 - val_mean_absolute_percentage_error: 18.4902
# Epoch 520/3000
# 680/680 - 3s - 4ms/step - loss: 2456004591616.0000 - mean_absolute_percentage_error: 19.9575 - val_loss: 3096738267136.0000 - val_mean_absolute_percentage_error: 18.4541
# Epoch 521/3000
# 680/680 - 3s - 5ms/step - loss: 2455936172032.0000 - mean_absolute_percentage_error: 19.9816 - val_loss: 3113387556864.0000 - val_mean_absolute_percentage_error: 18.4966
# Epoch 522/3000
# 680/680 - 4s - 6ms/step - loss: 2455824760832.0000 - mean_absolute_percentage_error: 19.9704 - val_loss: 3111704592384.0000 - val_mean_absolute_percentage_error: 18.4925
# Epoch 523/3000
# 680/680 - 2s - 2ms/step - loss: 2455614521344.0000 - mean_absolute_percentage_error: 19.9735 - val_loss: 3116649414656.0000 - val_mean_absolute_percentage_error: 18.5049
# Epoch 524/3000
# 680/680 - 2s - 2ms/step - loss: 2455438360576.0000 - mean_absolute_percentage_error: 19.9645 - val_loss: 3108603953152.0000 - val_mean_absolute_percentage_error: 18.4848
# Epoch 525/3000
# 680/680 - 3s - 4ms/step - loss: 2455288676352.0000 - mean_absolute_percentage_error: 19.9702 - val_loss: 3116930957312.0000 - val_mean_absolute_percentage_error: 18.5071
# Epoch 526/3000
# 680/680 - 3s - 4ms/step - loss: 2455142662144.0000 - mean_absolute_percentage_error: 19.9495 - val_loss: 3096674041856.0000 - val_mean_absolute_percentage_error: 18.4552
# Epoch 527/3000
# 680/680 - 2s - 3ms/step - loss: 2455021289472.0000 - mean_absolute_percentage_error: 19.9696 - val_loss: 3105511702528.0000 - val_mean_absolute_percentage_error: 18.4775
# Epoch 528/3000
# 680/680 - 3s - 4ms/step - loss: 2454876061696.0000 - mean_absolute_percentage_error: 19.9798 - val_loss: 3111776681984.0000 - val_mean_absolute_percentage_error: 18.4938
# Epoch 529/3000
# 680/680 - 3s - 4ms/step - loss: 2454799777792.0000 - mean_absolute_percentage_error: 19.9576 - val_loss: 3110306054144.0000 - val_mean_absolute_percentage_error: 18.4907
# Epoch 530/3000
# 680/680 - 3s - 4ms/step - loss: 2454594256896.0000 - mean_absolute_percentage_error: 19.9690 - val_loss: 3118997700608.0000 - val_mean_absolute_percentage_error: 18.5138
# Epoch 531/3000
# 680/680 - 4s - 5ms/step - loss: 2454415736832.0000 - mean_absolute_percentage_error: 19.9350 - val_loss: 3088876044288.0000 - val_mean_absolute_percentage_error: 18.4384
# Epoch 532/3000
# 680/680 - 4s - 6ms/step - loss: 2454361997312.0000 - mean_absolute_percentage_error: 19.9763 - val_loss: 3100605415424.0000 - val_mean_absolute_percentage_error: 18.4679
# Epoch 533/3000
# 680/680 - 2s - 2ms/step - loss: 2454089105408.0000 - mean_absolute_percentage_error: 19.9857 - val_loss: 3128954191872.0000 - val_mean_absolute_percentage_error: 18.5406
# Epoch 534/3000
# 680/680 - 3s - 4ms/step - loss: 2454009675776.0000 - mean_absolute_percentage_error: 19.9550 - val_loss: 3118972010496.0000 - val_mean_absolute_percentage_error: 18.5151
# Epoch 535/3000
# 680/680 - 2s - 2ms/step - loss: 2453902721024.0000 - mean_absolute_percentage_error: 19.9473 - val_loss: 3110915801088.0000 - val_mean_absolute_percentage_error: 18.4948
# Epoch 536/3000
# 680/680 - 4s - 5ms/step - loss: 2453756182528.0000 - mean_absolute_percentage_error: 19.9504 - val_loss: 3097496387584.0000 - val_mean_absolute_percentage_error: 18.4613
# Epoch 537/3000
# 680/680 - 2s - 2ms/step - loss: 2453550399488.0000 - mean_absolute_percentage_error: 19.9750 - val_loss: 3117596278784.0000 - val_mean_absolute_percentage_error: 18.5127
# Epoch 538/3000
# 680/680 - 2s - 2ms/step - loss: 2453431386112.0000 - mean_absolute_percentage_error: 19.9382 - val_loss: 3099724873728.0000 - val_mean_absolute_percentage_error: 18.4674
# Epoch 539/3000
# 680/680 - 2s - 2ms/step - loss: 2453384724480.0000 - mean_absolute_percentage_error: 19.9665 - val_loss: 3107812540416.0000 - val_mean_absolute_percentage_error: 18.4874
# Epoch 540/3000
# 680/680 - 3s - 4ms/step - loss: 2453196767232.0000 - mean_absolute_percentage_error: 19.9679 - val_loss: 3124588445696.0000 - val_mean_absolute_percentage_error: 18.5311
# Epoch 541/3000
# 680/680 - 2s - 2ms/step - loss: 2453091123200.0000 - mean_absolute_percentage_error: 19.9534 - val_loss: 3118324252672.0000 - val_mean_absolute_percentage_error: 18.5152
# Epoch 542/3000
# 680/680 - 4s - 5ms/step - loss: 2452937506816.0000 - mean_absolute_percentage_error: 19.9591 - val_loss: 3120994189312.0000 - val_mean_absolute_percentage_error: 18.5225
# Epoch 543/3000
# 680/680 - 2s - 3ms/step - loss: 2452799356928.0000 - mean_absolute_percentage_error: 19.9405 - val_loss: 3104290897920.0000 - val_mean_absolute_percentage_error: 18.4800
# Epoch 544/3000
# 680/680 - 2s - 2ms/step - loss: 2452619526144.0000 - mean_absolute_percentage_error: 19.9494 - val_loss: 3104894615552.0000 - val_mean_absolute_percentage_error: 18.4814
# Epoch 545/3000
# 680/680 - 3s - 4ms/step - loss: 2452623982592.0000 - mean_absolute_percentage_error: 19.9566 - val_loss: 3101413343232.0000 - val_mean_absolute_percentage_error: 18.4731
# Epoch 546/3000
# 680/680 - 3s - 4ms/step - loss: 2452391723008.0000 - mean_absolute_percentage_error: 19.9571 - val_loss: 3113464365056.0000 - val_mean_absolute_percentage_error: 18.5039
# Epoch 547/3000
# 680/680 - 3s - 4ms/step - loss: 2452224212992.0000 - mean_absolute_percentage_error: 19.9401 - val_loss: 3096611127296.0000 - val_mean_absolute_percentage_error: 18.4619
# Epoch 548/3000
# 680/680 - 3s - 4ms/step - loss: 2452154482688.0000 - mean_absolute_percentage_error: 19.9589 - val_loss: 3109129289728.0000 - val_mean_absolute_percentage_error: 18.4941
# Epoch 549/3000
# 680/680 - 2s - 2ms/step - loss: 2451961020416.0000 - mean_absolute_percentage_error: 19.9578 - val_loss: 3115371986944.0000 - val_mean_absolute_percentage_error: 18.5104
# Epoch 550/3000
# 680/680 - 2s - 2ms/step - loss: 2451718275072.0000 - mean_absolute_percentage_error: 19.9364 - val_loss: 3094542548992.0000 - val_mean_absolute_percentage_error: 18.4578
# Epoch 551/3000
# 680/680 - 2s - 2ms/step - loss: 2451682885632.0000 - mean_absolute_percentage_error: 19.9552 - val_loss: 3105575141376.0000 - val_mean_absolute_percentage_error: 18.4861
# Epoch 552/3000
# 680/680 - 3s - 4ms/step - loss: 2451581435904.0000 - mean_absolute_percentage_error: 19.9580 - val_loss: 3109586993152.0000 - val_mean_absolute_percentage_error: 18.4964
# Epoch 553/3000
# 680/680 - 3s - 4ms/step - loss: 2451439616000.0000 - mean_absolute_percentage_error: 19.9506 - val_loss: 3118377992192.0000 - val_mean_absolute_percentage_error: 18.5186
# Epoch 554/3000
# 680/680 - 3s - 4ms/step - loss: 2451338428416.0000 - mean_absolute_percentage_error: 19.9445 - val_loss: 3114833281024.0000 - val_mean_absolute_percentage_error: 18.5103
# Epoch 555/3000
# 680/680 - 4s - 6ms/step - loss: 2451083100160.0000 - mean_absolute_percentage_error: 19.9622 - val_loss: 3126513369088.0000 - val_mean_absolute_percentage_error: 18.5403
# Epoch 556/3000
# 680/680 - 3s - 4ms/step - loss: 2451033817088.0000 - mean_absolute_percentage_error: 19.9235 - val_loss: 3106653601792.0000 - val_mean_absolute_percentage_error: 18.4901
# Epoch 557/3000
# 680/680 - 2s - 2ms/step - loss: 2450898812928.0000 - mean_absolute_percentage_error: 19.9511 - val_loss: 3104679133184.0000 - val_mean_absolute_percentage_error: 18.4856
# Epoch 558/3000
# 680/680 - 3s - 5ms/step - loss: 2450686738432.0000 - mean_absolute_percentage_error: 19.9398 - val_loss: 3100511043584.0000 - val_mean_absolute_percentage_error: 18.4745
# Epoch 559/3000
# 680/680 - 3s - 4ms/step - loss: 2450337038336.0000 - mean_absolute_percentage_error: 19.9746 - val_loss: 3133194371072.0000 - val_mean_absolute_percentage_error: 18.5585
# Epoch 560/3000
# 680/680 - 2s - 3ms/step - loss: 2450611765248.0000 - mean_absolute_percentage_error: 19.9316 - val_loss: 3117751468032.0000 - val_mean_absolute_percentage_error: 18.5200
# Epoch 561/3000
# 680/680 - 3s - 4ms/step - loss: 2450258395136.0000 - mean_absolute_percentage_error: 19.9321 - val_loss: 3106556870656.0000 - val_mean_absolute_percentage_error: 18.4922
# Epoch 562/3000
# 680/680 - 2s - 2ms/step - loss: 2450151178240.0000 - mean_absolute_percentage_error: 19.9430 - val_loss: 3105497022464.0000 - val_mean_absolute_percentage_error: 18.4897
# Epoch 563/3000
# 680/680 - 2s - 2ms/step - loss: 2450024300544.0000 - mean_absolute_percentage_error: 19.9467 - val_loss: 3114078830592.0000 - val_mean_absolute_percentage_error: 18.5107
# Epoch 564/3000
# 680/680 - 3s - 5ms/step - loss: 2449925996544.0000 - mean_absolute_percentage_error: 19.9429 - val_loss: 3117370310656.0000 - val_mean_absolute_percentage_error: 18.5204
# Epoch 565/3000
# 680/680 - 3s - 4ms/step - loss: 2449788895232.0000 - mean_absolute_percentage_error: 19.9429 - val_loss: 3116129845248.0000 - val_mean_absolute_percentage_error: 18.5164
# Epoch 566/3000
# 680/680 - 2s - 2ms/step - loss: 2449724407808.0000 - mean_absolute_percentage_error: 19.9320 - val_loss: 3106740895744.0000 - val_mean_absolute_percentage_error: 18.4942
# Epoch 567/3000
# 680/680 - 3s - 4ms/step - loss: 2449450991616.0000 - mean_absolute_percentage_error: 19.9570 - val_loss: 3124602863616.0000 - val_mean_absolute_percentage_error: 18.5399
# Epoch 568/3000
# 680/680 - 2s - 4ms/step - loss: 2449325162496.0000 - mean_absolute_percentage_error: 19.9239 - val_loss: 3107793141760.0000 - val_mean_absolute_percentage_error: 18.4967
# Epoch 569/3000
# 680/680 - 3s - 4ms/step - loss: 2449242324992.0000 - mean_absolute_percentage_error: 19.9412 - val_loss: 3107798384640.0000 - val_mean_absolute_percentage_error: 18.4972
# Epoch 570/3000
# 680/680 - 2s - 4ms/step - loss: 2449164992512.0000 - mean_absolute_percentage_error: 19.9419 - val_loss: 3117624852480.0000 - val_mean_absolute_percentage_error: 18.5233
# Epoch 571/3000
# 680/680 - 2s - 3ms/step - loss: 2449008492544.0000 - mean_absolute_percentage_error: 19.9384 - val_loss: 3114443997184.0000 - val_mean_absolute_percentage_error: 18.5154
# Epoch 572/3000
# 680/680 - 2s - 2ms/step - loss: 2448950558720.0000 - mean_absolute_percentage_error: 19.9290 - val_loss: 3111288832000.0000 - val_mean_absolute_percentage_error: 18.5073
# Epoch 573/3000
# 680/680 - 2s - 4ms/step - loss: 2448749494272.0000 - mean_absolute_percentage_error: 19.9384 - val_loss: 3108269981696.0000 - val_mean_absolute_percentage_error: 18.5003
# Epoch 574/3000
# 680/680 - 3s - 4ms/step - loss: 2448520380416.0000 - mean_absolute_percentage_error: 19.9506 - val_loss: 3125067907072.0000 - val_mean_absolute_percentage_error: 18.5430
# Epoch 575/3000
# 680/680 - 3s - 4ms/step - loss: 2448464805888.0000 - mean_absolute_percentage_error: 19.9242 - val_loss: 3112185102336.0000 - val_mean_absolute_percentage_error: 18.5095
# Epoch 576/3000
# ...
# Epoch 2731/3000
# 680/680 - 3s - 4ms/step - loss: 2290856755200.0000 - mean_absolute_percentage_error: 19.3264 - val_loss: 3225531711488.0000 - val_mean_absolute_percentage_error: 19.0101
# Epoch 2732/3000
# 680/680 - 2s - 4ms/step - loss: 2290786762752.0000 - mean_absolute_percentage_error: 19.3032 - val_loss: 3216167141376.0000 - val_mean_absolute_percentage_error: 18.9845
# Epoch 2733/3000
# 680/680 - 3s - 4ms/step - loss: 2290524356608.0000 - mean_absolute_percentage_error: 19.3204 - val_loss: 3232816168960.0000 - val_mean_absolute_percentage_error: 19.0309
# Epoch 2734/3000
# 680/680 - 4s - 6ms/step - loss: 2290644156416.0000 - mean_absolute_percentage_error: 19.3046 - val_loss: 3219447873536.0000 - val_mean_absolute_percentage_error: 18.9942
# Epoch 2735/3000
# 680/680 - 2s - 4ms/step - loss: 2290690818048.0000 - mean_absolute_percentage_error: 19.3097 - val_loss: 3224205787136.0000 - val_mean_absolute_percentage_error: 19.0064
# Epoch 2736/3000
# 680/680 - 3s - 4ms/step - loss: 2290596708352.0000 - mean_absolute_percentage_error: 19.3340 - val_loss: 3236258906112.0000 - val_mean_absolute_percentage_error: 19.0375
# Epoch 2737/3000
# 680/680 - 3s - 5ms/step - loss: 2290596184064.0000 - mean_absolute_percentage_error: 19.3139 - val_loss: 3245732265984.0000 - val_mean_absolute_percentage_error: 19.0630
# Epoch 2738/3000
# 680/680 - 2s - 4ms/step - loss: 2290528550912.0000 - mean_absolute_percentage_error: 19.2802 - val_loss: 3217989566464.0000 - val_mean_absolute_percentage_error: 18.9903
# Epoch 2739/3000
# 680/680 - 2s - 3ms/step - loss: 2290686361600.0000 - mean_absolute_percentage_error: 19.3223 - val_loss: 3231512264704.0000 - val_mean_absolute_percentage_error: 19.0261
# Epoch 2740/3000
# 680/680 - 2s - 2ms/step - loss: 2290550308864.0000 - mean_absolute_percentage_error: 19.3119 - val_loss: 3230498029568.0000 - val_mean_absolute_percentage_error: 19.0224
# Epoch 2741/3000
# 680/680 - 3s - 4ms/step - loss: 2290411896832.0000 - mean_absolute_percentage_error: 19.3223 - val_loss: 3253033500672.0000 - val_mean_absolute_percentage_error: 19.0836
# Epoch 2742/3000
# 680/680 - 3s - 4ms/step - loss: 2290567610368.0000 - mean_absolute_percentage_error: 19.2968 - val_loss: 3227706195968.0000 - val_mean_absolute_percentage_error: 19.0154
# Epoch 2743/3000
# 680/680 - 2s - 3ms/step - loss: 2290548998144.0000 - mean_absolute_percentage_error: 19.3047 - val_loss: 3219004588032.0000 - val_mean_absolute_percentage_error: 18.9919
# Epoch 2744/3000
# 680/680 - 3s - 4ms/step - loss: 2290544541696.0000 - mean_absolute_percentage_error: 19.3144 - val_loss: 3222629253120.0000 - val_mean_absolute_percentage_error: 19.0018
# Epoch 2745/3000
# 680/680 - 2s - 3ms/step - loss: 2290546638848.0000 - mean_absolute_percentage_error: 19.2981 - val_loss: 3212973178880.0000 - val_mean_absolute_percentage_error: 18.9743
# Epoch 2746/3000
# 680/680 - 3s - 4ms/step - loss: 2290456723456.0000 - mean_absolute_percentage_error: 19.3079 - val_loss: 3222026846208.0000 - val_mean_absolute_percentage_error: 19.0003
# Epoch 2747/3000
# 680/680 - 3s - 4ms/step - loss: 2290420547584.0000 - mean_absolute_percentage_error: 19.3277 - val_loss: 3243952308224.0000 - val_mean_absolute_percentage_error: 19.0590
# Epoch 2748/3000
# 680/680 - 3s - 5ms/step - loss: 2290430509056.0000 - mean_absolute_percentage_error: 19.3166 - val_loss: 3248228401152.0000 - val_mean_absolute_percentage_error: 19.0696
# Epoch 2749/3000
# 680/680 - 3s - 4ms/step - loss: 2290426052608.0000 - mean_absolute_percentage_error: 19.2996 - val_loss: 3235731996672.0000 - val_mean_absolute_percentage_error: 19.0350
# Epoch 2750/3000
# 680/680 - 2s - 2ms/step - loss: 2290452791296.0000 - mean_absolute_percentage_error: 19.3026 - val_loss: 3226307919872.0000 - val_mean_absolute_percentage_error: 19.0102
# Epoch 2751/3000
# 680/680 - 3s - 4ms/step - loss: 2290361827328.0000 - mean_absolute_percentage_error: 19.3018 - val_loss: 3218048024576.0000 - val_mean_absolute_percentage_error: 18.9906
# Epoch 2752/3000
# 680/680 - 2s - 4ms/step - loss: 2290368905216.0000 - mean_absolute_percentage_error: 19.3104 - val_loss: 3214671085568.0000 - val_mean_absolute_percentage_error: 18.9810
# Epoch 2753/3000
# 680/680 - 3s - 4ms/step - loss: 2290349768704.0000 - mean_absolute_percentage_error: 19.3164 - val_loss: 3225445728256.0000 - val_mean_absolute_percentage_error: 19.0084
# Epoch 2754/3000
# 680/680 - 3s - 5ms/step - loss: 2290265358336.0000 - mean_absolute_percentage_error: 19.3031 - val_loss: 3220282540032.0000 - val_mean_absolute_percentage_error: 18.9963
# Epoch 2755/3000
# 680/680 - 2s - 3ms/step - loss: 2290312019968.0000 - mean_absolute_percentage_error: 19.3194 - val_loss: 3237216518144.0000 - val_mean_absolute_percentage_error: 19.0408
# Epoch 2756/3000
# 680/680 - 1s - 2ms/step - loss: 2290364186624.0000 - mean_absolute_percentage_error: 19.3007 - val_loss: 3229597827072.0000 - val_mean_absolute_percentage_error: 19.0202
# Epoch 2757/3000
# 680/680 - 3s - 4ms/step - loss: 2290264047616.0000 - mean_absolute_percentage_error: 19.3101 - val_loss: 3221295202304.0000 - val_mean_absolute_percentage_error: 18.9988
# Epoch 2758/3000
# 680/680 - 3s - 4ms/step - loss: 2290341380096.0000 - mean_absolute_percentage_error: 19.2973 - val_loss: 3218978897920.0000 - val_mean_absolute_percentage_error: 18.9929
# Epoch 2759/3000
# 680/680 - 2s - 2ms/step - loss: 2290266406912.0000 - mean_absolute_percentage_error: 19.3256 - val_loss: 3237791137792.0000 - val_mean_absolute_percentage_error: 19.0435
# Epoch 2760/3000
# 680/680 - 4s - 5ms/step - loss: 2290131402752.0000 - mean_absolute_percentage_error: 19.3108 - val_loss: 3249062805504.0000 - val_mean_absolute_percentage_error: 19.0739
# Epoch 2761/3000
# 680/680 - 2s - 2ms/step - loss: 2290220007424.0000 - mean_absolute_percentage_error: 19.2930 - val_loss: 3219657326592.0000 - val_mean_absolute_percentage_error: 18.9947
# Epoch 2762/3000
# 680/680 - 3s - 4ms/step - loss: 2290061148160.0000 - mean_absolute_percentage_error: 19.3234 - val_loss: 3241767075840.0000 - val_mean_absolute_percentage_error: 19.0538
# Epoch 2763/3000
# 680/680 - 2s - 2ms/step - loss: 2290188812288.0000 - mean_absolute_percentage_error: 19.3024 - val_loss: 3224241700864.0000 - val_mean_absolute_percentage_error: 19.0059
# Epoch 2764/3000
# 680/680 - 2s - 4ms/step - loss: 2290209259520.0000 - mean_absolute_percentage_error: 19.3134 - val_loss: 3229932584960.0000 - val_mean_absolute_percentage_error: 19.0216
# Epoch 2765/3000
# 680/680 - 4s - 5ms/step - loss: 2290102042624.0000 - mean_absolute_percentage_error: 19.2864 - val_loss: 3205134024704.0000 - val_mean_absolute_percentage_error: 18.9562
# Epoch 2766/3000
# 680/680 - 2s - 3ms/step - loss: 2290168627200.0000 - mean_absolute_percentage_error: 19.3217 - val_loss: 3226286686208.0000 - val_mean_absolute_percentage_error: 19.0127
# Epoch 2767/3000
# 680/680 - 2s - 3ms/step - loss: 2290128781312.0000 - mean_absolute_percentage_error: 19.3046 - val_loss: 3223278059520.0000 - val_mean_absolute_percentage_error: 19.0047
# Epoch 2768/3000
# 680/680 - 2s - 2ms/step - loss: 2290038341632.0000 - mean_absolute_percentage_error: 19.3200 - val_loss: 3242791796736.0000 - val_mean_absolute_percentage_error: 19.0564
# Epoch 2769/3000
# 680/680 - 2s - 2ms/step - loss: 2290101518336.0000 - mean_absolute_percentage_error: 19.3068 - val_loss: 3237752340480.0000 - val_mean_absolute_percentage_error: 19.0448
# Epoch 2770/3000
# 680/680 - 2s - 2ms/step - loss: 2290048040960.0000 - mean_absolute_percentage_error: 19.3010 - val_loss: 3229041295360.0000 - val_mean_absolute_percentage_error: 19.0201
# Epoch 2771/3000
# 680/680 - 3s - 4ms/step - loss: 2290036768768.0000 - mean_absolute_percentage_error: 19.3008 - val_loss: 3222457548800.0000 - val_mean_absolute_percentage_error: 19.0029
# Epoch 2772/3000
# 680/680 - 3s - 4ms/step - loss: 2290039390208.0000 - mean_absolute_percentage_error: 19.3194 - val_loss: 3234732441600.0000 - val_mean_absolute_percentage_error: 19.0354
# Epoch 2773/3000
# 680/680 - 2s - 3ms/step - loss: 2290009505792.0000 - mean_absolute_percentage_error: 19.3025 - val_loss: 3231415271424.0000 - val_mean_absolute_percentage_error: 19.0266
# Epoch 2774/3000
# 680/680 - 3s - 4ms/step - loss: 2290003214336.0000 - mean_absolute_percentage_error: 19.3185 - val_loss: 3237732155392.0000 - val_mean_absolute_percentage_error: 19.0437
# Epoch 2775/3000
# 680/680 - 2s - 4ms/step - loss: 2289986437120.0000 - mean_absolute_percentage_error: 19.2908 - val_loss: 3224668209152.0000 - val_mean_absolute_percentage_error: 19.0074
# Epoch 2776/3000
# 680/680 - 2s - 2ms/step - loss: 2289939775488.0000 - mean_absolute_percentage_error: 19.3115 - val_loss: 3228507045888.0000 - val_mean_absolute_percentage_error: 19.0194
# Epoch 2777/3000
# 680/680 - 2s - 3ms/step - loss: 2289915133952.0000 - mean_absolute_percentage_error: 19.3098 - val_loss: 3237071552512.0000 - val_mean_absolute_percentage_error: 19.0435
# Epoch 2778/3000
# 680/680 - 2s - 4ms/step - loss: 2289908056064.0000 - mean_absolute_percentage_error: 19.3057 - val_loss: 3227057127424.0000 - val_mean_absolute_percentage_error: 19.0158
# Epoch 2779/3000
# 680/680 - 2s - 3ms/step - loss: 2289796644864.0000 - mean_absolute_percentage_error: 19.3043 - val_loss: 3226319978496.0000 - val_mean_absolute_percentage_error: 19.0132
# Epoch 2780/3000
# 680/680 - 2s - 2ms/step - loss: 2289872928768.0000 - mean_absolute_percentage_error: 19.3009 - val_loss: 3209125953536.0000 - val_mean_absolute_percentage_error: 18.9660
# Epoch 2781/3000
# 680/680 - 2s - 2ms/step - loss: 2289876336640.0000 - mean_absolute_percentage_error: 19.3087 - val_loss: 3206446579712.0000 - val_mean_absolute_percentage_error: 18.9596
# Epoch 2782/3000
# 680/680 - 2s - 2ms/step - loss: 2289920638976.0000 - mean_absolute_percentage_error: 19.3081 - val_loss: 3220080951296.0000 - val_mean_absolute_percentage_error: 18.9951
# Epoch 2783/3000
# 680/680 - 2s - 4ms/step - loss: 2289823907840.0000 - mean_absolute_percentage_error: 19.3065 - val_loss: 3221689729024.0000 - val_mean_absolute_percentage_error: 18.9990
# Epoch 2784/3000
# 680/680 - 4s - 5ms/step - loss: 2289598988288.0000 - mean_absolute_percentage_error: 19.3397 - val_loss: 3257868222464.0000 - val_mean_absolute_percentage_error: 19.0949
# Epoch 2785/3000
# 680/680 - 2s - 3ms/step - loss: 2289892327424.0000 - mean_absolute_percentage_error: 19.2853 - val_loss: 3233092206592.0000 - val_mean_absolute_percentage_error: 19.0297
# Epoch 2786/3000
# 680/680 - 2s - 2ms/step - loss: 2289783537664.0000 - mean_absolute_percentage_error: 19.3186 - val_loss: 3251631030272.0000 - val_mean_absolute_percentage_error: 19.0789
# Epoch 2787/3000
# 680/680 - 3s - 4ms/step - loss: 2289661378560.0000 - mean_absolute_percentage_error: 19.2730 - val_loss: 3211138170880.0000 - val_mean_absolute_percentage_error: 18.9717
# Epoch 2788/3000
# 680/680 - 3s - 4ms/step - loss: 2289769644032.0000 - mean_absolute_percentage_error: 19.3157 - val_loss: 3227369078784.0000 - val_mean_absolute_percentage_error: 19.0143
# Epoch 2789/3000
# 680/680 - 2s - 2ms/step - loss: 2289681825792.0000 - mean_absolute_percentage_error: 19.3217 - val_loss: 3239478820864.0000 - val_mean_absolute_percentage_error: 19.0465
# Epoch 2790/3000
# 680/680 - 4s - 5ms/step - loss: 2289783013376.0000 - mean_absolute_percentage_error: 19.2922 - val_loss: 3233280688128.0000 - val_mean_absolute_percentage_error: 19.0306
# Epoch 2791/3000
# 680/680 - 2s - 3ms/step - loss: 2289616289792.0000 - mean_absolute_percentage_error: 19.3194 - val_loss: 3244680544256.0000 - val_mean_absolute_percentage_error: 19.0616
# Epoch 2792/3000
# 680/680 - 2s - 4ms/step - loss: 2289707778048.0000 - mean_absolute_percentage_error: 19.2925 - val_loss: 3231892897792.0000 - val_mean_absolute_percentage_error: 19.0277
# Epoch 2793/3000
# 680/680 - 2s - 2ms/step - loss: 2289635688448.0000 - mean_absolute_percentage_error: 19.3047 - val_loss: 3228927000576.0000 - val_mean_absolute_percentage_error: 19.0199
# Epoch 2794/3000
# 680/680 - 2s - 4ms/step - loss: 2289599774720.0000 - mean_absolute_percentage_error: 19.3092 - val_loss: 3227564376064.0000 - val_mean_absolute_percentage_error: 19.0151
# Epoch 2795/3000
# 680/680 - 3s - 5ms/step - loss: 2289538170880.0000 - mean_absolute_percentage_error: 19.2833 - val_loss: 3198295474176.0000 - val_mean_absolute_percentage_error: 18.9380
# Epoch 2796/3000
# 680/680 - 2s - 4ms/step - loss: 2289656922112.0000 - mean_absolute_percentage_error: 19.3318 - val_loss: 3230207049728.0000 - val_mean_absolute_percentage_error: 19.0241
# Epoch 2797/3000
# 680/680 - 2s - 2ms/step - loss: 2289647747072.0000 - mean_absolute_percentage_error: 19.2966 - val_loss: 3229557194752.0000 - val_mean_absolute_percentage_error: 19.0217
# Epoch 2798/3000
# 680/680 - 2s - 2ms/step - loss: 2289544462336.0000 - mean_absolute_percentage_error: 19.3042 - val_loss: 3224594284544.0000 - val_mean_absolute_percentage_error: 19.0085
# Epoch 2799/3000
# 680/680 - 2s - 2ms/step - loss: 2289576968192.0000 - mean_absolute_percentage_error: 19.3023 - val_loss: 3221616590848.0000 - val_mean_absolute_percentage_error: 19.0010
# Epoch 2800/3000
# 680/680 - 3s - 4ms/step - loss: 2289566220288.0000 - mean_absolute_percentage_error: 19.3112 - val_loss: 3218688966656.0000 - val_mean_absolute_percentage_error: 18.9922
# Epoch 2801/3000
# 680/680 - 3s - 4ms/step - loss: 2289533452288.0000 - mean_absolute_percentage_error: 19.2871 - val_loss: 3210194452480.0000 - val_mean_absolute_percentage_error: 18.9701
# Epoch 2802/3000
# 680/680 - 3s - 4ms/step - loss: 2289473421312.0000 - mean_absolute_percentage_error: 19.3219 - val_loss: 3227249278976.0000 - val_mean_absolute_percentage_error: 19.0147
# Epoch 2803/3000
# 680/680 - 2s - 2ms/step - loss: 2289476042752.0000 - mean_absolute_percentage_error: 19.3005 - val_loss: 3225723076608.0000 - val_mean_absolute_percentage_error: 19.0113
# Epoch 2804/3000
# 680/680 - 3s - 4ms/step - loss: 2289383243776.0000 - mean_absolute_percentage_error: 19.3166 - val_loss: 3237369085952.0000 - val_mean_absolute_percentage_error: 19.0418
# Epoch 2805/3000
# 680/680 - 2s - 4ms/step - loss: 2289376165888.0000 - mean_absolute_percentage_error: 19.3079 - val_loss: 3243154079744.0000 - val_mean_absolute_percentage_error: 19.0554
# Epoch 2806/3000
# 680/680 - 3s - 4ms/step - loss: 2289455857664.0000 - mean_absolute_percentage_error: 19.2988 - val_loss: 3228677963776.0000 - val_mean_absolute_percentage_error: 19.0166
# Epoch 2807/3000
# 680/680 - 3s - 5ms/step - loss: 2289440129024.0000 - mean_absolute_percentage_error: 19.2967 - val_loss: 3226765623296.0000 - val_mean_absolute_percentage_error: 19.0134
# Epoch 2808/3000
# 680/680 - 2s - 3ms/step - loss: 2289343397888.0000 - mean_absolute_percentage_error: 19.2953 - val_loss: 3211086266368.0000 - val_mean_absolute_percentage_error: 18.9716
# Epoch 2809/3000
# 680/680 - 2s - 3ms/step - loss: 2289463459840.0000 - mean_absolute_percentage_error: 19.3183 - val_loss: 3220122370048.0000 - val_mean_absolute_percentage_error: 18.9955
# Epoch 2810/3000
# 680/680 - 3s - 4ms/step - loss: 2289374593024.0000 - mean_absolute_percentage_error: 19.2973 - val_loss: 3215516762112.0000 - val_mean_absolute_percentage_error: 18.9833
# Epoch 2811/3000
# 680/680 - 2s - 2ms/step - loss: 2289348640768.0000 - mean_absolute_percentage_error: 19.2950 - val_loss: 3203928686592.0000 - val_mean_absolute_percentage_error: 18.9523
# Epoch 2812/3000
# 680/680 - 2s - 2ms/step - loss: 2289393991680.0000 - mean_absolute_percentage_error: 19.3063 - val_loss: 3213411221504.0000 - val_mean_absolute_percentage_error: 18.9773
# Epoch 2813/3000
# 680/680 - 2s - 4ms/step - loss: 2289333174272.0000 - mean_absolute_percentage_error: 19.3186 - val_loss: 3224565710848.0000 - val_mean_absolute_percentage_error: 19.0072
# Epoch 2814/3000
# 680/680 - 2s - 3ms/step - loss: 2289254531072.0000 - mean_absolute_percentage_error: 19.2934 - val_loss: 3213601538048.0000 - val_mean_absolute_percentage_error: 18.9777
# Epoch 2815/3000
# 680/680 - 2s - 2ms/step - loss: 2289261084672.0000 - mean_absolute_percentage_error: 19.3120 - val_loss: 3231494176768.0000 - val_mean_absolute_percentage_error: 19.0268
# CPU times: user 1h 34min 40s, sys: 3min 35s, total: 1h 38min 16s
# Wall time: 1h 52min 21s

# %%
new.save('model/model'+model_name+' '+str(data.columns.size-2)+'.keras')  # The file needs to end with the .keras extension
# uncomment to load
# new = tf.keras.models.load_model('model32-32 3.keras')
from sklearn.metrics import mean_squared_error
print(mean_squared_error(new.predict(X_train),y_train))
print(mean_squared_error(new.predict(X_val),y_val))
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 2583164354560.0
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 3029701492736.0

# %% [markdown]
# ### 2 Plots: mse loss and cross-validation loss

# %%
line1=plt.plot(history.history['loss'],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'],label='Validation Mean Squared Error')
plt.legend()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()
line1=plt.plot(history.history['loss'][100:],label='Training Mean Squared Error')
line2=plt.plot(history.history['val_loss'][100:],label='Validation Mean Squared Error')
plt.xticks( list(range(0,2000,200)), list(range(100,2000,200)))
list(range(len(line1)))
plt.legend()
plt.title('Loss after 100 epochs')
plt.xlabel('epochs')
plt.ylabel('kWh^2')
plt.show()

# %% [markdown]
# ### 3 Qualitative Plots

# %%
start_train=train_idx[0]
end_train=train_idx[15*24]
print(start_train)

start_val=val_idx[0]
end_val=val_idx[15*24]
print(start_val)

start_test=test_idx[45*24]
end_test=test_idx[45*24+15*24]
print(start_test)
# Out:
# 2018-08-02 04:00:00
# 2021-04-04 10:00:00
# 2021-11-16 17:00:00

# %%
y_train_prediction=new.predict(X_train)
y_val_prediction=new.predict(X_val)
# Out:
# 680/680 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()

# %%
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas inflow", "predicted gas inflow"])

# %%
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Training data')
plt.legend(["gas outflow", "predicted gas outflow"])

# %%
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Validation data')
plt.show()

# %% [markdown]
# ## --

# %%
y_TEST_prediction=new.predict(X_test)

from sklearn.metrics import mean_absolute_percentage_error
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

mse_test_inflow=mean_squared_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mse_test_outflow=mean_squared_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse test inflow ',mse_test_inflow)
print('mse test outflow ',mse_test_outflow)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))

print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)

b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Model '+ model_name + ' ('+str(data.columns.size-2)+' Inputs): Test data')
plt.show()
# Out:
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# mse_test:  3976488812544.0
# mse test inflow  3886726103906.3833
# mse test outflow  4066245928992.2124
# mape_test:  0.19227704405784607
# mape test inflow  0.18014126595534505
# mape test outflow  0.20441280775909404

# %%
X_total_train=np.append(X_train,values=X_val,axis=0)
y_total_train=np.append(y_train,values=y_val,axis=0)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error
regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_train_prediction=regressor.predict(X_train)
y_val_prediction=regressor.predict(X_val)
y_TEST_prediction=regressor.predict(X_test)

mape_test_inflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)0 inflow'],y_TEST_prediction[:,0])
mape_test_outflow=mean_absolute_percentage_error(y_test['sum(physicalFlow)1 outflow'],y_TEST_prediction[:,1])

print('mse_train: ',mean_squared_error(y_train,y_train_prediction))
print('mse_val: ',mean_squared_error(y_val,y_val_prediction))
print('mse_test: ',mean_squared_error(y_test,y_TEST_prediction))

print('mape_train: ',mean_absolute_percentage_error(y_train,y_train_prediction))
print('mape_val: ',mean_absolute_percentage_error(y_val,y_val_prediction))
print('mape_test: ',mean_absolute_percentage_error(y_test,y_TEST_prediction))


print('mape test inflow ',mape_test_inflow)
print('mape test outflow ',mape_test_outflow)
## train
a=pd.DataFrame(y_train).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
a['prediction gas inflow']=y_train_prediction[:,0]
a['prediction gas outflow']=y_train_prediction[:,1]
# a.round()
# a['2018-10':'2018-10-10'].plot()
a[start_train:end_train]['gas inflow'].plot()
a[start_train:end_train]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Training data')
plt.show()
a[start_train:end_train]['gas outflow'].plot()
a[start_train:end_train]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Training data')
plt.show()
## val
b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_val:end_val]['gas inflow'].plot()
b[start_val:end_val]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Validation data')
plt.show()

b[start_val:end_val]['gas outflow'].plot()
b[start_val:end_val]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Validation data')
plt.show()

b=pd.DataFrame(y_val).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_val_prediction[:,0]
b['prediction gas outflow']=y_val_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

## test
b=pd.DataFrame(y_test).rename(columns={'sum(physicalFlow)0 inflow':'gas inflow','sum(physicalFlow)1 outflow':'gas outflow'})
b['prediction gas inflow']=y_TEST_prediction[:,0]
b['prediction gas outflow']=y_TEST_prediction[:,1]
# b.round()
# b['2018-10':'2018-10-10'].plot()

b[start_test:end_test]['gas inflow'].plot()
b[start_test:end_test]['prediction gas inflow'].plot()
plt.legend(["gas inflow", "predicted gas inflow"])
plt.title('Regression: Test data')
plt.show()

b[start_test:end_test]['gas outflow'].plot()
b[start_test:end_test]['prediction gas outflow'].plot()
plt.legend(["gas outflow", "predicted gas outflow"])
plt.title('Regression: Test data')
plt.show()

# print('mape test inflow 2022 6 ',mean_absolute_percentage_error(y_test['2022-6-20':'2022-6']['sum(physicalFlow)0 inflow'],pd.DataFrame(y_TEST_prediction,index=test_idx)['2022-6-20':'2022-6'][0]))

# b['2022-6':'2022-6']['gas outflow'].plot()
# b['2022-6':'2022-6']['prediction gas outflow'].plot()
# plt.legend(["gas outflow", "predicted gas outflow"])
# plt.title('Test data')
# Out:
# mse_train:  2495186000199.182
# mse_val:  3283774487665.349
# mse_test:  3852757611181.9287
# mape_train:  0.20096472156614587
# mape_val:  0.1899900955017627
# mape_test:  0.18181033550773262
# mape test inflow  0.17604202406760325
# mape test outflow  0.1875786469478627
